# %% [markdown]
# # Miscellaneous

# %%
from rdkit import Chem
import pandas as pd
import csv

df = pd.read_csv('merged_molecules1.csv')

# Count the occurrences of each value in the 'validity' column
validity_counts = df['validity'].value_counts()

# Print the counts
print(validity_counts)

# Optionally, you can access the counts for 'valid' and 'invalid' specifically
valid_count = validity_counts.get('valid', 0)
invalid_count = validity_counts.get('invalid', 0)

print(f"Valid molecules: {valid_count}")
print(f"Invalid molecules: {invalid_count}")
# Out:
# validity
# valid      84452
# invalid    15548
# Name: count, dtype: int64
# Valid molecules: 84452
# Invalid molecules: 15548

# %%
import re
import csv

def extract_losses_and_validities(file_path):
    # Initialize an empty list to store the results
    results = []
    
    # Regular expression pattern to match lines with disc_loss, gen_loss, and valid
    pattern = re.compile(r'disc_loss:\s*([\d.]+),\s*gen_loss:\s*([\d.-]+),\s*valid\s*\d+\s*=\s*([\d.]+)')
    
    # Open the file and read it line by line
    with open(file_path, 'r') as file:
        for line in file:
            # Search for the pattern in the current line
            match = pattern.search(line)
            if match:
                # Extract values and add them to the results list
                disc_loss, gen_loss, valid = match.groups()
                results.append({
                    'disc_loss': float(disc_loss),
                    'gen_loss': float(gen_loss),
                    'valid': float(valid)
                })
    
    return results

def save_to_csv(data, output_file):
    # Specify the fieldnames based on the keys in the dictionaries
    fieldnames = ['disc_loss', 'gen_loss', 'valid']
    
    # Open the CSV file in write mode
    with open(output_file, 'w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        
        # Write the header
        writer.writeheader()
        
        # Write the data rows
        writer.writerows(data)

# Specify the path to your input .txt file and output .csv file
input_file_path = 'losses.txt'
output_file_path = 'losses.csv'

# Extract data from the .txt file
extracted_data = extract_losses_and_validities(input_file_path)

# Save the extracted data to a CSV file
save_to_csv(extracted_data, output_file_path)
extracted_data
# Out:
# [{'disc_loss': 0.69738722, 'gen_loss': 1.15852427, 'valid': 0.02},
#  {'disc_loss': 0.23383799, 'gen_loss': -4.01097965, 'valid': 0.0},
#  {'disc_loss': 0.04292502, 'gen_loss': 0.79418868, 'valid': 0.03},
#  {'disc_loss': 0.00702529, 'gen_loss': -0.15746461, 'valid': 0.14},
#  {'disc_loss': 0.01574175, 'gen_loss': 0.22207528, 'valid': 0.08},
#  {'disc_loss': 0.0039141, 'gen_loss': 0.00193376, 'valid': 0.09},
#  {'disc_loss': 0.0300383, 'gen_loss': -0.04787258, 'valid': 0.06},
#  {'disc_loss': 0.00552681, 'gen_loss': 0.17580704, 'valid': 0.04},
#  {'disc_loss': 0.00537377, 'gen_loss': -0.16845562, 'valid': 0.07},
#  {'disc_loss': 0.00143724, 'gen_loss': -0.10243212, 'valid': 0.05},
#  {'disc_loss': 0.00341556, 'gen_loss': 0.12107533, 'valid': 0.05},
#  {'disc_loss': 0.00047034, 'gen_loss': -0.09414044, 'valid': 0.03},
#  {'disc_loss': 0.01540486, 'gen_loss': -0.10632857, 'valid': 0.04},
#  {'disc_loss': 0.00109082, 'gen_loss': -0.05116373, 'valid': 0.04},
#  {'disc_loss': 0.00459421, 'gen_loss': 0.41004258, 'valid': 0.01},
#  {'disc_loss': 0.00378867, 'gen_loss': 0.14420217, 'valid': 0.02},
#  {'disc_loss': 0.00010583, 'gen_loss': -0.08297262, 'valid': 0.03},
#  {'disc_loss': 7.487e-05, 'gen_loss': -0.0419189, 'valid': 0.02},
#  {'disc_loss': 0.0003589, 'gen_loss': -0.04667303, 'valid': 0.03},
#  {'disc_loss': 0.00716799, 'gen_loss': -0.22910021, 'valid': 0.06},
#  {'disc_loss': 0.00454581, 'gen_loss': -1.08012402, 'valid': 0.11},
#  {'disc_loss': 0.00095962, 'gen_loss': -0.09774516, 'valid': 0.1},
#  {'disc_loss': 0.06313824, 'gen_loss': -0.36291939, 'valid': 0.09},
#  {'disc_loss': 0.00047072, 'gen_loss': -0.27870709, 'valid': 0.01},
#  {'disc_loss': 0.00835563, 'gen_loss': 0.37761116, 'valid': 0.03},
#  {'disc_loss': 0.00092443, 'gen_loss': -0.05040459, 'valid': 0.02},
#  {'disc_loss': 0.04656492, 'gen_loss': -0.06491023, 'valid': 0.03},
#  {'disc_loss': 0.00799904, 'gen_loss': -0.00439233, 'valid': 0.11},
#  {'disc_loss': 0.00031229, 'gen_loss': -0.14997676, 'valid': 0.03},
#  {'disc_loss': 0.00624461, 'gen_loss': 0.68832552, 'valid': 0.03},
#  {'disc_loss': 0.00046262, 'gen_loss': -0.09154515, 'valid': 0.02},
#  {'disc_loss': 0.00039691, 'gen_loss': -0.07651667, 'valid': 0.02},
#  {'disc_loss': 0.00015572, 'gen_loss': -0.07512152, 'valid': 0.02},
#  {'disc_loss': 0.03732083, 'gen_loss': -0.37082133, 'valid': 0.11},
#  {'disc_loss': 0.00042408, 'gen_loss': -0.0603126, 'valid': 0.03},
#  {'disc_loss': 0.00025727, 'gen_loss': -0.13620961, 'valid': 0.02},
#  {'disc_loss': 0.00037553, 'gen_loss': -0.20482713, 'valid': 0.06},
#  {'disc_loss': 0.0039281, 'gen_loss': -0.17053625, 'valid': 0.04},
#  {'disc_loss': 0.00249965, 'gen_loss': -0.21206714, 'valid': 0.06},
#  {'disc_loss': 0.0017615, 'gen_loss': -0.09868468, 'valid': 0.03},
#  {'disc_loss': 0.00023296, 'gen_loss': -0.22534193, 'valid': 0.01},
#  {'disc_loss': 0.00365304, 'gen_loss': -0.15691456, 'valid': 0.02},
#  {'disc_loss': 0.00078898, 'gen_loss': -0.08432466, 'valid': 0.03},
#  {'disc_loss': 0.00059391, 'gen_loss': -0.10593893, 'valid': 0.05},
#  {'disc_loss': 6.528e-05, 'gen_loss': -0.09725605, 'valid': 0.03},
#  {'disc_loss': 0.00022958, 'gen_loss': -0.08543886, 'valid': 0.01},
#  {'disc_loss': 0.00117531, 'gen_loss': -0.29493102, 'valid': 0.02},
#  {'disc_loss': 0.00165963, 'gen_loss': -0.25842974, 'valid': 0.03},
#  {'disc_loss': 0.00011426, 'gen_loss': -0.12640208, 'valid': 0.01},
#  {'disc_loss': 0.00181239, 'gen_loss': -0.20644914, 'valid': 0.01},
#  {'disc_loss': 0.01393871, 'gen_loss': -0.12785125, 'valid': 0.0},
#  {'disc_loss': 0.00108872, 'gen_loss': -0.02474267, 'valid': 0.04},
#  {'disc_loss': 2.001e-05, 'gen_loss': -0.06472346, 'valid': 0.0},
#  {'disc_loss': 6.45e-06, 'gen_loss': -0.06833307, 'valid': 0.01},
#  {'disc_loss': 1.142e-05, 'gen_loss': -0.04042049, 'valid': 0.0},
#  {'disc_loss': 1.33e-06, 'gen_loss': -0.04163376, 'valid': 0.0},
#  {'disc_loss': 1.74e-06, 'gen_loss': -0.0409314, 'valid': 0.02},
#  {'disc_loss': 6.02e-06, 'gen_loss': -0.0412203, 'valid': 0.01},
#  {'disc_loss': 5.13e-06, 'gen_loss': -0.0411411, 'valid': 0.03},
#  {'disc_loss': 1.77e-06, 'gen_loss': -0.04286876, 'valid': 0.01},
#  {'disc_loss': 5.38e-06, 'gen_loss': -0.04327437, 'valid': 0.0},
#  {'disc_loss': 2.79e-06, 'gen_loss': -0.06630687, 'valid': 0.0},
#  {'disc_loss': 0.00106524, 'gen_loss': -0.14995144, 'valid': 0.14},
#  {'disc_loss': 4.705e-05, 'gen_loss': -0.16851299, 'valid': 0.09},
#  {'disc_loss': 0.02881686, 'gen_loss': -0.43802226, 'valid': 0.11},
#  {'disc_loss': 0.00038415, 'gen_loss': -0.20544831, 'valid': 0.02},
#  {'disc_loss': 0.02882181, 'gen_loss': -0.17331359, 'valid': 0.06},
#  {'disc_loss': 0.0373981, 'gen_loss': 0.12532602, 'valid': 0.04},
#  {'disc_loss': 0.0507998, 'gen_loss': -0.66247392, 'valid': 0.03},
#  {'disc_loss': 0.00551964, 'gen_loss': -0.4319534, 'valid': 0.56},
#  {'disc_loss': 0.11399244, 'gen_loss': 1.21755099, 'valid': 0.07},
#  {'disc_loss': 0.00172053, 'gen_loss': -0.05015236, 'valid': 0.06},
#  {'disc_loss': 0.00745399, 'gen_loss': -0.13729304, 'valid': 0.04},
#  {'disc_loss': 0.00626741, 'gen_loss': -0.6626668, 'valid': 0.01},
#  {'disc_loss': 0.01123045, 'gen_loss': -0.27993372, 'valid': 0.11},
#  {'disc_loss': 0.00809546, 'gen_loss': -0.02188388, 'valid': 0.2},
#  {'disc_loss': 0.00051567, 'gen_loss': -0.23080793, 'valid': 0.04},
#  {'disc_loss': 0.02982871, 'gen_loss': -0.0905324, 'valid': 0.04},
#  {'disc_loss': 0.01460682, 'gen_loss': -0.0660757, 'valid': 0.04},
#  {'disc_loss': 0.00200096, 'gen_loss': -0.04182118, 'valid': 0.07},
#  {'disc_loss': 0.007246, 'gen_loss': 0.29510006, 'valid': 0.1},
#  {'disc_loss': 0.0008905, 'gen_loss': -0.30029568, 'valid': 0.03},
#  {'disc_loss': 0.01771401, 'gen_loss': 0.08832246, 'valid': 0.05},
#  {'disc_loss': 0.00074714, 'gen_loss': -0.06296229, 'valid': 0.17},
#  {'disc_loss': 0.00607691, 'gen_loss': 0.25448212, 'valid': 0.1},
#  {'disc_loss': 0.00173792, 'gen_loss': -0.13144109, 'valid': 0.1},
#  {'disc_loss': 0.01859514, 'gen_loss': 0.02232024, 'valid': 0.11},
#  {'disc_loss': 0.00379248, 'gen_loss': -0.21049927, 'valid': 0.17},
#  {'disc_loss': 0.00465653, 'gen_loss': -0.27618894, 'valid': 0.02},
#  {'disc_loss': 0.0024945, 'gen_loss': -0.18464109, 'valid': 0.07},
#  {'disc_loss': 0.00525539, 'gen_loss': 0.22074647, 'valid': 0.13},
#  {'disc_loss': 0.01178662, 'gen_loss': 0.22671573, 'valid': 0.03},
#  {'disc_loss': 0.02904265, 'gen_loss': 0.01666, 'valid': 0.37},
#  {'disc_loss': 0.00735251, 'gen_loss': -0.08625009, 'valid': 0.12},
#  {'disc_loss': 0.04984144, 'gen_loss': 0.57484746, 'valid': 0.08},
#  {'disc_loss': 0.03176283, 'gen_loss': -0.19013879, 'valid': 0.08},
#  {'disc_loss': 0.01014014, 'gen_loss': 0.41065702, 'valid': 0.18},
#  {'disc_loss': 0.00338949, 'gen_loss': -0.05279268, 'valid': 0.24},
#  {'disc_loss': 0.02329168, 'gen_loss': 0.08235355, 'valid': 0.11},
#  {'disc_loss': 0.00184549, 'gen_loss': -0.06187462, 'valid': 0.12},
#  {'disc_loss': 0.00133007, 'gen_loss': 0.01791836, 'valid': 0.22},
#  {'disc_loss': 0.00804934, 'gen_loss': -0.41134512, 'valid': 0.14},
#  {'disc_loss': 0.00341224, 'gen_loss': -0.1999594, 'valid': 0.11},
#  {'disc_loss': 0.02183007, 'gen_loss': 1.00326741, 'valid': 0.05},
#  {'disc_loss': 0.01808447, 'gen_loss': 0.14865094, 'valid': 0.21},
#  {'disc_loss': 0.00115827, 'gen_loss': -0.08294383, 'valid': 0.02},
#  {'disc_loss': 0.0126837, 'gen_loss': -0.18121785, 'valid': 0.14},
#  {'disc_loss': 0.01040618, 'gen_loss': -0.03240795, 'valid': 0.05},
#  {'disc_loss': 0.00169615, 'gen_loss': -0.1436609, 'valid': 0.08},
#  {'disc_loss': 0.0022059, 'gen_loss': -0.17027436, 'valid': 0.08},
#  {'disc_loss': 0.06977005, 'gen_loss': 0.98996925, 'valid': 0.03},
#  {'disc_loss': 0.00143607, 'gen_loss': -0.09840749, 'valid': 0.09},
#  {'disc_loss': 0.01162566, 'gen_loss': -0.11699149, 'valid': 0.08},
#  {'disc_loss': 0.00083978, 'gen_loss': -0.46734998, 'valid': 0.09},
#  {'disc_loss': 0.06160837, 'gen_loss': -0.07719917, 'valid': 0.22},
#  {'disc_loss': 0.05203509, 'gen_loss': 2.08009958, 'valid': 0.12},
#  {'disc_loss': 0.01746317, 'gen_loss': -0.20280489, 'valid': 0.16},
#  {'disc_loss': 0.00945681, 'gen_loss': 0.70376569, 'valid': 0.06},
#  {'disc_loss': 0.03351979, 'gen_loss': 0.24681571, 'valid': 0.05},
#  {'disc_loss': 0.00786449, 'gen_loss': -0.07302029, 'valid': 0.08},
#  {'disc_loss': 0.00606959, 'gen_loss': -0.46619084, 'valid': 0.03},
#  {'disc_loss': 0.01626241, 'gen_loss': -0.46908432, 'valid': 0.05},
#  {'disc_loss': 0.00460189, 'gen_loss': -0.07940902, 'valid': 0.03},
#  {'disc_loss': 0.00310222, 'gen_loss': -0.26839757, 'valid': 0.11},
#  {'disc_loss': 0.03388824, 'gen_loss': 1.28019047, 'valid': 0.05},
#  {'disc_loss': 0.01025786, 'gen_loss': -0.11245727, 'valid': 0.05},
#  {'disc_loss': 0.01178748, 'gen_loss': 0.25140506, 'valid': 0.12},
#  {'disc_loss': 0.00643196, 'gen_loss': -0.30263734, 'valid': 0.16},
#  {'disc_loss': 0.0190387, 'gen_loss': -0.29060364, 'valid': 0.07},
#  {'disc_loss': 0.00758445, 'gen_loss': 0.11480577, 'valid': 0.22},
#  {'disc_loss': 0.01958848, 'gen_loss': -0.32915276, 'valid': 0.13},
#  {'disc_loss': 0.01806086, 'gen_loss': -0.18314357, 'valid': 0.14},
#  {'disc_loss': 0.03973077, 'gen_loss': -0.15771073, 'valid': 0.14},
#  {'disc_loss': 0.01687444, 'gen_loss': 0.3731001, 'valid': 0.06},
#  {'disc_loss': 0.01205072, 'gen_loss': 0.09391248, 'valid': 0.04},
#  {'disc_loss': 0.01310854, 'gen_loss': -0.32309332, 'valid': 0.11},
#  {'disc_loss': 0.01421369, 'gen_loss': 0.14723814, 'valid': 0.16},
#  {'disc_loss': 0.01017976, 'gen_loss': 0.36977947, 'valid': 0.17},
#  {'disc_loss': 0.02031651, 'gen_loss': -0.02751292, 'valid': 0.18},
#  {'disc_loss': 0.0460984, 'gen_loss': 1.54274189, 'valid': 0.06},
#  {'disc_loss': 0.01751984, 'gen_loss': -0.27521712, 'valid': 0.15},
#  {'disc_loss': 0.02170116, 'gen_loss': 0.39056516, 'valid': 0.28},
#  {'disc_loss': 0.00357122, 'gen_loss': -0.23204948, 'valid': 0.08},
#  {'disc_loss': 0.02236612, 'gen_loss': 1.09233832, 'valid': 0.1},
#  {'disc_loss': 0.01739301, 'gen_loss': -0.41594529, 'valid': 0.11},
#  {'disc_loss': 0.0169595, 'gen_loss': -0.19083028, 'valid': 0.1},
#  {'disc_loss': 0.01320265, 'gen_loss': -0.33320647, 'valid': 0.14},
#  {'disc_loss': 0.04346262, 'gen_loss': -0.71276331, 'valid': 0.1},
#  {'disc_loss': 0.01643603, 'gen_loss': -0.20115562, 'valid': 0.1},
#  {'disc_loss': 0.02002107, 'gen_loss': -0.13812654, 'valid': 0.09},
#  {'disc_loss': 0.00685994, 'gen_loss': -0.21096149, 'valid': 0.11},
#  {'disc_loss': 0.02204042, 'gen_loss': -0.06735931, 'valid': 0.19},
#  {'disc_loss': 0.00921842, 'gen_loss': -0.37885255, 'valid': 0.18},
#  {'disc_loss': 0.03302517, 'gen_loss': -0.1382295, 'valid': 0.04},
#  {'disc_loss': 0.00168695, 'gen_loss': -0.21912152, 'valid': 0.18},
#  {'disc_loss': 0.02500736, 'gen_loss': -0.0229327, 'valid': 0.17},
#  {'disc_loss': 0.02016373, 'gen_loss': -0.05334264, 'valid': 0.21},
#  {'disc_loss': 0.01319844, 'gen_loss': -0.23196012, 'valid': 0.07},
#  {'disc_loss': 0.05741524, 'gen_loss': 0.00808828, 'valid': 0.16},
#  {'disc_loss': 0.01620245, 'gen_loss': 0.19670464, 'valid': 0.09},
#  {'disc_loss': 0.02208345, 'gen_loss': 0.23982596, 'valid': 0.16},
#  {'disc_loss': 0.01760049, 'gen_loss': -0.14804521, 'valid': 0.1},
#  {'disc_loss': 0.02190034, 'gen_loss': 0.13956037, 'valid': 0.12},
#  {'disc_loss': 0.01268991, 'gen_loss': -0.2258306, 'valid': 0.05},
#  {'disc_loss': 0.02023325, 'gen_loss': -0.31368002, 'valid': 0.02},
#  {'disc_loss': 0.03944518, 'gen_loss': 0.0751491, 'valid': 0.1},
#  {'disc_loss': 0.03833371, 'gen_loss': -0.1342057, 'valid': 0.11},
#  {'disc_loss': 0.01363373, 'gen_loss': -0.29182082, 'valid': 0.13},
#  {'disc_loss': 0.02198336, 'gen_loss': 0.11753643, 'valid': 0.13},
#  {'disc_loss': 0.00229745, 'gen_loss': -0.26062137, 'valid': 0.14},
#  {'disc_loss': 0.01984003, 'gen_loss': 0.11552837, 'valid': 0.14},
#  {'disc_loss': 0.02587683, 'gen_loss': -0.03321156, 'valid': 0.19},
#  {'disc_loss': 0.01963906, 'gen_loss': 0.84387308, 'valid': 0.13},
#  {'disc_loss': 0.03259971, 'gen_loss': 0.10745212, 'valid': 0.11},
#  {'disc_loss': 0.04089123, 'gen_loss': 0.90132868, 'valid': 0.27},
#  {'disc_loss': 0.00655003, 'gen_loss': -0.19852763, 'valid': 0.17},
#  {'disc_loss': 0.03450648, 'gen_loss': 0.13009578, 'valid': 0.15},
#  {'disc_loss': 0.05838094, 'gen_loss': 1.50670421, 'valid': 0.1},
#  {'disc_loss': 0.04086661, 'gen_loss': 0.59114945, 'valid': 0.13},
#  {'disc_loss': 0.02327624, 'gen_loss': 0.08903087, 'valid': 0.28},
#  {'disc_loss': 0.03003088, 'gen_loss': 0.49108562, 'valid': 0.21},
#  {'disc_loss': 0.04510832, 'gen_loss': -0.75479048, 'valid': 0.19},
#  {'disc_loss': 0.01763653, 'gen_loss': 0.3809351, 'valid': 0.17},
#  {'disc_loss': 0.03301997, 'gen_loss': 0.21227753, 'valid': 0.39},
#  {'disc_loss': 0.03875492, 'gen_loss': 0.6078161, 'valid': 0.3},
#  {'disc_loss': 0.04482322, 'gen_loss': 0.02839866, 'valid': 0.16},
#  {'disc_loss': 0.05349442, 'gen_loss': 0.4931393, 'valid': 0.26},
#  {'disc_loss': 0.02694805, 'gen_loss': -0.20652254, 'valid': 0.18},
#  {'disc_loss': 0.01541613, 'gen_loss': -0.59623301, 'valid': 0.32},
#  {'disc_loss': 0.0121097, 'gen_loss': 0.10847957, 'valid': 0.1},
#  {'disc_loss': 0.02965531, 'gen_loss': -0.44962031, 'valid': 0.17},
#  {'disc_loss': 0.03189543, 'gen_loss': 0.84684563, 'valid': 0.13},
#  {'disc_loss': 0.0156735, 'gen_loss': -0.7035659, 'valid': 0.24},
#  {'disc_loss': 0.02242645, 'gen_loss': 0.01354853, 'valid': 0.25},
#  {'disc_loss': 0.06574208, 'gen_loss': 0.0538137, 'valid': 0.28},
#  {'disc_loss': 0.04046645, 'gen_loss': -0.1163073, 'valid': 0.21},
#  {'disc_loss': 0.02575758, 'gen_loss': -0.1788855, 'valid': 0.3},
#  {'disc_loss': 0.03446305, 'gen_loss': -0.45245939, 'valid': 0.22},
#  {'disc_loss': 0.01760067, 'gen_loss': -0.30010587, 'valid': 0.35},
#  {'disc_loss': 0.0333422, 'gen_loss': 0.12693752, 'valid': 0.39},
#  {'disc_loss': 0.06164538, 'gen_loss': -0.16622402, 'valid': 0.21},
#  {'disc_loss': 0.02863221, 'gen_loss': 0.16312248, 'valid': 0.18},
#  {'disc_loss': 0.01619036, 'gen_loss': -0.45774928, 'valid': 0.23},
#  {'disc_loss': 0.03815867, 'gen_loss': 0.04167659, 'valid': 0.3},
#  {'disc_loss': 0.02159495, 'gen_loss': -0.4440214, 'valid': 0.15},
#  {'disc_loss': 0.06184772, 'gen_loss': 0.29838508, 'valid': 0.22},
#  {'disc_loss': 0.03179003, 'gen_loss': -0.06090694, 'valid': 0.29},
#  {'disc_loss': 0.01817967, 'gen_loss': 0.1796838, 'valid': 0.52},
#  {'disc_loss': 0.0409496, 'gen_loss': 0.4094539, 'valid': 0.39},
#  {'disc_loss': 0.02277204, 'gen_loss': 0.00901495, 'valid': 0.36},
#  {'disc_loss': 0.02789321, 'gen_loss': -0.46375313, 'valid': 0.3},
#  {'disc_loss': 0.02771938, 'gen_loss': -0.28824273, 'valid': 0.27},
#  {'disc_loss': 0.03044716, 'gen_loss': -0.64820921, 'valid': 0.24},
#  {'disc_loss': 0.04968873, 'gen_loss': 0.14389685, 'valid': 0.35},
#  {'disc_loss': 0.04521178, 'gen_loss': 0.05010814, 'valid': 0.32},
#  {'disc_loss': 0.03927707, 'gen_loss': -0.33367124, 'valid': 0.28},
#  {'disc_loss': 0.01926512, 'gen_loss': -0.53122735, 'valid': 0.42},
#  {'disc_loss': 0.02326424, 'gen_loss': 0.19467688, 'valid': 0.22},
#  {'disc_loss': 0.02519922, 'gen_loss': 0.14901225, 'valid': 0.23},
#  {'disc_loss': 0.03395194, 'gen_loss': -0.40817553, 'valid': 0.32},
#  {'disc_loss': 0.02338372, 'gen_loss': -0.15017766, 'valid': 0.36},
#  {'disc_loss': 0.00846025, 'gen_loss': -0.49109238, 'valid': 0.37},
#  {'disc_loss': 0.02947532, 'gen_loss': -0.31989658, 'valid': 0.43},
#  {'disc_loss': 0.01929383, 'gen_loss': -0.31606072, 'valid': 0.59},
#  {'disc_loss': 0.09046549, 'gen_loss': 1.14949214, 'valid': 0.36},
#  {'disc_loss': 0.02339588, 'gen_loss': -0.32795379, 'valid': 0.35},
#  {'disc_loss': 0.01853748, 'gen_loss': -0.74959606, 'valid': 0.31},
#  {'disc_loss': 0.02539591, 'gen_loss': -0.32604358, 'valid': 0.27},
#  {'disc_loss': 0.01395401, 'gen_loss': -0.40614441, 'valid': 0.18},
#  {'disc_loss': 0.05577625, 'gen_loss': 0.49728459, 'valid': 0.44},
#  {'disc_loss': 0.01553567, 'gen_loss': -0.16517401, 'valid': 0.31},
#  {'disc_loss': 0.01626287, 'gen_loss': -0.26044035, 'valid': 0.38},
#  {'disc_loss': 0.03431615, 'gen_loss': -0.33322668, 'valid': 0.44},
#  {'disc_loss': 0.04422917, 'gen_loss': -0.3731969, 'valid': 0.29},
#  {'disc_loss': 0.05318155, 'gen_loss': 0.0374145, 'valid': 0.3},
#  {'disc_loss': 0.03433723, 'gen_loss': 0.15654644, 'valid': 0.24},
#  {'disc_loss': 0.08120295, 'gen_loss': 0.66086411, 'valid': 0.39},
#  {'disc_loss': 0.02857414, 'gen_loss': -0.25846648, 'valid': 0.2},
#  {'disc_loss': 0.02992315, 'gen_loss': 0.31326187, 'valid': 0.52},
#  {'disc_loss': 0.04708619, 'gen_loss': 0.59069997, 'valid': 0.38},
#  {'disc_loss': 0.04028551, 'gen_loss': 0.4022114, 'valid': 0.51},
#  {'disc_loss': 0.05898312, 'gen_loss': -0.29361436, 'valid': 0.44},
#  {'disc_loss': 0.03789175, 'gen_loss': -0.36205497, 'valid': 0.32},
#  {'disc_loss': 0.05654684, 'gen_loss': -0.08677071, 'valid': 0.41},
#  {'disc_loss': 0.03786041, 'gen_loss': -0.30712709, 'valid': 0.26},
#  {'disc_loss': 0.04541261, 'gen_loss': 0.19517265, 'valid': 0.37},
#  {'disc_loss': 0.07989198, 'gen_loss': 1.68287468, 'valid': 0.22},
#  {'disc_loss': 0.01769814, 'gen_loss': -0.32448637, 'valid': 0.34},
#  {'disc_loss': 0.04787818, 'gen_loss': 0.28811216, 'valid': 0.41},
#  {'disc_loss': 0.0374606, 'gen_loss': -0.3481805, 'valid': 0.36},
#  {'disc_loss': 0.05587418, 'gen_loss': -0.87021387, 'valid': 0.38},
#  {'disc_loss': 0.04570831, 'gen_loss': 0.40422589, 'valid': 0.42},
#  {'disc_loss': 0.05253304, 'gen_loss': -0.44394439, 'valid': 0.52},
#  {'disc_loss': 0.0227987, 'gen_loss': -0.97968799, 'valid': 0.44},
#  {'disc_loss': 0.02666401, 'gen_loss': -0.10958039, 'valid': 0.5},
#  {'disc_loss': 0.0529363, 'gen_loss': 0.33060324, 'valid': 0.47},
#  {'disc_loss': 0.02262774, 'gen_loss': -0.60395879, 'valid': 0.08},
#  {'disc_loss': 0.03075423, 'gen_loss': -0.35078382, 'valid': 0.23},
#  {'disc_loss': 0.03197528, 'gen_loss': -0.25169381, 'valid': 0.34},
#  {'disc_loss': 0.11412983, 'gen_loss': -0.59891462, 'valid': 0.46},
#  {'disc_loss': 0.0765871, 'gen_loss': -0.4965975, 'valid': 0.5},
#  {'disc_loss': 0.02434604, 'gen_loss': -0.29360586, 'valid': 0.49},
#  {'disc_loss': 0.01290859, 'gen_loss': -0.4397409, 'valid': 0.37},
#  {'disc_loss': 0.03121665, 'gen_loss': -0.10171001, 'valid': 0.54},
#  {'disc_loss': 0.05320489, 'gen_loss': -0.10530644, 'valid': 0.57},
#  {'disc_loss': 0.04892518, 'gen_loss': 0.04061625, 'valid': 0.33},
#  {'disc_loss': 0.04312553, 'gen_loss': -0.38192084, 'valid': 0.46},
#  {'disc_loss': 0.0614258, 'gen_loss': -0.34127703, 'valid': 0.48},
#  {'disc_loss': 0.03503381, 'gen_loss': -0.37515059, 'valid': 0.67},
#  {'disc_loss': 0.04519407, 'gen_loss': -0.36809102, 'valid': 0.47},
#  {'disc_loss': 0.11675007, 'gen_loss': 0.37001559, 'valid': 0.51},
#  {'disc_loss': 0.16005798, 'gen_loss': 0.92747086, 'valid': 0.59},
#  {'disc_loss': 0.04974419, 'gen_loss': 0.01348327, 'valid': 0.65},
#  {'disc_loss': 0.05177712, 'gen_loss': -0.16702946, 'valid': 0.46},
#  {'disc_loss': 0.05800444, 'gen_loss': 0.1409612, 'valid': 0.55},
#  {'disc_loss': 0.08788459, 'gen_loss': -0.20141597, 'valid': 0.66},
#  {'disc_loss': 0.04021833, 'gen_loss': -0.92638433, 'valid': 0.5},
#  {'disc_loss': 0.06617547, 'gen_loss': -0.21489814, 'valid': 0.4},
#  {'disc_loss': 0.03837806, 'gen_loss': 1.23899174, 'valid': 0.42},
#  {'disc_loss': 0.03565358, 'gen_loss': -0.53340304, 'valid': 0.37},
#  {'disc_loss': 0.05400824, 'gen_loss': -0.56299186, 'valid': 0.53},
#  {'disc_loss': 0.03305789, 'gen_loss': -0.11888598, 'valid': 0.46},
#  {'disc_loss': 0.02726457, 'gen_loss': -0.2960566, 'valid': 0.54},
#  {'disc_loss': 0.06354628, 'gen_loss': -0.39262187, 'valid': 0.6},
#  {'disc_loss': 0.07408465, 'gen_loss': 0.22338702, 'valid': 0.44},
#  {'disc_loss': 0.02522553, 'gen_loss': -0.35181993, 'valid': 0.52},
#  {'disc_loss': 0.09545978, 'gen_loss': -0.7422576, 'valid': 0.69},
#  {'disc_loss': 0.021639, 'gen_loss': -0.50107801, 'valid': 0.53},
#  {'disc_loss': 0.05573237, 'gen_loss': -0.01875223, 'valid': 0.53},
#  {'disc_loss': 0.04345674, 'gen_loss': 0.0797808, 'valid': 0.63},
#  {'disc_loss': 0.03658868, 'gen_loss': -0.42939195, 'valid': 0.64},
#  {'disc_loss': 0.01459245, 'gen_loss': -0.07749278, 'valid': 0.63},
#  {'disc_loss': 0.03457191, 'gen_loss': 0.20886461, 'valid': 0.56},
#  {'disc_loss': 0.03097539, 'gen_loss': -0.47813985, 'valid': 0.57},
#  {'disc_loss': 0.05865433, 'gen_loss': 0.42234924, 'valid': 0.52},
#  {'disc_loss': 0.06736992, 'gen_loss': -0.16899177, 'valid': 0.58},
#  {'disc_loss': 0.05426519, 'gen_loss': 0.10111913, 'valid': 0.56},
#  {'disc_loss': 0.01958556, 'gen_loss': -0.22139451, 'valid': 0.3},
#  {'disc_loss': 0.03713641, 'gen_loss': 0.66870618, 'valid': 0.52},
#  {'disc_loss': 0.04461607, 'gen_loss': 0.05037481, 'valid': 0.73},
#  {'disc_loss': 0.02328191, 'gen_loss': -0.71816123, 'valid': 0.56},
#  {'disc_loss': 0.06169427, 'gen_loss': 0.17141829, 'valid': 0.47},
#  {'disc_loss': 0.07711875, 'gen_loss': -0.39602587, 'valid': 0.65},
#  {'disc_loss': 0.06225893, 'gen_loss': 0.24761969, 'valid': 0.3},
#  {'disc_loss': 0.06510003, 'gen_loss': 0.00824078, 'valid': 0.47},
#  {'disc_loss': 0.11721797, 'gen_loss': -0.67511755, 'valid': 0.31},
#  {'disc_loss': 0.05457434, 'gen_loss': 0.17006953, 'valid': 0.51},
#  {'disc_loss': 0.03938177, 'gen_loss': 0.23630083, 'valid': 0.63},
#  {'disc_loss': 0.03939366, 'gen_loss': 0.17835583, 'valid': 0.58},
#  {'disc_loss': 0.04274556, 'gen_loss': 0.34344763, 'valid': 0.39},
#  {'disc_loss': 0.0566454, 'gen_loss': -0.70332819, 'valid': 0.37},
#  {'disc_loss': 0.07152533, 'gen_loss': -0.16816027, 'valid': 0.54},
#  {'disc_loss': 0.0432306, 'gen_loss': -0.18183097, 'valid': 0.47},
#  {'disc_loss': 0.03359489, 'gen_loss': -0.00708253, 'valid': 0.42},
#  {'disc_loss': 0.00887002, 'gen_loss': -0.17596188, 'valid': 0.62},
#  {'disc_loss': 0.06034649, 'gen_loss': 0.09130505, 'valid': 0.5},
#  {'disc_loss': 0.04239627, 'gen_loss': 0.23319322, 'valid': 0.53},
#  {'disc_loss': 0.06360459, 'gen_loss': 0.47442505, 'valid': 0.32},
#  {'disc_loss': 0.04195648, 'gen_loss': 0.22057101, 'valid': 0.28},
#  {'disc_loss': 0.03357466, 'gen_loss': -0.14867206, 'valid': 0.54},
#  {'disc_loss': 0.05115021, 'gen_loss': -0.23634969, 'valid': 0.55},
#  {'disc_loss': 0.07084189, 'gen_loss': 0.51054156, 'valid': 0.68},
#  {'disc_loss': 0.04289978, 'gen_loss': -0.54327649, 'valid': 0.76},
#  {'disc_loss': 0.04448486, 'gen_loss': 0.08700753, 'valid': 0.7},
#  {'disc_loss': 0.03717277, 'gen_loss': -0.67817301, 'valid': 0.65},
#  {'disc_loss': 0.10041479, 'gen_loss': -0.11242702, 'valid': 0.61},
#  {'disc_loss': 0.04190955, 'gen_loss': -0.29287335, 'valid': 0.67},
#  {'disc_loss': 0.04000312, 'gen_loss': 0.49358913, 'valid': 0.55},
#  {'disc_loss': 0.06623162, 'gen_loss': -0.4412795, 'valid': 0.58},
#  {'disc_loss': 0.04076672, 'gen_loss': 0.38986936, 'valid': 0.69},
#  {'disc_loss': 0.04805298, 'gen_loss': 0.10109019, 'valid': 0.61},
#  {'disc_loss': 0.07234679, 'gen_loss': 0.17690694, 'valid': 0.78},
#  {'disc_loss': 0.0878752, 'gen_loss': 0.5213539, 'valid': 0.8},
#  {'disc_loss': 0.08029614, 'gen_loss': 0.52920818, 'valid': 0.85},
#  {'disc_loss': 0.02189691, 'gen_loss': -0.37138912, 'valid': 0.64},
#  {'disc_loss': 0.05681501, 'gen_loss': 0.13432246, 'valid': 0.46},
#  {'disc_loss': 0.0334111, 'gen_loss': -0.87971807, 'valid': 0.59},
#  {'disc_loss': 0.02550462, 'gen_loss': -0.12744389, 'valid': 0.62},
#  {'disc_loss': 0.06041713, 'gen_loss': 0.17366633, 'valid': 0.65},
#  {'disc_loss': 0.03628747, 'gen_loss': -0.15454534, 'valid': 0.78},
#  {'disc_loss': 0.0765773, 'gen_loss': 1.56936395, 'valid': 0.59},
#  {'disc_loss': 0.02689144, 'gen_loss': -0.40548551, 'valid': 0.61},
#  {'disc_loss': 0.09220472, 'gen_loss': -0.347155, 'valid': 0.61},
#  {'disc_loss': 0.06161902, 'gen_loss': 0.49536747, 'valid': 0.62},
#  {'disc_loss': 0.03510454, 'gen_loss': -0.37724268, 'valid': 0.65},
#  {'disc_loss': 0.05117545, 'gen_loss': 0.71073478, 'valid': 0.64},
#  {'disc_loss': 0.02859605, 'gen_loss': -0.64841753, 'valid': 0.64},
#  {'disc_loss': 0.03393798, 'gen_loss': -0.23459868, 'valid': 0.48},
#  {'disc_loss': 0.04605345, 'gen_loss': 0.49814734, 'valid': 0.61},
#  {'disc_loss': 0.08312564, 'gen_loss': -0.3307437, 'valid': 0.61},
#  {'disc_loss': 0.05305345, 'gen_loss': 0.25832024, 'valid': 0.62},
#  {'disc_loss': 0.05065215, 'gen_loss': -0.41673648, 'valid': 0.64},
#  {'disc_loss': 0.03384146, 'gen_loss': -0.42904949, 'valid': 0.67},
#  {'disc_loss': 0.03036695, 'gen_loss': -0.04652855, 'valid': 0.6},
#  {'disc_loss': 0.04485638, 'gen_loss': -0.28646299, 'valid': 0.72},
#  {'disc_loss': 0.04596968, 'gen_loss': -0.00706028, 'valid': 0.6},
#  {'disc_loss': 0.07322867, 'gen_loss': -0.00733088, 'valid': 0.68},
#  {'disc_loss': 0.03629754, 'gen_loss': -0.46036863, 'valid': 0.6},
#  {'disc_loss': 0.03074511, 'gen_loss': -0.39331713, 'valid': 0.63},
#  {'disc_loss': 0.03173922, 'gen_loss': 0.50589317, 'valid': 0.74},
#  {'disc_loss': 0.03369293, 'gen_loss': -0.09633002, 'valid': 0.66},
#  {'disc_loss': 0.05912897, 'gen_loss': 0.64602405, 'valid': 0.56},
#  {'disc_loss': 0.04514944, 'gen_loss': 0.22845334, 'valid': 0.62},
#  {'disc_loss': 0.05882792, 'gen_loss': -0.01972859, 'valid': 0.42},
#  {'disc_loss': 0.04034821, 'gen_loss': 0.10799194, 'valid': 0.57},
#  {'disc_loss': 0.04188084, 'gen_loss': -0.51582748, 'valid': 0.59},
#  {'disc_loss': 0.04207112, 'gen_loss': -0.28854299, 'valid': 0.64},
#  {'disc_loss': 0.05283478, 'gen_loss': 0.41645578, 'valid': 0.64},
#  {'disc_loss': 0.03593239, 'gen_loss': 0.36129943, 'valid': 0.66},
#  {'disc_loss': 0.04546243, 'gen_loss': 0.18580309, 'valid': 0.61},
#  {'disc_loss': 0.04458454, 'gen_loss': 0.30460036, 'valid': 0.49},
#  {'disc_loss': 0.05320419, 'gen_loss': 0.61474842, 'valid': 0.62},
#  {'disc_loss': 0.07456063, 'gen_loss': -0.55001378, 'valid': 0.6},
#  {'disc_loss': 0.04807605, 'gen_loss': -0.0483225, 'valid': 0.63},
#  {'disc_loss': 0.05218401, 'gen_loss': 0.43270791, 'valid': 0.57},
#  {'disc_loss': 0.05922611, 'gen_loss': 0.21066889, 'valid': 0.66},
#  {'disc_loss': 0.0575726, 'gen_loss': 0.34446314, 'valid': 0.66},
#  {'disc_loss': 0.03472781, 'gen_loss': -0.21052466, 'valid': 0.77},
#  {'disc_loss': 0.0284278, 'gen_loss': -0.57307881, 'valid': 0.62},
#  {'disc_loss': 0.05111318, 'gen_loss': 0.28970152, 'valid': 0.64},
#  {'disc_loss': 0.07569082, 'gen_loss': -0.00761151, 'valid': 0.65},
#  {'disc_loss': 0.11847232, 'gen_loss': -0.62092936, 'valid': 0.7},
#  {'disc_loss': 0.03747101, 'gen_loss': -0.34424147, 'valid': 0.6},
#  {'disc_loss': 0.05477625, 'gen_loss': 1.0072422, 'valid': 0.64},
#  {'disc_loss': 0.02097422, 'gen_loss': -0.45009691, 'valid': 0.64},
#  {'disc_loss': 0.06612158, 'gen_loss': -0.35776055, 'valid': 0.8},
#  {'disc_loss': 0.01928546, 'gen_loss': -0.5719744, 'valid': 0.63},
#  {'disc_loss': 0.03608146, 'gen_loss': -0.17335969, 'valid': 0.53},
#  {'disc_loss': 0.03799005, 'gen_loss': -0.35541573, 'valid': 0.81},
#  {'disc_loss': 0.09114908, 'gen_loss': 0.56868923, 'valid': 0.8},
#  {'disc_loss': 0.0783438, 'gen_loss': 1.14215362, 'valid': 0.6},
#  {'disc_loss': 0.02615731, 'gen_loss': -0.22356279, 'valid': 0.43},
#  {'disc_loss': 0.05873017, 'gen_loss': 0.41259003, 'valid': 0.72},
#  {'disc_loss': 0.06033186, 'gen_loss': -0.29573789, 'valid': 0.6},
#  {'disc_loss': 0.02799957, 'gen_loss': -0.36156744, 'valid': 0.72},
#  {'disc_loss': 0.05588976, 'gen_loss': -0.1805286, 'valid': 0.68},
#  {'disc_loss': 0.06138584, 'gen_loss': -0.07290398, 'valid': 0.68},
#  {'disc_loss': 0.0178237, 'gen_loss': -0.19275588, 'valid': 0.61},
#  {'disc_loss': 0.08202184, 'gen_loss': 0.52789986, 'valid': 0.71},
#  {'disc_loss': 0.03729487, 'gen_loss': 0.22773208, 'valid': 0.38},
#  {'disc_loss': 0.0490912, 'gen_loss': 0.48398131, 'valid': 0.77},
#  {'disc_loss': 0.03987112, 'gen_loss': -0.59119326, 'valid': 0.7},
#  {'disc_loss': 0.03770941, 'gen_loss': 0.11238362, 'valid': 0.6},
#  {'disc_loss': 0.06675205, 'gen_loss': 0.34970897, 'valid': 0.5},
#  {'disc_loss': 0.06323478, 'gen_loss': 0.14801954, 'valid': 0.67},
#  {'disc_loss': 0.07067312, 'gen_loss': 0.15836628, 'valid': 0.76},
#  {'disc_loss': 0.03930651, 'gen_loss': -0.30429244, 'valid': 0.72},
#  {'disc_loss': 0.03823392, 'gen_loss': -0.1989051, 'valid': 0.46},
#  {'disc_loss': 0.04390769, 'gen_loss': -0.22918399, 'valid': 0.45},
#  {'disc_loss': 0.03828108, 'gen_loss': 0.06004205, 'valid': 0.56},
#  {'disc_loss': 0.04663685, 'gen_loss': -0.49004096, 'valid': 0.79},
#  {'disc_loss': 0.04816053, 'gen_loss': 0.03804497, 'valid': 0.81},
#  {'disc_loss': 0.06099928, 'gen_loss': -0.04035061, 'valid': 0.7},
#  {'disc_loss': 0.07806435, 'gen_loss': -0.09103823, 'valid': 0.66},
#  {'disc_loss': 0.08234517, 'gen_loss': 1.11072361, 'valid': 0.67},
#  {'disc_loss': 0.0595682, 'gen_loss': 0.22429937, 'valid': 0.67},
#  {'disc_loss': 0.03760672, 'gen_loss': 0.43454638, 'valid': 0.66},
#  {'disc_loss': 0.03778863, 'gen_loss': -0.53443992, 'valid': 0.59},
#  {'disc_loss': 0.03599897, 'gen_loss': 0.24057436, 'valid': 0.71},
#  {'disc_loss': 0.06853791, 'gen_loss': 0.68445098, 'valid': 0.77},
#  {'disc_loss': 0.07965659, 'gen_loss': 1.1402241, 'valid': 0.58},
#  {'disc_loss': 0.02651639, 'gen_loss': -0.08182605, 'valid': 0.6},
#  {'disc_loss': 0.03617425, 'gen_loss': 0.23303245, 'valid': 0.78},
#  {'disc_loss': 0.03552115, 'gen_loss': -0.28883389, 'valid': 0.75},
#  {'disc_loss': 0.06086447, 'gen_loss': 0.00219631, 'valid': 0.65},
#  {'disc_loss': 0.05691452, 'gen_loss': 0.37288415, 'valid': 0.8},
#  {'disc_loss': 0.03741868, 'gen_loss': -0.3679603, 'valid': 0.81},
#  {'disc_loss': 0.05832196, 'gen_loss': -0.03707849, 'valid': 0.49},
#  {'disc_loss': 0.03399355, 'gen_loss': -0.23946783, 'valid': 0.69},
#  {'disc_loss': 0.0561479, 'gen_loss': -0.35444105, 'valid': 0.75},
#  {'disc_loss': 0.08130646, 'gen_loss': 0.58922803, 'valid': 0.67},
#  {'disc_loss': 0.03666966, 'gen_loss': -0.47376218, 'valid': 0.6},
#  {'disc_loss': 0.06634134, 'gen_loss': 0.38750631, 'valid': 0.83},
#  {'disc_loss': 0.04281063, 'gen_loss': 0.03280793, 'valid': 0.68},
#  {'disc_loss': 0.03435871, 'gen_loss': 0.1382374, 'valid': 0.77},
#  {'disc_loss': 0.04083906, 'gen_loss': 0.39060715, 'valid': 0.76},
#  {'disc_loss': 0.06120357, 'gen_loss': -0.27212793, 'valid': 0.73},
#  {'disc_loss': 0.03701508, 'gen_loss': -0.42144781, 'valid': 0.67},
#  {'disc_loss': 0.06165582, 'gen_loss': 0.02729036, 'valid': 0.61},
#  {'disc_loss': 0.07459851, 'gen_loss': 0.58076811, 'valid': 0.66},
#  {'disc_loss': 0.05969048, 'gen_loss': 0.2203031, 'valid': 0.69},
#  {'disc_loss': 0.03455526, 'gen_loss': -0.39594856, 'valid': 0.81},
#  {'disc_loss': 0.03901304, 'gen_loss': 0.23581412, 'valid': 0.65},
#  {'disc_loss': 0.04923294, 'gen_loss': 0.40407309, 'valid': 0.52},
#  {'disc_loss': 0.04153201, 'gen_loss': -0.16801192, 'valid': 0.77},
#  {'disc_loss': 0.04265393, 'gen_loss': -0.43225348, 'valid': 0.72},
#  {'disc_loss': 0.06933906, 'gen_loss': -0.00287455, 'valid': 0.66},
#  {'disc_loss': 0.05086851, 'gen_loss': -0.16079088, 'valid': 0.67},
#  {'disc_loss': 0.01563606, 'gen_loss': -0.48061407, 'valid': 0.79},
#  {'disc_loss': 0.04342879, 'gen_loss': -0.54134119, 'valid': 0.72},
#  {'disc_loss': 0.0367478, 'gen_loss': -0.3037121, 'valid': 0.82},
#  {'disc_loss': 0.04997477, 'gen_loss': -0.41330373, 'valid': 0.46},
#  {'disc_loss': 0.05118573, 'gen_loss': 0.25252908, 'valid': 0.77},
#  {'disc_loss': 0.06262104, 'gen_loss': -0.35770178, 'valid': 0.64},
#  {'disc_loss': 0.04799196, 'gen_loss': -0.34089512, 'valid': 0.71},
#  {'disc_loss': 0.07209353, 'gen_loss': -0.02091675, 'valid': 0.8},
#  {'disc_loss': 0.04019396, 'gen_loss': 0.16389695, 'valid': 0.61},
#  {'disc_loss': 0.03573759, 'gen_loss': 0.00280622, 'valid': 0.75},
#  {'disc_loss': 0.07049073, 'gen_loss': 0.11187907, 'valid': 0.7},
#  {'disc_loss': 0.06664181, 'gen_loss': -0.16924979, 'valid': 0.67},
#  {'disc_loss': 0.03826448, 'gen_loss': 0.11902089, 'valid': 0.71},
#  {'disc_loss': 0.04652052, 'gen_loss': -0.31649542, 'valid': 0.79},
#  {'disc_loss': 0.04264098, 'gen_loss': 0.6519658, 'valid': 0.64},
#  {'disc_loss': 0.06553271, 'gen_loss': -0.41555214, 'valid': 0.77},
#  {'disc_loss': 0.08472514, 'gen_loss': 0.73189837, 'valid': 0.82},
#  {'disc_loss': 0.02696548, 'gen_loss': -0.27188826, 'valid': 0.66},
#  {'disc_loss': 0.05825459, 'gen_loss': -0.00824941, 'valid': 0.54},
#  {'disc_loss': 0.05505161, 'gen_loss': 0.52924478, 'valid': 0.69},
#  {'disc_loss': 0.04153121, 'gen_loss': -0.27205774, 'valid': 0.69},
#  {'disc_loss': 0.06756887, 'gen_loss': -0.56203949, 'valid': 0.81},
#  {'disc_loss': 0.0526108, 'gen_loss': 0.64669174, 'valid': 0.77},
#  {'disc_loss': 0.03966756, 'gen_loss': 0.10574014, 'valid': 0.74},
#  {'disc_loss': 0.07060021, 'gen_loss': 0.10159816, 'valid': 0.74},
#  {'disc_loss': 0.05207218, 'gen_loss': -0.21261866, 'valid': 0.84},
#  {'disc_loss': 0.03035155, 'gen_loss': -0.36803424, 'valid': 0.78},
#  {'disc_loss': 0.0597442, 'gen_loss': 0.31210566, 'valid': 0.97},
#  {'disc_loss': 0.07055585, 'gen_loss': 0.3409425, 'valid': 0.74},
#  {'disc_loss': 0.06097814, 'gen_loss': -0.16781454, 'valid': 0.68},
#  {'disc_loss': 0.0948364, 'gen_loss': 1.19196784, 'valid': 0.63},
#  {'disc_loss': 0.05726858, 'gen_loss': -0.4534466, 'valid': 0.69},
#  {'disc_loss': 0.0437918, 'gen_loss': 0.223316, 'valid': 0.79},
#  {'disc_loss': 0.04391753, 'gen_loss': -0.51842272, 'valid': 0.84},
#  {'disc_loss': 0.03214394, 'gen_loss': -0.25252685, 'valid': 0.82},
#  {'disc_loss': 0.075652, 'gen_loss': -0.00751577, 'valid': 0.78},
#  {'disc_loss': 0.03726468, 'gen_loss': -0.26892167, 'valid': 0.71},
#  {'disc_loss': 0.05060693, 'gen_loss': 0.11078008, 'valid': 0.77},
#  {'disc_loss': 0.03505582, 'gen_loss': -0.08103919, 'valid': 0.83},
#  {'disc_loss': 0.04586169, 'gen_loss': 0.26714998, 'valid': 0.79},
#  {'disc_loss': 0.05135306, 'gen_loss': -0.19666889, 'valid': 0.84},
#  {'disc_loss': 0.06424893, 'gen_loss': -0.11249828, 'valid': 0.75},
#  {'disc_loss': 0.06431293, 'gen_loss': -0.45138261, 'valid': 0.87},
#  {'disc_loss': 0.05002823, 'gen_loss': -0.08804459, 'valid': 0.8},
#  {'disc_loss': 0.03682582, 'gen_loss': 0.27819031, 'valid': 0.81},
#  {'disc_loss': 0.03138606, 'gen_loss': 0.23221937, 'valid': 0.75},
#  {'disc_loss': 0.08150209, 'gen_loss': -0.1874724, 'valid': 0.79},
#  {'disc_loss': 0.03536576, 'gen_loss': -0.02505639, 'valid': 0.66},
#  {'disc_loss': 0.0548594, 'gen_loss': 0.1993666, 'valid': 0.74},
#  {'disc_loss': 0.04724901, 'gen_loss': -0.24478364, 'valid': 0.71},
#  {'disc_loss': 0.05004991, 'gen_loss': 0.58174008, 'valid': 0.83},
#  {'disc_loss': 0.07767218, 'gen_loss': 0.5575853, 'valid': 0.72},
#  {'disc_loss': 0.06084277, 'gen_loss': 0.14552024, 'valid': 0.69},
#  {'disc_loss': 0.05569494, 'gen_loss': -0.10502636, 'valid': 0.73},
#  {'disc_loss': 0.05817062, 'gen_loss': -0.42778265, 'valid': 0.76},
#  {'disc_loss': 0.04789224, 'gen_loss': -0.0906307, 'valid': 0.64},
#  {'disc_loss': 0.06280854, 'gen_loss': -0.44581628, 'valid': 0.71},
#  {'disc_loss': 0.05404254, 'gen_loss': -0.16145465, 'valid': 0.75},
#  {'disc_loss': 0.06972048, 'gen_loss': 0.10252636, 'valid': 0.8},
#  {'disc_loss': 0.08430037, 'gen_loss': -0.47246811, 'valid': 0.72},
#  {'disc_loss': 0.03886186, 'gen_loss': -0.52538973, 'valid': 0.7},
#  {'disc_loss': 0.04138856, 'gen_loss': 0.2624208, 'valid': 0.81},
#  {'disc_loss': 0.045098, 'gen_loss': -0.13584578, 'valid': 0.88},
#  {'disc_loss': 0.06526557, 'gen_loss': 0.65069765, 'valid': 0.6},
#  {'disc_loss': 0.04185772, 'gen_loss': -0.05743527, 'valid': 0.65},
#  {'disc_loss': 0.018777, 'gen_loss': -0.42023757, 'valid': 0.82},
#  {'disc_loss': 0.04114527, 'gen_loss': -0.55189246, 'valid': 0.77},
#  {'disc_loss': 0.06952624, 'gen_loss': -0.20829211, 'valid': 0.82},
#  {'disc_loss': 0.02993456, 'gen_loss': -0.09112298, 'valid': 0.68},
#  {'disc_loss': 0.09828004, 'gen_loss': 0.53532821, 'valid': 0.84},
#  {'disc_loss': 0.02438367, 'gen_loss': -0.391752, 'valid': 0.65},
#  {'disc_loss': 0.04242459, 'gen_loss': 0.13077506, 'valid': 0.72},
#  {'disc_loss': 0.04544836, 'gen_loss': -0.13338575, 'valid': 0.7},
#  {'disc_loss': 0.05816822, 'gen_loss': 0.48667493, 'valid': 0.75},
#  {'disc_loss': 0.02076347, 'gen_loss': -0.18378715, 'valid': 0.72},
#  {'disc_loss': 0.02928173, 'gen_loss': -0.02385981, 'valid': 0.78},
#  {'disc_loss': 0.0491844, 'gen_loss': -0.02489564, 'valid': 0.84},
#  {'disc_loss': 0.03097085, 'gen_loss': -0.30369398, 'valid': 0.7},
#  {'disc_loss': 0.04023119, 'gen_loss': -0.34284103, 'valid': 0.76},
#  {'disc_loss': 0.08670183, 'gen_loss': 0.17474969, 'valid': 0.86},
#  {'disc_loss': 0.07616632, 'gen_loss': -0.10355873, 'valid': 0.72},
#  {'disc_loss': 0.07363255, 'gen_loss': -0.60169953, 'valid': 0.8},
#  {'disc_loss': 0.06676319, 'gen_loss': -0.55906427, 'valid': 0.84},
#  {'disc_loss': 0.11562567, 'gen_loss': 0.1111953, 'valid': 0.82},
#  {'disc_loss': 0.06681933, 'gen_loss': -0.15859206, 'valid': 0.75},
#  {'disc_loss': 0.08161724, 'gen_loss': -0.55734396, 'valid': 0.68},
#  {'disc_loss': 0.02614108, 'gen_loss': -0.24894723, 'valid': 0.73},
#  {'disc_loss': 0.07313202, 'gen_loss': 0.11129533, 'valid': 0.75},
#  {'disc_loss': 0.03349786, 'gen_loss': -0.60885632, 'valid': 0.84},
#  {'disc_loss': 0.03353828, 'gen_loss': 0.0277701, 'valid': 0.66},
#  {'disc_loss': 0.02939504, 'gen_loss': -0.50928313, 'valid': 0.81},
#  {'disc_loss': 0.05504983, 'gen_loss': -0.37159178, 'valid': 0.83},
#  {'disc_loss': 0.03324924, 'gen_loss': -0.12334976, 'valid': 0.89},
#  {'disc_loss': 0.07282577, 'gen_loss': -0.81227249, 'valid': 0.74},
#  {'disc_loss': 0.05713993, 'gen_loss': -0.18094771, 'valid': 0.7},
#  {'disc_loss': 0.04568, 'gen_loss': -0.06850501, 'valid': 0.68},
#  {'disc_loss': 0.0391922, 'gen_loss': -0.40074438, 'valid': 0.72},
#  {'disc_loss': 0.06399493, 'gen_loss': 0.19279484, 'valid': 0.77},
#  {'disc_loss': 0.02493526, 'gen_loss': -0.15281248, 'valid': 0.84},
#  {'disc_loss': 0.03151638, 'gen_loss': -0.31176847, 'valid': 0.87},
#  {'disc_loss': 0.02691405, 'gen_loss': -0.03889081, 'valid': 0.81},
#  {'disc_loss': 0.03208417, 'gen_loss': 0.06482423, 'valid': 0.81},
#  {'disc_loss': 0.03111593, 'gen_loss': -0.01796155, 'valid': 0.87},
#  {'disc_loss': 0.03680725, 'gen_loss': 0.13287759, 'valid': 0.82},
#  {'disc_loss': 0.06703934, 'gen_loss': -0.23293084, 'valid': 0.77},
#  {'disc_loss': 0.09987578, 'gen_loss': -0.39428172, 'valid': 0.78},
#  {'disc_loss': 0.04978755, 'gen_loss': -0.10598152, 'valid': 0.7},
#  {'disc_loss': 0.07371939, 'gen_loss': 0.63281673, 'valid': 0.77},
#  {'disc_loss': 0.07043447, 'gen_loss': 0.44888458, 'valid': 0.74},
#  {'disc_loss': 0.06348433, 'gen_loss': -0.51697868, 'valid': 0.87},
#  {'disc_loss': 0.02598057, 'gen_loss': -0.28967261, 'valid': 0.91},
#  {'disc_loss': 0.04803988, 'gen_loss': 0.56856459, 'valid': 0.74},
#  {'disc_loss': 0.04139719, 'gen_loss': -0.47631615, 'valid': 0.65},
#  {'disc_loss': 0.03483171, 'gen_loss': -0.10394612, 'valid': 0.81},
#  {'disc_loss': 0.01305955, 'gen_loss': -0.35672766, 'valid': 0.91},
#  {'disc_loss': 0.06076356, 'gen_loss': 0.22766601, 'valid': 0.81},
#  {'disc_loss': 0.048626, 'gen_loss': -0.40943548, 'valid': 0.9},
#  {'disc_loss': 0.03565093, 'gen_loss': -0.22183432, 'valid': 0.76},
#  {'disc_loss': 0.04856363, 'gen_loss': 0.00034008, 'valid': 0.66},
#  {'disc_loss': 0.06225225, 'gen_loss': -0.0751967, 'valid': 0.67},
#  {'disc_loss': 0.03397624, 'gen_loss': -0.23116183, 'valid': 0.89},
#  {'disc_loss': 0.04656546, 'gen_loss': 0.1299244, 'valid': 0.84},
#  {'disc_loss': 0.04592608, 'gen_loss': 0.45459601, 'valid': 0.86},
#  {'disc_loss': 0.02464691, 'gen_loss': -0.22130229, 'valid': 0.76},
#  {'disc_loss': 0.02524983, 'gen_loss': -0.04440461, 'valid': 0.86},
#  {'disc_loss': 0.03165115, 'gen_loss': 0.16441998, 'valid': 0.76},
#  {'disc_loss': 0.04327555, 'gen_loss': -0.34351769, 'valid': 0.87},
#  {'disc_loss': 0.03745469, 'gen_loss': 0.31310549, 'valid': 0.93},
#  {'disc_loss': 0.08996036, 'gen_loss': -0.41119039, 'valid': 0.87},
#  {'disc_loss': 0.03792867, 'gen_loss': 0.2832351, 'valid': 0.86},
#  {'disc_loss': 0.04409236, 'gen_loss': -0.24684563, 'valid': 0.89},
#  {'disc_loss': 0.0348809, 'gen_loss': -0.04465594, 'valid': 0.8},
#  {'disc_loss': 0.035021, 'gen_loss': 0.227152, 'valid': 0.86},
#  {'disc_loss': 0.05874636, 'gen_loss': -0.46397752, 'valid': 0.82},
#  {'disc_loss': 0.04527696, 'gen_loss': -0.15225819, 'valid': 0.86},
#  {'disc_loss': 0.02529493, 'gen_loss': 0.08228564, 'valid': 0.65},
#  {'disc_loss': 0.03436421, 'gen_loss': -0.59390527, 'valid': 0.9},
#  {'disc_loss': 0.08697909, 'gen_loss': 0.87880272, 'valid': 0.69},
#  {'disc_loss': 0.03660001, 'gen_loss': 0.2290037, 'valid': 0.91},
#  {'disc_loss': 0.06074987, 'gen_loss': 0.58430099, 'valid': 0.7},
#  {'disc_loss': 0.05321737, 'gen_loss': 0.20568299, 'valid': 0.86},
#  {'disc_loss': 0.05488923, 'gen_loss': -0.30228478, 'valid': 0.81},
#  {'disc_loss': 0.04878652, 'gen_loss': -0.00295991, 'valid': 0.73},
#  {'disc_loss': 0.0476312, 'gen_loss': 0.11677413, 'valid': 0.81},
#  {'disc_loss': 0.0289984, 'gen_loss': -0.64821273, 'valid': 0.93},
#  {'disc_loss': 0.0630413, 'gen_loss': -0.27017733, 'valid': 0.93},
#  {'disc_loss': 0.04558556, 'gen_loss': 0.14256595, 'valid': 0.87},
#  {'disc_loss': 0.04895049, 'gen_loss': -0.14067665, 'valid': 0.73},
#  {'disc_loss': 0.0646445, 'gen_loss': 0.24134926, 'valid': 0.78},
#  {'disc_loss': 0.07317516, 'gen_loss': -0.36437821, 'valid': 0.85},
#  {'disc_loss': 0.04108598, 'gen_loss': 0.24475873, 'valid': 0.85},
#  {'disc_loss': 0.03996359, 'gen_loss': 0.02139969, 'valid': 0.86},
#  {'disc_loss': 0.06409194, 'gen_loss': -0.4457776, 'valid': 0.78},
#  {'disc_loss': 0.0207899, 'gen_loss': -0.44746393, 'valid': 0.84},
#  {'disc_loss': 0.05720554, 'gen_loss': 0.27720514, 'valid': 0.73},
#  {'disc_loss': 0.04557819, 'gen_loss': 0.304712, 'valid': 0.48},
#  {'disc_loss': 0.06165089, 'gen_loss': -0.01713529, 'valid': 0.75},
#  {'disc_loss': 0.02592054, 'gen_loss': -0.16533424, 'valid': 0.74},
#  {'disc_loss': 0.03037011, 'gen_loss': 0.22858503, 'valid': 0.51},
#  {'disc_loss': 0.06332864, 'gen_loss': 0.13701859, 'valid': 0.89},
#  {'disc_loss': 0.02209641, 'gen_loss': -0.15889978, 'valid': 0.76},
#  {'disc_loss': 0.06413548, 'gen_loss': 0.07262421, 'valid': 0.69},
#  {'disc_loss': 0.05478736, 'gen_loss': -0.44082224, 'valid': 0.63},
#  {'disc_loss': 0.03529408, 'gen_loss': -0.24484634, 'valid': 0.71},
#  {'disc_loss': 0.04566442, 'gen_loss': -0.25443056, 'valid': 0.69},
#  {'disc_loss': 0.04878019, 'gen_loss': 0.2408493, 'valid': 0.7},
#  {'disc_loss': 0.08363787, 'gen_loss': 0.59717923, 'valid': 0.69},
#  {'disc_loss': 0.06993701, 'gen_loss': 0.61866307, 'valid': 0.76},
#  {'disc_loss': 0.03547966, 'gen_loss': 0.17427096, 'valid': 0.73},
#  {'disc_loss': 0.07007816, 'gen_loss': -0.06148441, 'valid': 0.83},
#  {'disc_loss': 0.04857757, 'gen_loss': -0.28076717, 'valid': 0.85},
#  {'disc_loss': 0.07187875, 'gen_loss': 0.36217162, 'valid': 0.77},
#  {'disc_loss': 0.04597104, 'gen_loss': 0.37618476, 'valid': 0.88},
#  {'disc_loss': 0.08245832, 'gen_loss': 0.13583559, 'valid': 0.85},
#  {'disc_loss': 0.07343476, 'gen_loss': 0.53510517, 'valid': 0.78},
#  {'disc_loss': 0.03979353, 'gen_loss': 0.16665258, 'valid': 0.79},
#  {'disc_loss': 0.0161665, 'gen_loss': -0.33968884, 'valid': 0.8},
#  {'disc_loss': 0.03681523, 'gen_loss': 0.31288424, 'valid': 0.85},
#  {'disc_loss': 0.03357053, 'gen_loss': -0.13544798, 'valid': 0.73},
#  {'disc_loss': 0.07336486, 'gen_loss': 0.01283304, 'valid': 0.86},
#  {'disc_loss': 0.06358235, 'gen_loss': 0.31785434, 'valid': 0.79},
#  {'disc_loss': 0.03675102, 'gen_loss': 0.31222776, 'valid': 0.8},
#  {'disc_loss': 0.04915889, 'gen_loss': -0.30005565, 'valid': 0.87},
#  {'disc_loss': 0.03676765, 'gen_loss': -0.14527912, 'valid': 0.81},
#  {'disc_loss': 0.03250641, 'gen_loss': -0.20030031, 'valid': 0.61},
#  {'disc_loss': 0.04384211, 'gen_loss': 0.16374648, 'valid': 0.76},
#  {'disc_loss': 0.06267583, 'gen_loss': 0.13146281, 'valid': 0.71},
#  {'disc_loss': 0.03765927, 'gen_loss': -0.09720082, 'valid': 0.82},
#  {'disc_loss': 0.05488274, 'gen_loss': 0.10751225, 'valid': 0.78},
#  {'disc_loss': 0.07445303, 'gen_loss': 0.81843716, 'valid': 0.77},
#  {'disc_loss': 0.04179458, 'gen_loss': -0.29568869, 'valid': 0.9},
#  {'disc_loss': 0.05033635, 'gen_loss': -0.25704244, 'valid': 0.78},
#  {'disc_loss': 0.03421524, 'gen_loss': -0.38875821, 'valid': 0.8},
#  {'disc_loss': 0.04342302, 'gen_loss': -0.08388312, 'valid': 0.83},
#  {'disc_loss': 0.02310753, 'gen_loss': -0.33257493, 'valid': 0.67},
#  {'disc_loss': 0.02027568, 'gen_loss': -0.46598798, 'valid': 0.83},
#  {'disc_loss': 0.05609224, 'gen_loss': -0.41543669, 'valid': 0.67},
#  {'disc_loss': 0.02982653, 'gen_loss': 0.24041478, 'valid': 0.83},
#  {'disc_loss': 0.05586985, 'gen_loss': -0.03514374, 'valid': 0.87},
#  {'disc_loss': 0.05637744, 'gen_loss': 0.10106838, 'valid': 0.7},
#  {'disc_loss': 0.04582613, 'gen_loss': 0.31311119, 'valid': 0.93},
#  {'disc_loss': 0.05175523, 'gen_loss': -0.14099869, 'valid': 0.88},
#  {'disc_loss': 0.04164482, 'gen_loss': 0.37753898, 'valid': 0.82},
#  {'disc_loss': 0.04867204, 'gen_loss': 0.44290271, 'valid': 0.79},
#  {'disc_loss': 0.04646309, 'gen_loss': -0.00712972, 'valid': 0.74},
#  {'disc_loss': 0.06153015, 'gen_loss': 1.02457523, 'valid': 0.82},
#  {'disc_loss': 0.09298717, 'gen_loss': 1.26948905, 'valid': 0.68},
#  {'disc_loss': 0.04081146, 'gen_loss': 0.05598099, 'valid': 0.85},
#  {'disc_loss': 0.01779704, 'gen_loss': -0.06451706, 'valid': 0.79},
#  {'disc_loss': 0.03206735, 'gen_loss': 0.33441299, 'valid': 0.8},
#  {'disc_loss': 0.01619853, 'gen_loss': -0.16018286, 'valid': 0.83},
#  {'disc_loss': 0.0417593, 'gen_loss': -0.26365924, 'valid': 0.81},
#  {'disc_loss': 0.03824503, 'gen_loss': -0.37039754, 'valid': 0.81},
#  {'disc_loss': 0.0298654, 'gen_loss': -0.24826264, 'valid': 0.81},
#  {'disc_loss': 0.04778686, 'gen_loss': -0.04438846, 'valid': 0.87},
#  {'disc_loss': 0.0544432, 'gen_loss': 0.19943933, 'valid': 0.93},
#  {'disc_loss': 0.04769734, 'gen_loss': -0.40719217, 'valid': 0.76},
#  {'disc_loss': 0.03142858, 'gen_loss': -0.14685383, 'valid': 0.92},
#  {'disc_loss': 0.05742024, 'gen_loss': 0.72293532, 'valid': 0.83},
#  {'disc_loss': 0.044403, 'gen_loss': -0.35974616, 'valid': 0.81},
#  {'disc_loss': 0.05658135, 'gen_loss': 0.52258283, 'valid': 0.78},
#  {'disc_loss': 0.07414994, 'gen_loss': 0.69621205, 'valid': 0.91},
#  {'disc_loss': 0.02603349, 'gen_loss': -0.17376813, 'valid': 0.78},
#  {'disc_loss': 0.0606042, 'gen_loss': 0.40050653, 'valid': 0.87},
#  {'disc_loss': 0.04378491, 'gen_loss': -0.39691046, 'valid': 0.87},
#  {'disc_loss': 0.05250452, 'gen_loss': 0.19554369, 'valid': 0.63},
#  {'disc_loss': 0.02172695, 'gen_loss': -0.30028829, 'valid': 0.76},
#  {'disc_loss': 0.08429602, 'gen_loss': 0.2143106, 'valid': 0.83},
#  {'disc_loss': 0.06920759, 'gen_loss': -0.27607831, 'valid': 0.87},
#  {'disc_loss': 0.07627896, 'gen_loss': -0.47733507, 'valid': 0.87},
#  {'disc_loss': 0.03393682, 'gen_loss': -0.27725348, 'valid': 0.84},
#  {'disc_loss': 0.04098216, 'gen_loss': -0.29933158, 'valid': 0.76},
#  {'disc_loss': 0.06969018, 'gen_loss': 0.15926698, 'valid': 0.83},
#  {'disc_loss': 0.04618733, 'gen_loss': -0.02781902, 'valid': 0.87},
#  {'disc_loss': 0.04656318, 'gen_loss': 0.37681869, 'valid': 0.85},
#  {'disc_loss': 0.02644826, 'gen_loss': 0.04008526, 'valid': 0.81},
#  {'disc_loss': 0.06394592, 'gen_loss': -0.04038114, 'valid': 0.85},
#  {'disc_loss': 0.06261173, 'gen_loss': -0.04281815, 'valid': 0.85},
#  {'disc_loss': 0.0787595, 'gen_loss': -0.19355831, 'valid': 0.79},
#  {'disc_loss': 0.04387596, 'gen_loss': 0.07941359, 'valid': 0.83},
#  {'disc_loss': 0.03530293, 'gen_loss': 0.61094189, 'valid': 0.83},
#  {'disc_loss': 0.04075898, 'gen_loss': -0.43131846, 'valid': 0.82},
#  {'disc_loss': 0.06244047, 'gen_loss': 0.46579194, 'valid': 0.96},
#  {'disc_loss': 0.04512572, 'gen_loss': -0.22116053, 'valid': 0.82},
#  {'disc_loss': 0.03740053, 'gen_loss': -0.00868254, 'valid': 0.84},
#  {'disc_loss': 0.05043986, 'gen_loss': 0.1389316, 'valid': 0.83},
#  {'disc_loss': 0.03814036, 'gen_loss': 0.0062112, 'valid': 0.85},
#  {'disc_loss': 0.03098531, 'gen_loss': 0.2491442, 'valid': 0.84},
#  {'disc_loss': 0.05402625, 'gen_loss': 0.23774023, 'valid': 0.76},
#  {'disc_loss': 0.02843204, 'gen_loss': 0.02850134, 'valid': 0.95},
#  {'disc_loss': 0.07594673, 'gen_loss': 0.5723182, 'valid': 0.89},
#  {'disc_loss': 0.05457852, 'gen_loss': -0.05351432, 'valid': 0.92},
#  {'disc_loss': 0.03832889, 'gen_loss': 0.0767872, 'valid': 0.85},
#  {'disc_loss': 0.0619728, 'gen_loss': -0.13515227, 'valid': 0.94},
#  {'disc_loss': 0.04694843, 'gen_loss': 0.56702667, 'valid': 0.75},
#  {'disc_loss': 0.0327853, 'gen_loss': -0.32602146, 'valid': 0.79},
#  {'disc_loss': 0.04364444, 'gen_loss': -0.12470924, 'valid': 0.77},
#  {'disc_loss': 0.05545118, 'gen_loss': 0.099726, 'valid': 0.81},
#  {'disc_loss': 0.05597493, 'gen_loss': 0.32761851, 'valid': 0.86},
#  {'disc_loss': 0.0389546, 'gen_loss': -0.3303844, 'valid': 0.64},
#  {'disc_loss': 0.0216079, 'gen_loss': -0.476971, 'valid': 0.68},
#  {'disc_loss': 0.0447166, 'gen_loss': 0.19348195, 'valid': 0.98},
#  {'disc_loss': 0.04796499, 'gen_loss': 0.00552889, 'valid': 0.89},
#  {'disc_loss': 0.04982227, 'gen_loss': -0.30969048, 'valid': 0.77},
#  {'disc_loss': 0.04131776, 'gen_loss': 0.02864865, 'valid': 0.95},
#  {'disc_loss': 0.0441286, 'gen_loss': 0.22761108, 'valid': 0.86},
# ...
#  {'disc_loss': 0.05060589, 'gen_loss': -0.10207517, 'valid': 0.87},
#  {'disc_loss': 0.04073234, 'gen_loss': -0.3450751, 'valid': 0.92},
#  {'disc_loss': 0.05217075, 'gen_loss': -0.17399471, 'valid': 0.7},
#  {'disc_loss': 0.06545487, 'gen_loss': -0.21611065, 'valid': 0.75},
#  {'disc_loss': 0.08153872, 'gen_loss': -0.01315507, 'valid': 0.91},
#  {'disc_loss': 0.03290415, 'gen_loss': -0.25165287, 'valid': 0.76},
#  {'disc_loss': 0.04687292, 'gen_loss': 0.03766343, 'valid': 0.85},
#  {'disc_loss': 0.06821021, 'gen_loss': -0.09818288, 'valid': 0.83},
#  {'disc_loss': 0.09395929, 'gen_loss': 0.06246234, 'valid': 0.87},
#  {'disc_loss': 0.04709217, 'gen_loss': -0.3150242, 'valid': 0.86},
#  {'disc_loss': 0.06052266, 'gen_loss': 0.0820047, 'valid': 0.86},
#  {'disc_loss': 0.0302266, 'gen_loss': 0.0017732, 'valid': 0.87},
#  {'disc_loss': 0.0399121, 'gen_loss': 0.01966037, 'valid': 0.85},
#  {'disc_loss': 0.06140811, 'gen_loss': 0.13792022, 'valid': 0.65},
#  {'disc_loss': 0.03010155, 'gen_loss': -0.04344839, 'valid': 0.93},
#  {'disc_loss': 0.08584073, 'gen_loss': 0.62154311, 'valid': 0.84},
#  {'disc_loss': 0.03949001, 'gen_loss': -0.10744075, 'valid': 0.84},
#  {'disc_loss': 0.06051891, 'gen_loss': 0.33922213, 'valid': 0.9},
#  {'disc_loss': 0.03387172, 'gen_loss': 0.12604791, 'valid': 0.84},
#  {'disc_loss': 0.07494116, 'gen_loss': 0.06090234, 'valid': 0.76},
#  {'disc_loss': 0.0445413, 'gen_loss': 0.39086482, 'valid': 0.77},
#  {'disc_loss': 0.03244567, 'gen_loss': -0.23559567, 'valid': 0.6},
#  {'disc_loss': 0.05721363, 'gen_loss': -0.28447971, 'valid': 0.88},
#  {'disc_loss': 0.03399734, 'gen_loss': -0.25219652, 'valid': 0.78},
#  {'disc_loss': 0.02459512, 'gen_loss': -0.01473859, 'valid': 0.81},
#  {'disc_loss': 0.04896666, 'gen_loss': 0.1525919, 'valid': 0.86},
#  {'disc_loss': 0.09321249, 'gen_loss': 0.17878191, 'valid': 0.94},
#  {'disc_loss': 0.0377176, 'gen_loss': 0.0891796, 'valid': 0.83},
#  {'disc_loss': 0.03525116, 'gen_loss': 0.12714534, 'valid': 0.74},
#  {'disc_loss': 0.03231404, 'gen_loss': 0.0974006, 'valid': 0.72},
#  {'disc_loss': 0.04358881, 'gen_loss': -0.14360033, 'valid': 0.81},
#  {'disc_loss': 0.03874376, 'gen_loss': 0.23305219, 'valid': 0.79},
#  {'disc_loss': 0.0525379, 'gen_loss': -0.06146012, 'valid': 0.89},
#  {'disc_loss': 0.04197459, 'gen_loss': -0.12031605, 'valid': 0.81},
#  {'disc_loss': 0.0377451, 'gen_loss': 0.23071519, 'valid': 0.64},
#  {'disc_loss': 0.02954975, 'gen_loss': -0.24043982, 'valid': 0.82},
#  {'disc_loss': 0.06643455, 'gen_loss': 0.38016659, 'valid': 0.87},
#  {'disc_loss': 0.04004057, 'gen_loss': -0.0811678, 'valid': 0.77},
#  {'disc_loss': 0.03879917, 'gen_loss': 0.05373611, 'valid': 0.8},
#  {'disc_loss': 0.02794091, 'gen_loss': 0.14716041, 'valid': 0.8},
#  {'disc_loss': 0.02867822, 'gen_loss': -0.07952171, 'valid': 0.56},
#  {'disc_loss': 0.08753615, 'gen_loss': 0.71098471, 'valid': 0.79},
#  {'disc_loss': 0.06315487, 'gen_loss': -0.37045521, 'valid': 0.8},
#  {'disc_loss': 0.05683513, 'gen_loss': 0.30079666, 'valid': 0.88},
#  {'disc_loss': 0.06534296, 'gen_loss': 0.026581, 'valid': 0.83},
#  {'disc_loss': 0.06748718, 'gen_loss': 0.29726791, 'valid': 0.83},
#  {'disc_loss': 0.03697688, 'gen_loss': -0.36901554, 'valid': 0.82},
#  {'disc_loss': 0.04688423, 'gen_loss': 0.16785711, 'valid': 0.88},
#  {'disc_loss': 0.06118659, 'gen_loss': 0.44420728, 'valid': 0.87},
#  {'disc_loss': 0.05812748, 'gen_loss': -0.53895897, 'valid': 0.81},
#  {'disc_loss': 0.07757492, 'gen_loss': 0.39412302, 'valid': 0.84},
#  {'disc_loss': 0.0351941, 'gen_loss': -0.17858873, 'valid': 0.74},
#  {'disc_loss': 0.09345335, 'gen_loss': 0.13661925, 'valid': 0.9},
#  {'disc_loss': 0.02702232, 'gen_loss': -0.24901778, 'valid': 0.84},
#  {'disc_loss': 0.0437631, 'gen_loss': -0.38064066, 'valid': 0.87},
#  {'disc_loss': 0.0192676, 'gen_loss': 0.00405068, 'valid': 0.87},
#  {'disc_loss': 0.06354757, 'gen_loss': 0.14871077, 'valid': 0.84},
#  {'disc_loss': 0.05975053, 'gen_loss': 0.65492618, 'valid': 0.88},
#  {'disc_loss': 0.01005415, 'gen_loss': -0.2215485, 'valid': 0.83},
#  {'disc_loss': 0.03914815, 'gen_loss': -0.04693731, 'valid': 0.77},
#  {'disc_loss': 0.13465169, 'gen_loss': 0.62360436, 'valid': 0.73},
#  {'disc_loss': 0.03719515, 'gen_loss': -0.30604061, 'valid': 0.8},
#  {'disc_loss': 0.07996234, 'gen_loss': 0.05682188, 'valid': 0.86},
#  {'disc_loss': 0.04911145, 'gen_loss': -0.45585406, 'valid': 0.76},
#  {'disc_loss': 0.16644314, 'gen_loss': 0.51924002, 'valid': 0.88},
#  {'disc_loss': 0.04517431, 'gen_loss': 0.11925329, 'valid': 0.77},
#  {'disc_loss': 0.01650077, 'gen_loss': -0.2671124, 'valid': 0.84},
#  {'disc_loss': 0.03820093, 'gen_loss': 0.16854605, 'valid': 0.8},
#  {'disc_loss': 0.02103614, 'gen_loss': -0.16684939, 'valid': 0.84},
#  {'disc_loss': 0.02558987, 'gen_loss': -0.16101986, 'valid': 0.91},
#  {'disc_loss': 0.01942323, 'gen_loss': 0.06485908, 'valid': 0.89},
#  {'disc_loss': 0.08894338, 'gen_loss': 0.35238758, 'valid': 0.92},
#  {'disc_loss': 0.05371049, 'gen_loss': 0.21575661, 'valid': 0.91},
#  {'disc_loss': 0.06381606, 'gen_loss': -0.15489356, 'valid': 0.89},
#  {'disc_loss': 0.04019438, 'gen_loss': -0.16307817, 'valid': 0.83},
#  {'disc_loss': 0.02950429, 'gen_loss': -0.14092055, 'valid': 0.86},
#  {'disc_loss': 0.04443438, 'gen_loss': 0.18850861, 'valid': 0.83},
#  {'disc_loss': 0.02040166, 'gen_loss': -0.17026916, 'valid': 0.86},
#  {'disc_loss': 0.04362737, 'gen_loss': -0.17194802, 'valid': 0.87},
#  {'disc_loss': 0.05210452, 'gen_loss': -0.14470421, 'valid': 0.9},
#  {'disc_loss': 0.05350466, 'gen_loss': 0.36568555, 'valid': 0.8},
#  {'disc_loss': 0.0488026, 'gen_loss': 0.26964027, 'valid': 0.95},
#  {'disc_loss': 0.03901567, 'gen_loss': 0.06985949, 'valid': 0.81},
#  {'disc_loss': 0.04295567, 'gen_loss': -0.01458451, 'valid': 0.87},
#  {'disc_loss': 0.10165535, 'gen_loss': 0.77353299, 'valid': 0.81},
#  {'disc_loss': 0.03694518, 'gen_loss': -0.08587538, 'valid': 0.88},
#  {'disc_loss': 0.0366736, 'gen_loss': 0.05010942, 'valid': 0.88},
#  {'disc_loss': 0.04288227, 'gen_loss': 0.22075915, 'valid': 0.75},
#  {'disc_loss': 0.02200602, 'gen_loss': 0.04233179, 'valid': 0.93},
#  {'disc_loss': 0.06843647, 'gen_loss': -0.2685385, 'valid': 0.85},
#  {'disc_loss': 0.0618905, 'gen_loss': 0.31253165, 'valid': 0.83},
#  {'disc_loss': 0.03780594, 'gen_loss': -0.09011096, 'valid': 0.93},
#  {'disc_loss': 0.1248687, 'gen_loss': -0.22109589, 'valid': 0.76},
#  {'disc_loss': 0.02801982, 'gen_loss': -0.0579158, 'valid': 0.75},
#  {'disc_loss': 0.0393666, 'gen_loss': -0.2098978, 'valid': 0.93},
#  {'disc_loss': 0.04281726, 'gen_loss': -0.26723358, 'valid': 0.87},
#  {'disc_loss': 0.03307016, 'gen_loss': -0.18407036, 'valid': 0.89},
#  {'disc_loss': 0.05123695, 'gen_loss': 0.4965978, 'valid': 0.85},
#  {'disc_loss': 0.09250557, 'gen_loss': 0.29650971, 'valid': 0.92},
#  {'disc_loss': 0.06003309, 'gen_loss': 0.30594346, 'valid': 0.84},
#  {'disc_loss': 0.04064131, 'gen_loss': 0.34197262, 'valid': 0.91},
#  {'disc_loss': 0.03879917, 'gen_loss': 0.11436483, 'valid': 0.9},
#  {'disc_loss': 0.08535139, 'gen_loss': -0.24413712, 'valid': 0.81},
#  {'disc_loss': 0.05596037, 'gen_loss': 0.31852493, 'valid': 0.8},
#  {'disc_loss': 0.02275066, 'gen_loss': -0.38765195, 'valid': 0.86},
#  {'disc_loss': 0.06247794, 'gen_loss': 0.35790566, 'valid': 0.87},
#  {'disc_loss': 0.05785317, 'gen_loss': 0.35534608, 'valid': 0.83},
#  {'disc_loss': 0.05184918, 'gen_loss': -0.27749804, 'valid': 0.79},
#  {'disc_loss': 0.04107985, 'gen_loss': -0.23852329, 'valid': 0.7},
#  {'disc_loss': 0.04113382, 'gen_loss': -0.29167143, 'valid': 0.83},
#  {'disc_loss': 0.02895793, 'gen_loss': 0.13741754, 'valid': 0.78},
#  {'disc_loss': 0.03699566, 'gen_loss': -0.14902237, 'valid': 0.89},
#  {'disc_loss': 0.05868755, 'gen_loss': -0.19663635, 'valid': 0.91},
#  {'disc_loss': 0.04184123, 'gen_loss': 0.20828187, 'valid': 0.75},
#  {'disc_loss': 0.02311637, 'gen_loss': -0.10186888, 'valid': 0.92},
#  {'disc_loss': 0.02776255, 'gen_loss': 0.07514498, 'valid': 0.64},
#  {'disc_loss': 0.0421149, 'gen_loss': 0.1188444, 'valid': 0.87},
#  {'disc_loss': 0.04582287, 'gen_loss': 0.0021256, 'valid': 0.89},
#  {'disc_loss': 0.08144545, 'gen_loss': -0.38519436, 'valid': 0.94},
#  {'disc_loss': 0.01596292, 'gen_loss': 0.04015748, 'valid': 0.87},
#  {'disc_loss': 0.04088327, 'gen_loss': -0.4296822, 'valid': 0.86},
#  {'disc_loss': 0.0179248, 'gen_loss': -0.33425885, 'valid': 0.75},
#  {'disc_loss': 0.05951698, 'gen_loss': 0.48599663, 'valid': 0.89},
#  {'disc_loss': 0.05766028, 'gen_loss': -0.46234173, 'valid': 0.88},
#  {'disc_loss': 0.04663336, 'gen_loss': -0.41540825, 'valid': 0.91},
#  {'disc_loss': 0.03074271, 'gen_loss': -0.25415891, 'valid': 0.85},
#  {'disc_loss': 0.03818723, 'gen_loss': 0.1932957, 'valid': 0.84},
#  {'disc_loss': 0.08560656, 'gen_loss': 0.25582123, 'valid': 0.88},
#  {'disc_loss': 0.02625161, 'gen_loss': -0.22889607, 'valid': 0.88},
#  {'disc_loss': 0.05745634, 'gen_loss': 0.53749961, 'valid': 0.77},
#  {'disc_loss': 0.03372322, 'gen_loss': 0.2289207, 'valid': 0.82},
#  {'disc_loss': 0.05629468, 'gen_loss': -0.08056154, 'valid': 0.89},
#  {'disc_loss': 0.03381718, 'gen_loss': 0.3109543, 'valid': 0.82},
#  {'disc_loss': 0.04039673, 'gen_loss': 0.05161519, 'valid': 0.9},
#  {'disc_loss': 0.05385594, 'gen_loss': -0.09978975, 'valid': 0.84},
#  {'disc_loss': 0.05301827, 'gen_loss': 0.23761877, 'valid': 0.88},
#  {'disc_loss': 0.04908887, 'gen_loss': -0.14615628, 'valid': 0.92},
#  {'disc_loss': 0.02341381, 'gen_loss': 0.11182562, 'valid': 0.94},
#  {'disc_loss': 0.03787297, 'gen_loss': -0.10990064, 'valid': 0.87},
#  {'disc_loss': 0.03315788, 'gen_loss': -0.07907157, 'valid': 0.89},
#  {'disc_loss': 0.03656884, 'gen_loss': 0.18349272, 'valid': 0.87},
#  {'disc_loss': 0.03499889, 'gen_loss': 0.13714726, 'valid': 0.83},
#  {'disc_loss': 0.02882051, 'gen_loss': 0.00261225, 'valid': 0.75},
#  {'disc_loss': 0.02773861, 'gen_loss': -0.15078892, 'valid': 0.78},
#  {'disc_loss': 0.04482729, 'gen_loss': 0.13824682, 'valid': 0.85},
#  {'disc_loss': 0.02064015, 'gen_loss': -0.17198908, 'valid': 0.83},
#  {'disc_loss': 0.06654905, 'gen_loss': 0.22950827, 'valid': 0.75},
#  {'disc_loss': 0.03370528, 'gen_loss': -0.19571613, 'valid': 0.85},
#  {'disc_loss': 0.04267147, 'gen_loss': 0.35698569, 'valid': 0.88},
#  {'disc_loss': 0.06399146, 'gen_loss': 0.2596789, 'valid': 0.87},
#  {'disc_loss': 0.03393135, 'gen_loss': -0.17590992, 'valid': 0.89},
#  {'disc_loss': 0.02725453, 'gen_loss': -0.21345674, 'valid': 0.87},
#  {'disc_loss': 0.03282654, 'gen_loss': 0.01284667, 'valid': 0.88},
#  {'disc_loss': 0.08851758, 'gen_loss': 0.42605397, 'valid': 0.68},
#  {'disc_loss': 0.02478965, 'gen_loss': -0.10982038, 'valid': 0.84},
#  {'disc_loss': 0.02780187, 'gen_loss': -0.02780509, 'valid': 0.91},
#  {'disc_loss': 0.03638038, 'gen_loss': -0.09015263, 'valid': 0.64},
#  {'disc_loss': 0.05607076, 'gen_loss': -0.09995672, 'valid': 0.84},
#  {'disc_loss': 0.05350071, 'gen_loss': 0.48116368, 'valid': 0.9},
#  {'disc_loss': 0.03065245, 'gen_loss': -0.30946884, 'valid': 0.62},
#  {'disc_loss': 0.0427806, 'gen_loss': -0.1115775, 'valid': 0.94},
#  {'disc_loss': 0.09163073, 'gen_loss': -0.02333789, 'valid': 0.86},
#  {'disc_loss': 0.06531586, 'gen_loss': -0.12352616, 'valid': 0.81},
#  {'disc_loss': 0.04681795, 'gen_loss': 0.19976892, 'valid': 0.86},
#  {'disc_loss': 0.02701851, 'gen_loss': 0.1704662, 'valid': 0.88},
#  {'disc_loss': 0.03961121, 'gen_loss': -0.01640406, 'valid': 0.79},
#  {'disc_loss': 0.02101968, 'gen_loss': -0.32765639, 'valid': 0.85},
#  {'disc_loss': 0.02844476, 'gen_loss': 0.0892605, 'valid': 0.89},
#  {'disc_loss': 0.0144192, 'gen_loss': -0.16828613, 'valid': 0.8},
#  {'disc_loss': 0.02920692, 'gen_loss': -0.14730369, 'valid': 0.88},
#  {'disc_loss': 0.06403551, 'gen_loss': 0.20283374, 'valid': 0.83},
#  {'disc_loss': 0.07393776, 'gen_loss': -0.04298338, 'valid': 0.72},
#  {'disc_loss': 0.06666953, 'gen_loss': 0.0810219, 'valid': 0.92},
#  {'disc_loss': 0.06264253, 'gen_loss': -0.28063521, 'valid': 0.94},
#  {'disc_loss': 0.01585449, 'gen_loss': -0.23658428, 'valid': 0.89},
#  {'disc_loss': 0.06564716, 'gen_loss': 0.03205456, 'valid': 0.84},
#  {'disc_loss': 0.10622901, 'gen_loss': 0.46987665, 'valid': 0.88},
#  {'disc_loss': 0.09050097, 'gen_loss': 0.19116074, 'valid': 0.8},
#  {'disc_loss': 0.04175035, 'gen_loss': 0.09070391, 'valid': 0.79},
#  {'disc_loss': 0.04242535, 'gen_loss': -0.25143623, 'valid': 0.84},
#  {'disc_loss': 0.10408042, 'gen_loss': 0.19957405, 'valid': 0.91},
#  {'disc_loss': 0.01618281, 'gen_loss': -0.08053876, 'valid': 0.9},
#  {'disc_loss': 0.03471012, 'gen_loss': -0.17417064, 'valid': 0.86},
#  {'disc_loss': 0.05288618, 'gen_loss': 0.02068955, 'valid': 0.79},
#  {'disc_loss': 0.04041013, 'gen_loss': 0.27385899, 'valid': 0.88},
#  {'disc_loss': 0.05989105, 'gen_loss': -0.04821493, 'valid': 0.85},
#  {'disc_loss': 0.02533823, 'gen_loss': -0.18858258, 'valid': 0.87},
#  {'disc_loss': 0.04651679, 'gen_loss': 0.2279302, 'valid': 0.72},
#  {'disc_loss': 0.03642059, 'gen_loss': -0.10973048, 'valid': 0.9},
#  {'disc_loss': 0.05086298, 'gen_loss': -0.24614917, 'valid': 0.86},
#  {'disc_loss': 0.05115534, 'gen_loss': 0.08609282, 'valid': 0.87},
#  {'disc_loss': 0.0392569, 'gen_loss': 0.19646464, 'valid': 0.85},
#  {'disc_loss': 0.01230695, 'gen_loss': -0.30033907, 'valid': 0.88},
#  {'disc_loss': 0.04811746, 'gen_loss': 0.23958205, 'valid': 0.96},
#  {'disc_loss': 0.04874115, 'gen_loss': 0.16487506, 'valid': 0.88},
#  {'disc_loss': 0.05212826, 'gen_loss': -0.05619472, 'valid': 0.9},
#  {'disc_loss': 0.04388253, 'gen_loss': 0.25968832, 'valid': 0.95},
#  {'disc_loss': 0.04272559, 'gen_loss': -0.40250489, 'valid': 0.84},
#  {'disc_loss': 0.04569203, 'gen_loss': 0.16414736, 'valid': 0.84},
#  {'disc_loss': 0.03970154, 'gen_loss': -0.12761176, 'valid': 0.92},
#  {'disc_loss': 0.02232551, 'gen_loss': -0.20202893, 'valid': 0.94},
#  {'disc_loss': 0.03774308, 'gen_loss': 0.08325116, 'valid': 0.88},
#  {'disc_loss': 0.06148344, 'gen_loss': 0.11944014, 'valid': 0.83},
#  {'disc_loss': 0.07870496, 'gen_loss': 0.22643742, 'valid': 0.89},
#  {'disc_loss': 0.06983595, 'gen_loss': -0.14657934, 'valid': 0.9},
#  {'disc_loss': 0.04856852, 'gen_loss': 0.37318191, 'valid': 0.74},
#  {'disc_loss': 0.05442073, 'gen_loss': 0.33070791, 'valid': 0.92},
#  {'disc_loss': 0.03430729, 'gen_loss': -0.33131388, 'valid': 0.8},
#  {'disc_loss': 0.03054611, 'gen_loss': -0.0853403, 'valid': 0.85},
#  {'disc_loss': 0.04295507, 'gen_loss': 0.18224691, 'valid': 0.83},
#  {'disc_loss': 0.04502129, 'gen_loss': -0.06371593, 'valid': 0.92},
#  {'disc_loss': 0.06822477, 'gen_loss': 0.02712102, 'valid': 0.85},
#  {'disc_loss': 0.03960121, 'gen_loss': -0.19399814, 'valid': 0.84},
#  {'disc_loss': 0.05137648, 'gen_loss': 0.46909878, 'valid': 0.94},
#  {'disc_loss': 0.0265029, 'gen_loss': 0.18268399, 'valid': 0.8},
#  {'disc_loss': 0.03088957, 'gen_loss': 0.01178325, 'valid': 0.87},
#  {'disc_loss': 0.07683724, 'gen_loss': 0.07552775, 'valid': 0.82},
#  {'disc_loss': 0.04772794, 'gen_loss': 0.07876319, 'valid': 0.94},
#  {'disc_loss': 0.02039805, 'gen_loss': -0.23095995, 'valid': 0.82},
#  {'disc_loss': 0.02487257, 'gen_loss': 0.10387036, 'valid': 0.86},
#  {'disc_loss': 0.0532752, 'gen_loss': -0.01945725, 'valid': 0.91},
#  {'disc_loss': 0.02719771, 'gen_loss': -0.09433863, 'valid': 0.87},
#  {'disc_loss': 0.02360454, 'gen_loss': -0.43637946, 'valid': 0.8},
#  {'disc_loss': 0.03172946, 'gen_loss': 0.02775984, 'valid': 0.83},
#  {'disc_loss': 0.01820104, 'gen_loss': -0.09124503, 'valid': 0.9},
#  {'disc_loss': 0.01567566, 'gen_loss': -0.40564978, 'valid': 0.86},
#  {'disc_loss': 0.02265546, 'gen_loss': -0.36337322, 'valid': 0.8},
#  {'disc_loss': 0.04337208, 'gen_loss': -0.24022597, 'valid': 0.93},
#  {'disc_loss': 0.03801106, 'gen_loss': -0.11023142, 'valid': 0.67},
#  {'disc_loss': 0.02065696, 'gen_loss': 0.11359268, 'valid': 0.93},
#  {'disc_loss': 0.01958395, 'gen_loss': 0.05603115, 'valid': 0.83},
#  {'disc_loss': 0.0333675, 'gen_loss': 0.06202351, 'valid': 0.82},
#  {'disc_loss': 0.06188705, 'gen_loss': 0.09181678, 'valid': 0.95},
#  {'disc_loss': 0.05496328, 'gen_loss': 0.17251298, 'valid': 0.8},
#  {'disc_loss': 0.07439424, 'gen_loss': 0.32833615, 'valid': 0.88},
#  {'disc_loss': 0.08319214, 'gen_loss': 0.71365601, 'valid': 0.82},
#  {'disc_loss': 0.05169844, 'gen_loss': -0.03007875, 'valid': 0.94},
#  {'disc_loss': 0.02964766, 'gen_loss': -0.02100768, 'valid': 0.82},
#  ...]

# %%
import pandas as pd
import glob

# Define the path to the folder containing the CSV files
folder_path = 'generated/'

# Get a list of all CSV files in the folder
csv_files = glob.glob(folder_path + 'generated_molecules*.csv')

# Initialize an empty list to store dataframes
dataframes = []

# Loop through the list of CSV files and read each one into a dataframe
for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

# Concatenate all the dataframes into one
merged_df = pd.concat(dataframes, ignore_index=True)

# Drop duplicates based on the 'canonical_smiles' column
merged_df.drop_duplicates(subset='canonical_smiles', inplace=True)

# Save the merged dataframe to a new CSV file
merged_df.to_csv('merged_molecules.csv', index=False)

print("CSV files have been merged and duplicates have been dropped.")
# Out:
# CSV files have been merged and duplicates have been dropped.

# %%
import pandas as pd

# Step 1: Load the CSV file
df = pd.read_csv('merged_molecules.csv')

# Step 2: Randomly sample 100,000 rows
df_sampled = df.sample(n=100000, random_state=42)

# Step 3: Save the sampled DataFrame to a new CSV file
df_sampled.to_csv('merged_molecules.csv', index=False)

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client
from rdkit import Chem
from rdkit.Chem import Descriptors, Crippen

# Define the ChEMBL IDs to be added
chembl_ids = [
    'CHEMBL1200633', 'CHEMBL684', 'CHEMBL529', 'CHEMBL267345', 'CHEMBL55', 
    'CHEMBL125', 'CHEMBL290960', 'CHEMBL374478', 'CHEMBL1292'
]

# Initialize the ChEMBL molecule and activity clients
molecule = new_client.molecule
activity = new_client.activity

# Function to check Lipinski's rule of five
def passes_lipinski(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if not mol:
        return False
    h_donors = Descriptors.NumHDonors(mol)
    h_acceptors = Descriptors.NumHAcceptors(mol)
    mol_weight = Descriptors.MolWt(mol)
    logp = Crippen.MolLogP(mol)
    if h_donors <= 5 and h_acceptors <= 10 and mol_weight <= 500 and logp <= 5:
        return True
    return False

# Function to get molecule details from ChEMBL
def get_molecule_details(chembl_id):
    try:
        res = molecule.get(chembl_id)
        activities = activity.filter(molecule_chembl_id=chembl_id).only(['standard_value', 'standard_units', 'standard_type', 'pchembl_value', 'target_chembl_id', 'bao_label'])

        # Aggregate the first activity entry if available
        if activities:
            first_activity = activities[0]
            standard_value = first_activity['standard_value'] if 'standard_value' in first_activity else ''
            standard_units = first_activity['standard_units'] if 'standard_units' in first_activity else ''
            standard_type = first_activity['standard_type'] if 'standard_type' in first_activity else ''
            pchembl_value = first_activity['pchembl_value'] if 'pchembl_value' in first_activity else ''
            target_pref_name = first_activity['target_chembl_id'] if 'target_chembl_id' in first_activity else ''
            bao_label = first_activity['bao_label'] if 'bao_label' in first_activity else ''
        else:
            standard_value = ''
            standard_units = ''
            standard_type = ''
            pchembl_value = ''
            target_pref_name = ''
            bao_label = ''

        canonical_smiles = res['molecule_structures']['canonical_smiles'] if 'molecule_structures' in res else ''
        lipinski = passes_lipinski(canonical_smiles)

        return {
            'molecule_chembl_id': chembl_id,
            'canonical_smiles': canonical_smiles,
            'standard_value': standard_value,
            'standard_units': standard_units,
            'standard_type': standard_type,
            'pchembl_value': pchembl_value,
            'target_pref_name': target_pref_name,
            'bao_label': bao_label,
            'passes_lipinski': lipinski,
            'molecule_name': res['pref_name'] if 'pref_name' in res else ''
        }
    except Exception as e:
        print(f"Error retrieving data for {chembl_id}: {e}")
        return None

# Get details for all specified ChEMBL IDs
new_entries = [get_molecule_details(chembl_id) for chembl_id in chembl_ids]

# Filter out None entries
new_entries = [entry for entry in new_entries if entry is not None]

# Create a DataFrame for the new entries
new_entries_df = pd.DataFrame(new_entries)

# Read the existing CSV file
input_file_path = 'Updated_NTD_Drugs_with_names.csv'
existing_data_df = pd.read_csv(input_file_path)

# Append the new entries to the existing data
updated_data_df = pd.concat([existing_data_df, new_entries_df], ignore_index=True)
updated_data_df.drop_duplicates(subset='canonical_smiles', inplace=True)

# Save the updated data to a new CSV file
output_file_path = 'Final_NTD_Drugs_with_names.csv'
updated_data_df.to_csv(output_file_path, index=False)

print(f"CSV file '{output_file_path}' has been created successfully.")
# Out:
# CSV file 'Final_NTD_Drugs_with_names.csv' has been created successfully.

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# Load the CSV file
file_path = 'NTD_Drugs.csv'
df = pd.read_csv(file_path)

# Initialize the ChEMBL molecule client
molecule = new_client.molecule

# Function to get molecule name from SMILES using ChEMBL
def get_molecule_name(smiles):
    try:
        result = molecule.filter(molecule_structures__canonical_smiles=smiles).only(['molecule_structures', 'molecule_properties', 'molecule_synonyms'])
        if result:
            return result[0]['molecule_synonyms'][0]['synonyms']
        else:
            return None
    except Exception as e:
        print(f"Error fetching molecule name for SMILES {smiles}: {e}")
        return None

# Add a new column for molecule names
df['molecule_name'] = df['canonical_smiles'].apply(get_molecule_name)

df
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL1082  CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...
# 1           CHEMBL777             O=C(O)[C@H]1/C(=C/CO)O[C@@H]2CC(=O)N21
# 2        CHEMBL290960        CC1CS(=O)(=O)CCN1/N=C/c1ccc([N+](=O)[O-])o1
# 3       CHEMBL1631694               CSc1ccc(OCc2ncc([N+](=O)[O-])n2C)cc1
# 4           CHEMBL110                O=C(Cn1ccnc1[N+](=O)[O-])NCc1ccccc1
# 5            CHEMBL20                         CC(=O)Nc1nnc(S(N)(=O)=O)s1
# 6          CHEMBL1483                     CCCSc1ccc2[nH]c(NC(=O)OC)nc2c1
# 7         CHEMBL42442       COC(=O)Nc1nc2cc([S+]([O-])c3ccccc3)ccc2[nH]1
# 8          CHEMBL1503    COc1ccc2[nH]c([S+]([O-])Cc3ncc(C)c(OC)c3C)nc2c1
# 9        CHEMBL384467  C[C@@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C...
# 10          CHEMBL976              O=C(C1CCCCC1)N1CC(=O)N2CCc3ccccc3C2C1
# 11      CHEMBL2110737  CCCC(=O)O[C@H]1CN2CC[C@H](O)[C@@H]2[C@@H](O)[C...
# 12           CHEMBL76                  CCN(CC)CCCC(C)Nc1ccnc2cc(Cl)ccc12
# 13           CHEMBL45                      COc1ccc2[nH]cc(CCNC(C)=O)c2c1
# 14       CHEMBL358850                                   C[C@@H](O)C(=O)O
# 15          CHEMBL685            COC(=O)Nc1nc2cc(C(=O)c3ccccc3)ccc2[nH]1
# 16          CHEMBL628                CC(=O)CCCCn1c(=O)c2c(ncn2C)n(C)c1=O
# 17         CHEMBL1282                       CC(C)Cn1cnc2c(N)nc3ccccc3c21
# 18           CHEMBL55            N=C(N)c1ccc(OCCCCCOc2ccc(C(=N)N)cc2)cc1
# 19          CHEMBL869                  NC(=O)N/N=C/c1ccc([N+](=O)[O-])o1
# 20          CHEMBL830                              NCCCC(N)(C(=O)O)C(F)F
# 21      CHEMBL4069220  O=[N+]([O-])c1cn2c(n1)O[C@@H](COc1ccc(-c3ccc(F...
# 22          CHEMBL106                 OC(Cn1cncn1)(Cn1cncn1)c1ccc(F)cc1F
# 23         CHEMBL1467                                  Oc1ncnc2[nH]ncc12
# 24         CHEMBL1431                                  CN(C)C(=N)NC(=N)N
# 25          CHEMBL131  C[C@]12C=CC(=O)C=C1CC[C@@H]1[C@@H]2[C@@H](O)C[...
# 26         CHEMBL1043                    Nc1ccc(S(=O)(=O)c2ccc(N)cc2)cc1
# 27      CHEMBL3120215  COc1cccc2cc(-c3nc([C@H]4CC[C@H](C(=O)O)CC4)n4n...
# 28           CHEMBL36                      CCc1nc(N)nc(N)c1-c1ccc(Cl)cc1
# 29       CHEMBL566534  CO[C@H]1O[C@@H]2O[C@@]3(C)CC[C@H]4[C@H](C)CC[C...
# 30       CHEMBL361497  C[C@H]1[C@H](OC(=O)CCC(=O)O)O[C@@H]2O[C@@]3(C)...
# 31       CHEMBL416956     OC(c1cc(C(F)(F)F)nc2c(C(F)(F)F)cccc12)C1CCCCN1
# 32      CHEMBL1828820  c1cc([C@H]2CC[C@]3(CC2)OO[C@]2(O3)C3CC4CC(C3)C...
#
#     standard_value standard_units standard_type  pchembl_value  \
# 0        29410.000             nM          IC50           4.53
# 1            4.000             nM          IC50           8.40
# 2          110.000             nM          IC50           6.96
# 3          400.000             nM          IC50           6.40
# 4            1.800             nM          IC50           8.74
# 5            2.580             nM          IC50           8.59
# 6           37.000             nM          IC50           7.43
# 7            1.000             nM          IC50           9.00
# 8           95.500             nM          IC50           7.02
# 9            0.100             nM          IC50          10.00
# 10          77.000             nM          IC50           7.11
# 11       20000.000             nM          IC50            NaN
# 12           0.030             nM          IC50          10.52
# 13           0.017             nM          IC50          10.77
# 14     1000000.000             nM          IC50            NaN
# 15          54.200             nM          IC50           7.27
# 16        6600.000             nM          IC50           5.18
# 17         646.000             nM          IC50           6.19
# 18           0.800             nM          IC50           9.10
# 19       88100.000             nM          IC50           4.05
# 20          26.000             nM          IC50           7.58
# 21          30.000             nM          IC50           7.52
# 22           1.000             nM          IC50           9.00
# 23           3.600             nM          IC50           8.44
# 24           9.900             nM          IC50           8.00
# 25           0.526             nM          IC50           9.28
# 26         420.000             nM          IC50           6.38
# 27        1300.000             nM          IC50           5.89
# 28           0.028             nM          IC50          10.55
# 29           1.260             nM          IC50           8.90
# 30           0.300             nM          IC50           9.52
# 31           0.310             nM          IC50           9.51
# 32           2.000             nM          IC50           8.70
#
#                                  target_pref_name              bao_label  \
# 0                                           HaCaT      cell-based format
# 1                                       Unchecked           assay format
# 2                             Leishmania donovani  organism-based format
# 3                       Trypanosoma brucei brucei  organism-based format
# 4                               Trypanosoma cruzi  organism-based format
# 5                           Carbonic anhydrase IX  single protein format
# 6                            Giardia intestinalis  organism-based format
# 7                                       Unchecked           assay format
# 8                            Giardia intestinalis  organism-based format
# 9                                    Mus musculus  organism-based format
# 10                            Schistosoma mansoni  organism-based format
# 11                                     SARS-CoV-2  organism-based format
# 12                          Plasmodium falciparum  organism-based format
# 13                             Melatonin receptor           assay format
# 14  Alpha-ketoglutarate-dependent dioxygenase FTO           assay format
# 15                                      Unchecked      cell-based format
# 16                           Acetylcholinesterase  single protein format
# 17        7,8-dihydro-8-oxoguanine triphosphatase  single protein format
# 18                             Trypanosoma brucei  organism-based format
# 19             Snake venom metalloproteinase Bap1  single protein format
# 20                             NON-PROTEIN TARGET           assay format
# 21                            Leishmania donovani      cell-based format
# 22                               Candida albicans  organism-based format
# 23                         Xanthine dehydrogenase  single protein format
# 24                                           MCF7      cell-based format
# 25                        Glucocorticoid receptor  single protein format
# 26                                Myeloperoxidase  single protein format
# 27                                          SQ20B      cell-based format
# 28                          Plasmodium falciparum  organism-based format
# 29                          Plasmodium falciparum  organism-based format
# 30                          Plasmodium falciparum  organism-based format
# 31                          Plasmodium falciparum  organism-based format
# 32  Plasmodium falciparum (isolate K1 / Thailand)           assay format
#
#     passes_lipinski                  molecule_name
# 0              True                       AMIX 125
# 1              True                      BRL 14151
# 2              True                       BAY 2502
# 3              True                   FEXINIDAZOLE
# 4              True                   BENZNIDAZOLE
# 5              True                       ACETAMOX
# 6              True                    ALBENDAZOLE
# 7              True                     NSC-758943
# 8              True                          Antra
# 9              True                    AEROSEB-DEX
# 10             True                     BILTRICIDE
# 11             True                     CELGOSIVIR
# 12             True                         Aralen
# 13             True  5-METHOXY N-ACETYL-TRYPTAMINE
# 14             True              D-(-)-LACTIC ACID
# 15             True                    CHLORFENSON
# 16             True                         BL 191
# 17             True                         Aldara
# 18             True                    GNF-Pf-3680
# 19             True                        ACTIN-N
# 20             True                   Eflornithine
# 21             True                      DNDI-0690
# 22             True                     ALKANAZOLE
# 23             True                    ALLOPURINOL
# 24             True                        LA-6023
# 25             True                      CORTALONE
# 26             True                         ACZONE
# 27             True                       AEVI-006
# 28             True                      Chloridin
# 29             True                     ARTEMETHER
# 30             True         .ALPHA.-ARTESUNIC ACID
# 31             True                    GNF-Pf-5544
# 32             True                    Artefenomel

# %%
df.to_csv('NTD_Drugs_with_names.csv', index=False)

# %%
import torch

class OriginalTokenizer(object):
    def __init__(self, data):
        # Define the additional tokens to be included
        self.additional_tokens = ['[C@H]', '[C@@H]', '[nH]', '[O-]', '[C@]', '[N+]', '[C@@]', '[n+]', '[S+]']

        # Build the unique character set and remove '@'
        unique_char = list(set(''.join(data))) + self.additional_tokens + ['<eos>'] + ['<sos>']
        unique_char = [char for char in unique_char if char != '@']  # Remove '@'
        
        self.test_char = unique_char
        self.mapping = {'<pad>': 0}

        for i, c in enumerate(unique_char, start=1):
            self.mapping[c] = i

        self.inv_mapping = {v: k for k, v in self.mapping.items()}
        self.start_token = self.mapping['<sos>']
        self.end_token = self.mapping['<eos>']
        self.vocab_size = len(self.mapping.keys())

    def encode_smile(self, mol, add_eos=True):
        i = 0
        out = []
        while i < len(mol):
            matched = False
            for token in self.additional_tokens:
                if mol[i:i+len(token)] == token:
                    out.append(self.mapping[token])
                    i += len(token)
                    matched = True
                    break
            if not matched:
                out.append(self.mapping[mol[i]])
                i += 1
        if add_eos:
            out.append(self.end_token)
        return torch.LongTensor(out)

    # testing purposes
    def decode_tensor(self, tensor):
        return ''.join([self.inv_mapping[token.item()] for token in tensor if token.item() != self.end_token])

    def batch_tokenize(self, batch):
        out = map(lambda x: self.encode_smile(x), batch)
        return torch.nn.utils.rnn.pad_sequence(list(out), batch_first=True)


# Example data
data = ['CCO/N=C(\c1ccc(Br)cc1)C1C[C@@H]CN(C2(C#C)CCN(C(=O)c3c(C)cc[n+]([O-])c3C)CC2)C[S+]C1.Br']

original_tokenizer = OriginalTokenizer(data)
# Print token mappings
print("Original Tokenizer Mapping:", original_tokenizer.mapping)
print("Vocab Size: ", original_tokenizer.vocab_size)
print("start_token: ", original_tokenizer.start_token)
print("end_token: ", original_tokenizer.end_token)

# Encode and print each SMILES string
for smile in data:
    encoded_smile = original_tokenizer.encode_smile(smile)
    print(f"Original Tokenizer Encoding for {smile}: {encoded_smile}")
    decoded_smile = original_tokenizer.decode_tensor(encoded_smile)
    print(f"Decoded SMILES: {decoded_smile}")
# Out:
# <>:51: SyntaxWarning: invalid escape sequence '\c'
# <>:51: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\barri\AppData\Local\Temp\ipykernel_8296\3060387007.py:51: SyntaxWarning: invalid escape sequence '\c'
#   data = ['CCO/N=C(\c1ccc(Br)cc1)C1C[C@@H]CN(C2(C#C)CCN(C(=O)c3c(C)cc[n+]([O-])c3C)CC2)C[S+]C1.Br']
# Original Tokenizer Mapping: {'<pad>': 0, 'N': 1, '\\': 2, 'O': 3, 'B': 4, '1': 5, '-': 6, '+': 7, 'n': 8, '2': 9, 'H': 10, '=': 11, '[': 12, 'r': 13, '3': 14, 'C': 15, '(': 16, '/': 17, 'S': 18, '#': 19, ']': 20, '.': 21, ')': 22, 'c': 23, '[C@H]': 24, '[C@@H]': 25, '[nH]': 26, '[O-]': 27, '[C@]': 28, '[N+]': 29, '[C@@]': 30, '[n+]': 31, '[S+]': 32, '<eos>': 33, '<sos>': 34}
# Vocab Size:  35
# start_token:  34
# end_token:  33
# Original Tokenizer Encoding for CCO/N=C(\c1ccc(Br)cc1)C1C[C@@H]CN(C2(C#C)CCN(C(=O)c3c(C)cc[n+]([O-])c3C)CC2)C[S+]C1.Br: tensor([15, 15,  3, 17,  1, 11, 15, 16,  2, 23,  5, 23, 23, 23, 16,  4, 13, 22,
#         23, 23,  5, 22, 15,  5, 15, 25, 15,  1, 16, 15,  9, 16, 15, 19, 15, 22,
#         15, 15,  1, 16, 15, 16, 11,  3, 22, 23, 14, 23, 16, 15, 22, 23, 23, 31,
#         16, 27, 22, 23, 14, 15, 22, 15, 15,  9, 22, 15, 32, 15,  5, 21,  4, 13,
#         33])
# Decoded SMILES: CCO/N=C(\c1ccc(Br)cc1)C1C[C@@H]CN(C2(C#C)CCN(C(=O)c3c(C)cc[n+]([O-])c3C)CC2)C[S+]C1.Br

# %%
import torch

class Tokenizer(object):
    def __init__(self, data):
        # Define the additional tokens to be included
        self.additional_tokens = ['[C@H]', '[C@@H]', '[nH]', '[O-]', '[C@]', '[N+]', '[C@@]', '[n+]']

        # Build the unique character set
        unique_char = list(set(''.join(data))) + self.additional_tokens + ['<eos>'] + ['<sos>']
        self.test_char = unique_char
        self.mapping = {'<pad>': 0}

        for i, c in enumerate(unique_char, start=1):
            self.mapping[c] = i

        self.inv_mapping = {v: k for k, v in self.mapping.items()}
        self.start_token = self.mapping['<sos>']
        self.end_token = self.mapping['<eos>']
        self.vocab_size = len(self.mapping.keys())

    def encode_smile(self, mol, add_eos=True):
        i = 0
        out = []
        while i < len(mol):
            matched = False
            for token in self.additional_tokens:
                if mol[i:i+len(token)] == token:
                    out.append(self.mapping[token])
                    i += len(token)
                    matched = True
                    break
            if not matched:
                out.append(self.mapping[mol[i]])
                i += 1
        if add_eos:
            out.append(self.end_token)
        return torch.LongTensor(out)

    # testing purposes
    def decode_tensor(self, tensor):
        return ''.join([self.inv_mapping[token.item()] for token in tensor if token.item() != self.end_token])

    def batch_tokenize(self, batch):
        out = map(lambda x: self.encode_smile(x), batch)
        return torch.nn.utils.rnn.pad_sequence(list(out), batch_first=True)

# Example usage
data = ["CCO/N=C(\c1ccc(Br)cc1)C1C[C@@H]CN(C2(C#C)CCN(C(=O)c3c(C)cc[n+]([O-])c3C)CC2)CC[S@@]1.Br"]
tokenizer = Tokenizer(data)
print(tokenizer.mapping)
# Encode a sample SMILES string
encoded_smile = tokenizer.encode_smile("CCO/N=C(\c1ccc(Br)cc1)C1C[C@@H]CN(C2(C#C)CCN(C(=O)c3c(C)cc[n+]([O-])c3C)CC2)CC[S@@]1.Br")
print("Encoded SMILES:", encoded_smile)

# Decode the tensor back to SMILES string
decoded_smile = tokenizer.decode_tensor(encoded_smile)
print("Decoded SMILES:", decoded_smile)
# Out:
# {'<pad>': 0, '.': 1, 'B': 2, '@': 3, 'C': 4, '2': 5, '3': 6, 'H': 7, ')': 8, '[': 9, 'O': 10, 'r': 11, '\\': 12, '1': 13, '/': 14, '=': 15, 'S': 16, '#': 17, '+': 18, 'n': 19, ']': 20, '(': 21, 'c': 22, '-': 23, 'N': 24, '[C@H]': 25, '[C@@H]': 26, '[nH]': 27, '[O-]': 28, '[C@]': 29, '[N+]': 30, '[C@@]': 31, '[n+]': 32, '<eos>': 33, '<sos>': 34}
# Encoded SMILES: tensor([ 4,  4, 10, 14, 24, 15,  4, 21, 12, 22, 13, 22, 22, 22, 21,  2, 11,  8,
#         22, 22, 13,  8,  4, 13,  4, 26,  4, 24, 21,  4,  5, 21,  4, 17,  4,  8,
#          4,  4, 24, 21,  4, 21, 15, 10,  8, 22,  6, 22, 21,  4,  8, 22, 22, 32,
#         21, 28,  8, 22,  6,  4,  8,  4,  4,  5,  8,  4,  4,  9, 16,  3,  3, 20,
#         13,  1,  2, 11, 33])
# Decoded SMILES: CCO/N=C(\c1ccc(Br)cc1)C1C[C@@H]CN(C2(C#C)CCN(C(=O)c3c(C)cc[n+]([O-])c3C)CC2)CC[S@@]1.Br
# <>:48: SyntaxWarning: invalid escape sequence '\c'
# <>:52: SyntaxWarning: invalid escape sequence '\c'
# <>:48: SyntaxWarning: invalid escape sequence '\c'
# <>:52: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\barri\AppData\Local\Temp\ipykernel_8836\541264587.py:48: SyntaxWarning: invalid escape sequence '\c'
#   data = ["CCO/N=C(\c1ccc(Br)cc1)C1C[C@@H]CN(C2(C#C)CCN(C(=O)c3c(C)cc[n+]([O-])c3C)CC2)CC[S@@]1.Br"]
# C:\Users\barri\AppData\Local\Temp\ipykernel_8836\541264587.py:52: SyntaxWarning: invalid escape sequence '\c'
#   encoded_smile = tokenizer.encode_smile("CCO/N=C(\c1ccc(Br)cc1)C1C[C@@H]CN(C2(C#C)CCN(C(=O)c3c(C)cc[n+]([O-])c3C)CC2)CC[S@@]1.Br")

# %%
import torch

class OriginalTokenizer(object):
    def __init__(self, data):
        # Define the additional tokens to be included
        additional_tokens = ['[C@H]', '[C@@H]', '[nH]', '[O-]', '[C@]', '[N+]', '[C@@]', '[n+]']
        
        # Build the unique character set
        unique_char = list(set(''.join(data))) + additional_tokens + ['<eos>'] + ['<sos>']
        self.test_char = unique_char
        self.mapping = {'<pad>': 0}

        for i, c in enumerate(unique_char, start=1):
            self.mapping[c] = i
        
        self.inv_mapping = {v: k for k, v in self.mapping.items()}
        self.start_token = self.mapping['<sos>']
        self.end_token = self.mapping['<eos>']
        self.vocab_size = len(self.mapping.keys())
        
    def encode_smile(self, mol, add_eos=True):
        out = [self.mapping[i] for i in mol]
        if add_eos:
            out = out + [self.end_token]
        return torch.LongTensor(out)

    def decode_tensor(self, tensor):
        return ''.join([self.inv_mapping[token.item()] for token in tensor if token.item() != self.end_token])

    def batch_tokenize(self, batch):
        out = map(lambda x: self.encode_smile(x), batch)
        return torch.nn.utils.rnn.pad_sequence(list(out), batch_first=True)
        

# Example data
data = ['CCO/N=C(\c1ccc(Br)cc1)C1C[C@@H]CN(C2(C#C)CCN(C(=O)c3c(C)cc[n+]([O-])c3C)CC2)CC1.Br',
        'C=CCNc1c(O)cc2c(O)c1C[C@@H](C)C[C@H](OC)[C@H](O)[C@@H](C)/C=C(\C)[C@H](OC(N)=O)[C@@H](OC)/C=C\C=C(/C)C(=O)N2.Cl']
        # 'C=CCNc1c(O)cc2c(O)c1C[C@@H](C)C[C@H](OC)[C@H](O)[C@@H](C)/C=C(\C)[C@H](OC(N)=O)[C@@H](OC)/C=C\C=C(/C)C(=O)N2.Cl'
original_tokenizer = OriginalTokenizer(data)

# Print token mappings
print("Original Tokenizer Mapping:", original_tokenizer.mapping)
print("Vocab Size: ", original_tokenizer.vocab_size)
print("start_token: ", original_tokenizer.start_token)
print("end_token: ", original_tokenizer.end_token)

# Encode and print each SMILES string
for smile in data:
    encoded_smile = original_tokenizer.encode_smile(smile)
    print(f"Original Tokenizer Encoding for {smile}: {encoded_smile}")
    decoded_smile = original_tokenizer.decode_tensor(encoded_smile)
    print(f"Decoded SMILES: {decoded_smile}")
# Out:
# <>:36: SyntaxWarning: invalid escape sequence '\c'
# <>:37: SyntaxWarning: invalid escape sequence '\C'
# <>:36: SyntaxWarning: invalid escape sequence '\c'
# <>:37: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\barri\AppData\Local\Temp\ipykernel_7184\1997076066.py:36: SyntaxWarning: invalid escape sequence '\c'
#   data = ['CCO/N=C(\c1ccc(Br)cc1)C1C[C@@H]CN(C2(C#C)CCN(C(=O)c3c(C)cc[n+]([O-])c3C)CC2)CC1.Br',
# C:\Users\barri\AppData\Local\Temp\ipykernel_7184\1997076066.py:37: SyntaxWarning: invalid escape sequence '\C'
#   'C=CCNc1c(O)cc2c(O)c1C[C@@H](C)C[C@H](OC)[C@H](O)[C@@H](C)/C=C(\C)[C@H](OC(N)=O)[C@@H](OC)/C=C\C=C(/C)C(=O)N2.Cl']
# Original Tokenizer Mapping: {'<pad>': 0, '2': 1, '=': 2, 'c': 3, 'n': 4, 'l': 5, '@': 6, ')': 7, '(': 8, '.': 9, '\\': 10, 'N': 11, '[': 12, 'C': 13, 'H': 14, '3': 15, 'r': 16, '1': 17, 'B': 18, '#': 19, '+': 20, ']': 21, 'O': 22, '-': 23, '/': 24, '[C@H]': 25, '[C@@H]': 26, '[nH]': 27, '[O-]': 28, '[C@]': 29, '[N+]': 30, '[C@@]': 31, '[n+]': 32, '<eos>': 33, '<sos>': 34}
# Vocab Size:  35
# start_token:  34
# end_token:  33
# Original Tokenizer Encoding for CCO/N=C(\c1ccc(Br)cc1)C1C[C@@H]CN(C2(C#C)CCN(C(=O)c3c(C)cc[n+]([O-])c3C)CC2)CC1.Br: tensor([13, 13, 22, 24, 11,  2, 13,  8, 10,  3, 17,  3,  3,  3,  8, 18, 16,  7,
#          3,  3, 17,  7, 13, 17, 13, 12, 13,  6,  6, 14, 21, 13, 11,  8, 13,  1,
#          8, 13, 19, 13,  7, 13, 13, 11,  8, 13,  8,  2, 22,  7,  3, 15,  3,  8,
#         13,  7,  3,  3, 12,  4, 20, 21,  8, 12, 22, 23, 21,  7,  3, 15, 13,  7,
#         13, 13,  1,  7, 13, 13, 17,  9, 18, 16, 33])
# Decoded SMILES: CCO/N=C(\c1ccc(Br)cc1)C1C[C@@H]CN(C2(C#C)CCN(C(=O)c3c(C)cc[n+]([O-])c3C)CC2)CC1.Br
# Original Tokenizer Encoding for C=CCNc1c(O)cc2c(O)c1C[C@@H](C)C[C@H](OC)[C@H](O)[C@@H](C)/C=C(\C)[C@H](OC(N)=O)[C@@H](OC)/C=C\C=C(/C)C(=O)N2.Cl: tensor([13,  2, 13, 13, 11,  3, 17,  3,  8, 22,  7,  3,  3,  1,  3,  8, 22,  7,
#          3, 17, 13, 12, 13,  6,  6, 14, 21,  8, 13,  7, 13, 12, 13,  6, 14, 21,
#          8, 22, 13,  7, 12, 13,  6, 14, 21,  8, 22,  7, 12, 13,  6,  6, 14, 21,
#          8, 13,  7, 24, 13,  2, 13,  8, 10, 13,  7, 12, 13,  6, 14, 21,  8, 22,
#         13,  8, 11,  7,  2, 22,  7, 12, 13,  6,  6, 14, 21,  8, 22, 13,  7, 24,
#         13,  2, 13, 10, 13,  2, 13,  8, 24, 13,  7, 13,  8,  2, 22,  7, 11,  1,
#          9, 13,  5, 33])
# Decoded SMILES: C=CCNc1c(O)cc2c(O)c1C[C@@H](C)C[C@H](OC)[C@H](O)[C@@H](C)/C=C(\C)[C@H](OC(N)=O)[C@@H](OC)/C=C\C=C(/C)C(=O)N2.Cl

# %%
import pandas as pd
import re
from collections import Counter

# Load the dataset
data = pd.read_csv('NTD_filtered_smiles_dataset.csv')['canonical_smiles']

# Define the tokens to search for
tokens_to_search = ['[P@@]', '[Sr+2]', '[S@]', '[NH-]', '[Mg+2]', '[P+]', '[K+]', '[3H]', '[C-]', '[c+]', '[As]', '[C+]', '[S+]', '[C@]', '[S@@+]', '[I-]', '[N@]', '[Se+]', '[S@@]', '[o+]', '[Cl-]', '[Br-]', '[Li+]', '[Cl+3]', '[N@@+]', '[P-]', '[CaH2]', '[n+]', '[SeH]', '[Al]', '[n-]', '[N@+]', '[C@@H]', '[N+]', '[se]', '[s+]', '[cH-]', '[O]', '[Se]', '[2H]', '[Ca+2]', '[O+]', '[N-]', '[nH]', '[C@@]', '[I+]', '[B-]', '[S@+]', '[C@H]', '[Ag+]', '[NH+]', '[P@]', '[MgH2]', '[N@@]', '[Na+]', '[S-]', '[Si]', '[SH]', '[O-]', '[PH]']

# Initialize the Counter to keep track of token counts
token_counts = Counter()

# Iterate over each SMILES string in the dataset
for smile in data:
    for token in tokens_to_search:
        token_counts[token] += len(re.findall(re.escape(token), smile))

# Filter and sort the found tokens by their counts in descending order
found_tokens_sorted = sorted(token_counts.items(), key=lambda x: x[1], reverse=True)
found_tokens_sorted = [(token, count) for token, count in found_tokens_sorted if count > 0]

# Print the sorted found tokens and their counts
found_tokens_sorted
# Out:
# [('[C@H]', 199482),
#  ('[C@@H]', 181136),
#  ('[C@]', 70833),
#  ('[C@@]', 64920),
#  ('[nH]', 38677),
#  ('[O-]', 27764),
#  ('[N+]', 17734),
#  ('[S+]', 8489),
#  ('[n+]', 2393),
#  ('[Na+]', 1077),
#  ('[Br-]', 675),
#  ('[Cl-]', 589),
#  ('[I-]', 478),
#  ('[Si]', 365),
#  ('[N-]', 310),
#  ('[K+]', 215),
#  ('[Se]', 203),
#  ('[P+]', 107),
#  ('[2H]', 62),
#  ('[se]', 60),
#  ('[B-]', 47),
#  ('[Cl+3]', 36),
#  ('[C-]', 32),
#  ('[I+]', 29),
#  ('[3H]', 28),
#  ('[S@@+]', 27),
#  ('[P-]', 25),
#  ('[o+]', 22),
#  ('[S@+]', 21),
#  ('[P@]', 19),
#  ('[P@@]', 18),
#  ('[Li+]', 17),
#  ('[O+]', 12),
#  ('[N@+]', 11),
#  ('[PH]', 10),
#  ('[n-]', 9),
#  ('[O]', 9),
#  ('[S-]', 9),
#  ('[As]', 8),
#  ('[N@@+]', 8),
#  ('[s+]', 6),
#  ('[N@]', 5),
#  ('[N@@]', 5),
#  ('[NH+]', 4),
#  ('[Mg+2]', 3),
#  ('[Al]', 3),
#  ('[SH]', 3),
#  ('[S@]', 2),
#  ('[C+]', 2),
#  ('[Ag+]', 2),
#  ('[Sr+2]', 1),
#  ('[NH-]', 1),
#  ('[c+]', 1),
#  ('[Se+]', 1),
#  ('[S@@]', 1),
#  ('[CaH2]', 1),
#  ('[SeH]', 1),
#  ('[cH-]', 1),
#  ('[Ca+2]', 1),
#  ('[MgH2]', 1)]

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('final_smiles_dataset.csv')

# Keep only the 'Original_SMILES' column
df = df[['canonical_smiles']]

# Remove duplicates
df = df.drop_duplicates(subset='canonical_smiles')


# Save the cleaned dataset to a new CSV file
df.to_csv('final_smiles_dataset.csv', index=False)
# Out:
#                                          canonical_smiles
# 0       O=P(OP(=O)(OP(=O)(O)OC[C@@H]1O[C@H](n2c(nc(N)c...
# 1       CC(N1CCC[C@H]1C(N[C@@H](CCCCN)C(=O)N[C@H](CC(=...
# 2       CC(C(c1ccc2cc(OCc3ccc([N+](=O)[O-])cc3)ccc2c1)...
# 3              c12OCOc1cc(c(c2)C(=O)O)-c1cccc(c1N(C)C)C=C
# 4                    C1N2C(c3ccccc3)(SC1)c1c(Cl)cccc1C2=O
# ...                                                   ...
# 526838  O=S(=O)(c1ccc(C)cc1)N(CC(CNCc1ccco1)O)c1ccc(F)cc1
# 526839                   C(C1C(=CCc2c1c(ccc2O)O)C)C=C(C)C
# 526840  C(OP([O-])(OCCC12CC3CC(CC(C2)C3)(CCOCCCCCCCC)C...
# 526841                                  O=C/C=C/c1ccccc1O
# 526842  c1cc(ccc1-c1[nH]c2ccccc2n1)OCCCCCOc1ccc(-c2[nH...
#
# [526843 rows x 1 columns]

# %%
df
# Out:
#                                          canonical_smiles
# 0       O=P(OP(=O)(OP(=O)(O)OC[C@@H]1O[C@H](n2c(nc(N)c...
# 1       CC(N1CCC[C@H]1C(N[C@@H](CCCCN)C(=O)N[C@H](CC(=...
# 2       CC(C(c1ccc2cc(OCc3ccc([N+](=O)[O-])cc3)ccc2c1)...
# 3              c12OCOc1cc(c(c2)C(=O)O)-c1cccc(c1N(C)C)C=C
# 4                    C1N2C(c3ccccc3)(SC1)c1c(Cl)cccc1C2=O
# ...                                                   ...
# 526838  O=S(=O)(c1ccc(C)cc1)N(CC(CNCc1ccco1)O)c1ccc(F)cc1
# 526839                   C(C1C(=CCc2c1c(ccc2O)O)C)C=C(C)C
# 526840  C(OP([O-])(OCCC12CC3CC(CC(C2)C3)(CCOCCCCCCCC)C...
# 526841                                  O=C/C=C/c1ccccc1O
# 526842  c1cc(ccc1-c1[nH]c2ccccc2n1)OCCCCCOc1ccc(-c2[nH...
#
# [526843 rows x 1 columns]

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.DataStructs import TanimotoSimilarity

def calculate_tanimoto_similarity(molecule1, molecule2):
    if molecule1 is None or molecule2 is None:
        return None

    # Generate Morgan fingerprints
    fp1 = AllChem.GetMorganFingerprintAsBitVect(molecule1, 2, nBits=2048)
    fp2 = AllChem.GetMorganFingerprintAsBitVect(molecule2, 2, nBits=2048)


    similarity = TanimotoSimilarity(fp1, fp2)

    return similarity

mol1 = Chem.MolFromSmiles("Cc1ccn(-c2ccc(C(=O)N3CCC(F)(F)/C(=C\C(=O)NCc4ccccn4)c4ccccc43)c(Cl)c2)n1")
mol2 = Chem.MolFromSmiles("Cc1ccn(-c2ccc(C(=O)N3CCC(F)(F)/C(=C\C(=O)NCc4cccnn4)c4ccccc43)c(Cl)c2)n1")

similarity_score = calculate_tanimoto_similarity(mol1, mol2)

if similarity_score is not None:
    print(f"Tanimoto Similarity: {similarity_score}")
else:
    print("Invalid SMILES string. Unable to calculate similarity.")
# Out:
# Tanimoto Similarity: 0.85
# <>:18: SyntaxWarning: invalid escape sequence '\C'
# <>:19: SyntaxWarning: invalid escape sequence '\C'
# <>:18: SyntaxWarning: invalid escape sequence '\C'
# <>:19: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\barri\AppData\Local\Temp\ipykernel_9276\509433185.py:18: SyntaxWarning: invalid escape sequence '\C'
#   mol1 = Chem.MolFromSmiles("Cc1ccn(-c2ccc(C(=O)N3CCC(F)(F)/C(=C\C(=O)NCc4ccccn4)c4ccccc43)c(Cl)c2)n1")
# C:\Users\barri\AppData\Local\Temp\ipykernel_9276\509433185.py:19: SyntaxWarning: invalid escape sequence '\C'
#   mol2 = Chem.MolFromSmiles("Cc1ccn(-c2ccc(C(=O)N3CCC(F)(F)/C(=C\C(=O)NCc4cccnn4)c4ccccc43)c(Cl)c2)n1")

# %%
import pandas as pd
import os

file_numbers = 20
files = [f'generated/generated_molecules_{i}.csv' for i in range(1, file_numbers + 1)]

df_list = [pd.read_csv(file) for file in files if os.path.exists(file)]
df = pd.concat(df_list, ignore_index=True)

df = df.drop_duplicates(subset=['canonical_smiles'])

valid_count = df[df['validity'] == 'valid'].shape[0]
invalid_count = df[df['validity'] == 'invalid'].shape[0]

print(f"Number of valid entries: {valid_count}")
print(f"Number of invalid entries: {invalid_count}")
# Out:
# Number of valid entries: 100889
# Number of invalid entries: 18604

# %%
df
# Out:
#                                       canonical_smiles validity
# 0                   CCCCCc1ccc(-c2nsc(-c3ccccn3)n2)cc1    valid
# 1                  O=C(/C=C/c1ccco1)N1CCN(Cc2ccccc2)C1    valid
# 2                      COc1ccc(/C=N/NC(=O)c2ccccc2)cc1    valid
# 3                        O=C(NC1CCCCC1)c1ccc2ccccc2c1O    valid
# 4            COc1ccc(/C=N/NC(=O)c2ccccc2OCc2ccccc2)cc1    valid
# ...                                                ...      ...
# 269462                CCCCC(C(=O)O)c1ccccc1C#Cc1ccccc1    valid
# 269463  CC(C)(C)c1ccc(NC(=O)Nc2ccc(NC(=O)C(C)C)cc2)cc1    valid
# 269465               O=S(=O)(=O)c1cccc([N+](=O)[O-])c1  invalid
# 269466             CCCCNC(=O)c1scnc1S(=O)(=O)c1ccccc1O    valid
# 269468         CN(C)C(=O)C(=O)c1[nH]cnc1C(=O)Nc1ccccc1    valid
#
# [119493 rows x 2 columns]

# %%
# Save the merged DataFrame to a new CSV file
output_file = 'merged_molecules.csv'
df.to_csv(output_file, index=False)
print(f"Merged file saved as {output_file}")
# Out:
# Merged file saved as merged_molecules.csv

# %% [markdown]
# # DATA AUGMENTATION

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem, DataStructs

# Load the dataset
df = pd.read_csv('NTD_Drugs.csv')

# Function to generate original and augmented SMILES
def augment_smiles(smiles, num_augments=1):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return [None] * num_augments  # Invalid SMILES string
    augmented_smiles_list = []
    for _ in range(num_augments):
        augmented_smiles = Chem.MolToSmiles(mol, doRandom=True)
        augmented_smiles_list.append(augmented_smiles)
    return augmented_smiles_list

# Function to calculate Tanimoto similarity
def calculate_similarity(smiles1, smiles2):
    mol1 = Chem.MolFromSmiles(smiles1)
    mol2 = Chem.MolFromSmiles(smiles2)
    if mol1 is None or mol2 is None:
        return 0.0  # Invalid SMILES string
    fp1 = AllChem.GetMorganFingerprintAsBitVect(mol1, 2)
    fp2 = AllChem.GetMorganFingerprintAsBitVect(mol2, 2)
    similarity = DataStructs.TanimotoSimilarity(fp1, fp2)
    return similarity

# Augment the dataset
augmented_data = []
num_augments = 1000
for smiles in df['canonical_smiles']:
    augmented_smiles_list = augment_smiles(smiles, num_augments=num_augments)
    for augmented_smiles in augmented_smiles_list:
        if augmented_smiles is not None:
            similarity = calculate_similarity(smiles, augmented_smiles)
            augmented_data.append({
                'Original_SMILES': smiles,
                'Augmented_SMILES': augmented_smiles,
                'Augmentation_Type': 'Augmented',
                'Tanimoto_Score': similarity
            })
        else:
            augmented_data.append({
                'Original_SMILES': smiles,
                'Augmented_SMILES': smiles,
                'Augmentation_Type': 'Original',
                'Tanimoto_Score': similarity
            })

# Create a new DataFrame with the augmented SMILES and augmentation type
augmented_df = pd.DataFrame(augmented_data)

augmented_df.to_csv('NTD_augmented_smiles_dataset.csv', index=False)

# Display the augmented DataFrame
augmented_df
# Out:
#                                          Original_SMILES  \
# 0      CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...
# 1      CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...
# 2      CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...
# 3      CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...
# 4      CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...
# ...                                                  ...
# 32995  c1cc([C@H]2CC[C@]3(CC2)OO[C@]2(O3)C3CC4CC(C3)C...
# 32996  c1cc([C@H]2CC[C@]3(CC2)OO[C@]2(O3)C3CC4CC(C3)C...
# 32997  c1cc([C@H]2CC[C@]3(CC2)OO[C@]2(O3)C3CC4CC(C3)C...
# 32998  c1cc([C@H]2CC[C@]3(CC2)OO[C@]2(O3)C3CC4CC(C3)C...
# 32999  c1cc([C@H]2CC[C@]3(CC2)OO[C@]2(O3)C3CC4CC(C3)C...
#
#                                         Augmented_SMILES Augmentation_Type  \
# 0      C(N[C@H]1[C@@H]2N(C1=O)[C@H](C(C)(C)S2)C(O)=O)...         Augmented
# 1      [C@H](c1ccc(O)cc1)(N)C(N[C@H]1[C@@H]2N(C1=O)[C...         Augmented
# 2      CC1(S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)C(...         Augmented
# 3      [C@H](c1ccc(O)cc1)(N)C(N[C@@H]1C(N2[C@@H]1SC([...         Augmented
# 4      c1([C@@H](N)C(N[C@H]2[C@@H]3N([C@H](C(C)(C)S3)...         Augmented
# ...                                                  ...               ...
# 32995  C12[C@]3(OO[C@@]4(O3)CC[C@@H](c3ccc(cc3)OCCN3C...         Augmented
# 32996  [C@H]1(CC[C@@]2(O[C@]3(C4CC5CC3CC(C5)C4)OO2)CC...         Augmented
# 32997  O1O[C@]2(C3CC4CC(CC2C4)C3)O[C@@]21CC[C@@H](CC2...         Augmented
# 32998  c1c(ccc(c1)OCCN1CCOCC1)[C@H]1CC[C@]2(O[C@@]3(O...         Augmented
# 32999  O1CCN(CC1)CCOc1ccc(cc1)[C@H]1CC[C@]2(O[C@]3(OO...         Augmented
#
#        Tanimoto_Score
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 32995             1.0
# 32996             1.0
# 32997             1.0
# 32998             1.0
# 32999             1.0
#
# [33000 rows x 4 columns]

# %%
# Remove non similar canonical smiles
augmented_df = augmented_df[augmented_df['Tanimoto_Score'] == 1.0]

# Save the augmented dataset
augmented_df.to_csv('NTD_augmented_smiles_dataset.csv', index=False)

print("Data augmentation completed and saved to 'augmented_smiles_dataset.csv'.")
# Out:
# Data augmentation completed and saved to 'augmented_smiles_dataset.csv'.

# %%
augmented_df
# Out:
#                                          Original_SMILES  \
# 0      CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...
# 1      CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...
# 2      CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...
# 3      CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...
# 4      CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...
# ...                                                  ...
# 32995  c1cc([C@H]2CC[C@]3(CC2)OO[C@]2(O3)C3CC4CC(C3)C...
# 32996  c1cc([C@H]2CC[C@]3(CC2)OO[C@]2(O3)C3CC4CC(C3)C...
# 32997  c1cc([C@H]2CC[C@]3(CC2)OO[C@]2(O3)C3CC4CC(C3)C...
# 32998  c1cc([C@H]2CC[C@]3(CC2)OO[C@]2(O3)C3CC4CC(C3)C...
# 32999  c1cc([C@H]2CC[C@]3(CC2)OO[C@]2(O3)C3CC4CC(C3)C...
#
#                                         Augmented_SMILES Augmentation_Type  \
# 0      C(N[C@H]1[C@@H]2N(C1=O)[C@H](C(C)(C)S2)C(O)=O)...         Augmented
# 1      [C@H](c1ccc(O)cc1)(N)C(N[C@H]1[C@@H]2N(C1=O)[C...         Augmented
# 2      CC1(S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)C(...         Augmented
# 3      [C@H](c1ccc(O)cc1)(N)C(N[C@@H]1C(N2[C@@H]1SC([...         Augmented
# 4      c1([C@@H](N)C(N[C@H]2[C@@H]3N([C@H](C(C)(C)S3)...         Augmented
# ...                                                  ...               ...
# 32995  C12[C@]3(OO[C@@]4(O3)CC[C@@H](c3ccc(cc3)OCCN3C...         Augmented
# 32996  [C@H]1(CC[C@@]2(O[C@]3(C4CC5CC3CC(C5)C4)OO2)CC...         Augmented
# 32997  O1O[C@]2(C3CC4CC(CC2C4)C3)O[C@@]21CC[C@@H](CC2...         Augmented
# 32998  c1c(ccc(c1)OCCN1CCOCC1)[C@H]1CC[C@]2(O[C@@]3(O...         Augmented
# 32999  O1CCN(CC1)CCOc1ccc(cc1)[C@H]1CC[C@]2(O[C@]3(OO...         Augmented
#
#        Tanimoto_Score
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 32995             1.0
# 32996             1.0
# 32997             1.0
# 32998             1.0
# 32999             1.0
#
# [33000 rows x 4 columns]

# %%
# Count how many entries are 'Original'
original_count = augmented_df[augmented_df['Augmentation_Type'] == 'Original'].shape[0]

# Print the count
print(f"Number of 'Original' entries: {original_count}")
# Out:
# Number of 'Original' entries: 0

# %%
import pandas as pd
import numpy as np

# Load the augmented dataset
df = pd.read_csv('NTD_augmented_smiles_dataset.csv')

# Convert 'Original_SMILES' and 'Augmented_SMILES' columns to arrays
original_smiles_array = df['Original_SMILES'].fillna('').to_numpy()
augmented_smiles_array = df['Augmented_SMILES'].fillna('').to_numpy()

# Concatenate arrays
combined_smiles_array = np.concatenate([original_smiles_array, augmented_smiles_array])

# Calculate sizes
size_original_smiles_array = len(original_smiles_array)
size_augmented_smiles_array = len(augmented_smiles_array)
size_combined_smiles_array = len(combined_smiles_array)

print(f"Size of original_smiles_array: {size_original_smiles_array}")
print(f"Size of augmented_smiles_array: {size_augmented_smiles_array}")
print(f"Size of combined_smiles_array: {size_combined_smiles_array}")
# Out:
# Size of original_smiles_array: 33000
# Size of augmented_smiles_array: 33000
# Size of combined_smiles_array: 66000

# %%
# Create a DataFrame from combined_smiles_array
combined_df = pd.DataFrame({'canonical_smiles': combined_smiles_array})

# Remove duplicates
combined_df.drop_duplicates(subset=['canonical_smiles'], keep='first', inplace=True)

# Save the processed DataFrame
combined_df.to_csv('NTD_processed_combined_smiles.csv', index=False)

print("Processed combined SMILES saved to 'processed_combined_smiles.csv'.")
# Out:
# Processed combined SMILES saved to 'processed_combined_smiles.csv'.

# %%
combined_df
# Out:
#                                         canonical_smiles
# 0      CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)...
# 1000              O=C(O)[C@H]1/C(=C/CO)O[C@@H]2CC(=O)N21
# 2000         CC1CS(=O)(=O)CCN1/N=C/c1ccc([N+](=O)[O-])o1
# 3000                CSc1ccc(OCc2ncc([N+](=O)[O-])n2C)cc1
# 4000                 O=C(Cn1ccnc1[N+](=O)[O-])NCc1ccccc1
# ...                                                  ...
# 65995  C12[C@]3(OO[C@@]4(O3)CC[C@@H](c3ccc(cc3)OCCN3C...
# 65996  [C@H]1(CC[C@@]2(O[C@]3(C4CC5CC3CC(C5)C4)OO2)CC...
# 65997  O1O[C@]2(C3CC4CC(CC2C4)C3)O[C@@]21CC[C@@H](CC2...
# 65998  c1c(ccc(c1)OCCN1CCOCC1)[C@H]1CC[C@]2(O[C@@]3(O...
# 65999  O1CCN(CC1)CCOc1ccc(cc1)[C@H]1CC[C@]2(O[C@]3(OO...
#
# [20812 rows x 1 columns]

# %%
import pandas as pd
from rdkit import Chem

# Load the processed dataset
df = pd.read_csv('NTD_processed_combined_smiles.csv')

# Function to check validity of SMILES string
def check_validity(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return 'invalid'
    else:
        return 'valid'

# Add 'Validity' column
df['Validity'] = df['canonical_smiles'].apply(check_validity)

# Count valid and invalid entries
valid_count = df[df['Validity'] == 'valid'].shape[0]
invalid_count = df[df['Validity'] == 'invalid'].shape[0]

# Print counts
print(f"Number of valid SMILES: {valid_count}")
print(f"Number of invalid SMILES: {invalid_count}")
# Out:
# Number of valid SMILES: 20812
# Number of invalid SMILES: 0

# %%
import pandas as pd

# Load the processed dataset
df = pd.read_csv('NTD_processed_combined_smiles.csv')

# Drop duplicate SMILES strings
df.drop_duplicates(subset=['canonical_smiles'], keep='first', inplace=True)

# Shuffle the DataFrame
df_shuffled = df.sample(frac=1).reset_index(drop=True)

# Save the shuffled DataFrame
df_shuffled.to_csv('NTD_final_smiles_dataset.csv', index=False)

print("Shuffled SMILES data saved to 'NTD_final_smiles_dataset.csv'.")
# Out:
# Shuffled SMILES data saved to 'NTD_final_smiles_dataset.csv'.

# %%
df_shuffled
# Out:
#                                         canonical_smiles
# 0                                  NCCCC(C(O)=O)(C(F)F)N
# 1      [C@@H]1([C@H](O)[C@H](CN2[C@@H]1[C@H](CC2)O)OC...
# 2      c1cc(cc2c1[nH]c(n2)[S+]([O-])Cc1ncc(c(c1C)OC)C)OC
# 3      C1COCCN1CCOc1ccc([C@H]2CC[C@]3(CC2)OO[C@]2(C4C...
# 4                       c12[nH]c(nc1cc(cc2)SCCC)NC(=O)OC
# ...                                                  ...
# 20807                   n1c(c2c(n(cn2)CC(C)C)c2c1cccc2)N
# 20808                       C(Nc1sc(S(N)(=O)=O)nn1)(C)=O
# 20809              c1c(CNC(Cn2ccnc2[N+]([O-])=O)=O)cccc1
# 20810  O[C@@H]1[C@H]2[C@H]([C@H]3[C@@](C1)(C)[C@@](O)...
# 20811  [C@H]1(COc2ccc(-c3ccc(F)cc3)nc2)CCn2c(O1)nc([N...
#
# [20812 rows x 1 columns]

# %%
import pandas as pd

final_df = pd.read_csv('final_smiles_dataset.csv')
combined_df = pd.concat([final_df, df_shuffled[['canonical_smiles']]], ignore_index=True)
combined_df.drop_duplicates(subset='canonical_smiles', inplace=True)
combined_df.to_csv('NTD_final_smiles_dataset.csv', index=False)

combined_df
# Out:
#                                          canonical_smiles
# 0       CC(=O)N[C@@H](Cc1ccc(C(F)(F)P(=O)(O)O)cc1)C(=O...
# 1       N#CC1(NC(=O)[C@@H]2Cc3ccc(c(Cl)c3)OCCCCOc3cc(C...
# 2       COc1cc2[nH]c3ccc(Nc4cccc(OC(F)(F)F)c4)cc3c(=O)...
# 3          c1[nH]c2ccccc2c1CC[N+](Cc1cccs1)(Cc1sccc1)[O-]
# 4       C(CCC(S([O-])(=O)=O)P(=O)([O-])[O-])c1cc(ccc1)...
# ...                                                   ...
# 279201                   n1c(c2c(n(cn2)CC(C)C)c2c1cccc2)N
# 279202                       C(Nc1sc(S(N)(=O)=O)nn1)(C)=O
# 279203              c1c(CNC(Cn2ccnc2[N+]([O-])=O)=O)cccc1
# 279204  O[C@@H]1[C@H]2[C@H]([C@H]3[C@@](C1)(C)[C@@](O)...
# 279205  [C@H]1(COc2ccc(-c3ccc(F)cc3)nc2)CCn2c(O1)nc([N...
#
# [279164 rows x 1 columns]
