# %% [markdown]
# # Load and Re-Train Model

# %%
! pip install torch
! pip install numpy
! pip install rdkit
! pip install allennlp-light
! pip install zipfile
# Out:
# Requirement already satisfied: torch in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (2.3.0+cu118)
# Requirement already satisfied: filelock in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from torch) (2024.2.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch) (1.3.0)
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (1.26.3)
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: rdkit in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (2023.9.5)
# Requirement already satisfied: numpy in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from rdkit) (1.26.3)
# Requirement already satisfied: Pillow in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from rdkit) (10.2.0)
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: allennlp-light in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (1.0.0)
# Requirement already satisfied: ai2-tango in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from allennlp-light) (1.3.2)
# Requirement already satisfied: cached-path<2.0,>=1.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (1.6.2)
# Requirement already satisfied: rjsonnet>=0.5.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (0.5.4)
# Requirement already satisfied: GitPython<4.0,>=3.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (3.1.43)
# Requirement already satisfied: PyYAML<7.0,>=5.4.1 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (6.0.1)
# Requirement already satisfied: dill in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (0.3.8)
# Requirement already satisfied: base58 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (2.1.1)
# Requirement already satisfied: xxhash in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (3.4.1)
# Requirement already satisfied: filelock<4.0,>=3.4 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (3.13.1)
# Requirement already satisfied: click<8.1.4,>=8.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (8.1.3)
# Requirement already satisfied: click-help-colors<0.10,>=0.9.1 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (0.9.4)
# Requirement already satisfied: rich<14.0,>=12.3 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (13.7.1)
# Requirement already satisfied: tqdm<5.0,>=4.62 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (4.66.2)
# Requirement already satisfied: more-itertools<10.0,>=8.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (9.1.0)
# Requirement already satisfied: sqlitedict in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (2.1.0)
# Requirement already satisfied: glob2>=0.7 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (0.7)
# Requirement already satisfied: petname<3.0,>=2.6 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (2.6)
# Requirement already satisfied: pytz in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from ai2-tango->allennlp-light) (2024.1)
# Requirement already satisfied: requests<3.0,>=2.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (2.31.0)
# Requirement already satisfied: boto3<2.0,>=1.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (1.34.92)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (2.16.0)
# Requirement already satisfied: huggingface-hub<0.22.0,>=0.8.1 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (0.21.4)
# Requirement already satisfied: colorama in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from click<8.1.4,>=8.0->ai2-tango->allennlp-light) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from GitPython<4.0,>=3.0->ai2-tango->allennlp-light) (4.0.11)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from rich<14.0,>=12.3->ai2-tango->allennlp-light) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from rich<14.0,>=12.3->ai2-tango->allennlp-light) (2.17.2)
# Requirement already satisfied: botocore<1.35.0,>=1.34.92 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from boto3<2.0,>=1.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (1.34.92)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from boto3<2.0,>=1.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from boto3<2.0,>=1.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (0.10.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from gitdb<5,>=4.0.1->GitPython<4.0,>=3.0->ai2-tango->allennlp-light) (5.0.1)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (2.29.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (2.18.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (2.7.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (1.5.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<0.22.0,>=0.8.1->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<0.22.0,>=0.8.1->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<0.22.0,>=0.8.1->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (24.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.3->ai2-tango->allennlp-light) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (2024.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from botocore<1.35.0,>=1.34.92->boto3<2.0,>=1.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (2.9.0.post0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (1.23.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (0.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\barri\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.92->boto3<2.0,>=1.0->cached-path<2.0,>=1.0->ai2-tango->allennlp-light) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement zipfile (from versions: none)
# ERROR: No matching distribution found for zipfile
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
from model import TrainGAN
from tokenizer import Tokenizer
from layers import Generator, Discriminator

import zipfile

# Read the CSV file from the zip file
zip_file_path = "NTD_filtered_smiles_dataset.zip"
data = []
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    with zip_ref.open('NTD_filtered_smiles_dataset.csv') as csv_file:
        for line in csv_file.readlines()[1:]:
            smile = line.decode('utf-8').strip()
            data.append(smile)


# Define a function to read the top hyperparameters from the file
def read_top_hyperparameters(file_path):
    top_params = []
    with open(file_path, "r") as f:
        for line in f:
            score, params = line.split(', Parameters: ')
            params = eval(params.strip())
            top_params.append(params)
    return top_params

# %%
# Read the top hyperparameters
top_hyperparameters = read_top_hyperparameters("best_hyperparams.txt")

best_params_best = top_hyperparameters[0]
hidden_dim_best = best_params_best['hidden_dim']
lr_best = best_params_best['lr']
dropout_best = best_params_best['dropout']
batch_size_best = best_params_best['batch_size'] 
best_params_best
# Out:
# {'hidden_dim': 256,
#  'lr': 0.0002362588471099862,
#  'dropout': 0.3,
#  'batch_size': 64}

# %%
hidden_dim = hidden_dim_best
lr = lr_best
device = "cuda"
step = 220000

# Load tokenizer state
tokenizer_state = torch.load(f'models(test)/checkpoint_step_{step}/tokenizer.pth')
tokenizer = Tokenizer(data)
tokenizer.mapping = tokenizer_state['mapping']
tokenizer.inv_mapping = tokenizer_state['inv_mapping']
tokenizer.start_token = tokenizer_state['start_token']
tokenizer.end_token = tokenizer_state['end_token']
tokenizer.vocab_size = tokenizer_state['vocab_size']

# Load generator and discriminator models
generator = Generator(
    latent_dim=hidden_dim,
    vocab_size=tokenizer.vocab_size - 1,
    start_token=tokenizer.start_token - 1,
    end_token=tokenizer.end_token - 1,
).to(device)
generator.load_state_dict(torch.load(f'models(test)/checkpoint_step_{step}/generator.pth'))

discriminator = Discriminator(
    hidden_size=hidden_dim,
    vocab_size=tokenizer.vocab_size,
    start_token=tokenizer.start_token,
    bidirectional=True
).to(device)
discriminator.load_state_dict(torch.load(f'models(test)/checkpoint_step_{step}/discriminator.pth'))

# Load generator and discriminator optimizer states
generator_optimizer = torch.optim.Adam(generator.parameters(), lr=lr)
generator_optimizer.load_state_dict(torch.load(f'models(test)/checkpoint_step_{step}/generator_optimizer.pth'))

discriminator_optimizer = torch.optim.Adam(discriminator.parameters(), lr=lr)
discriminator_optimizer.load_state_dict(torch.load(f'models(test)/checkpoint_step_{step}/discriminator_optimizer.pth'))

# Create MolGen instance and assign loaded models and optimizer
gan_model_loaded = TrainGAN(data, hidden_dim=hidden_dim, lr=lr, device=device)
gan_model_loaded.tokenizer = tokenizer
gan_model_loaded.generator = generator
gan_model_loaded.discriminator = discriminator
gan_model_loaded.generator_optim = generator_optimizer
gan_model_loaded.discriminator_optim = discriminator_optimizer

# %%
# Update dropout rates in the model
gan_model_loaded.generator.output_layer[1].p = dropout_best
gan_model_loaded.generator.output_layer[4].p = dropout_best
gan_model_loaded.discriminator.fc[1].p = dropout_best
gan_model_loaded.discriminator.fc[4].p = dropout_best

gan_model_loaded.generator.project._dropout[0].p = dropout_best
gan_model_loaded.generator.project._dropout[1].p = dropout_best

print(gan_model_loaded.generator.output_layer[1].p)
print(gan_model_loaded.generator.output_layer[4].p)

print(gan_model_loaded.discriminator.fc[1].p)
print(gan_model_loaded.discriminator.fc[4].p)

print(gan_model_loaded.generator.project._dropout[0].p)
print(gan_model_loaded.generator.project._dropout[1].p)
# Out:
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3

# %%
# Prepare DataLoader
retrain_loader = gan_model_loaded.create_dataloader(data, batch_size=batch_size_best, shuffle=True, num_workers=8)
# Out:
# tokens:  ['e', '6', 'I', 'r', '#', '9', 'F', '+', '/', '(', ']', '=', '3', '5', 'K', '7', '2', 'o', 'n', '.', 'O', 'c', 'i', 'A', 'a', '-', 'N', '1', '\\', 'l', '[', 'H', '0', ')', 'M', '8', 's', 'P', '@', '4', 'B', 'S', '%', 'g', 'L', 'C', '[C@H]', '[C@@H]', '[nH]', '[O-]', '[C@]', '[N+]', '[C@@]', '[S+]', '<eos>', '<sos>']
# vocab_size:  57
# start:  56
# end:  55

# %%
gan_model_loaded.train_n_steps(retrain_loader, max_step=220100, evaluate_every=100, save_every=20000) # 180k # 100 epochs (200k max_step)
# Out:
# Cn1c(SCCCCCN2CCCN(C)C2)c(OC)c(OCCCN)c1
# valid 1401 =  0.84
# Model saved at step 140000 in models(test)/checkpoint_step_140000.
# CCOc1cc(CCSCCNC(=O)NO)n(-c2ccccnc2)nc2nc3ccccc3c2NCc2ccccc2Cl)n1
# valid 1402 =  0.68
# CCCCCCC/C=C\c1c[nH]c2ccccc2c1
# valid 1403 =  0.86
# CCCCC/C=C\c1ccc(CNC(=O)c2ccc([N+](=O)[O-])o2)cc1OC
# valid 1404 =  0.82
# CCOC(=O)c1ccc(-c2csc(-c3ccccc3)n2)cc1
# valid 1405 =  0.79
# O=C(O)/C(Cl)=C/c1ccc(Br)cc1
# valid 1406 =  0.92
# CCCCCCC(=O)c1ccc(C#N)cc1
# valid 1407 =  0.88
# COc1ccc(C2=NCCNC[C@H]2O)cc1
# valid 1408 =  0.84
# COc1ccc(/C=N/NC(=O)c2nc3ccccc3o2)cc1
# valid 1409 =  0.84
# O=C(O)c1ccc(NC(=S)NNC(=S)Nc2ccc(-c3ccccc3)cc2)cc1
# valid 1410 =  0.86
# S=C(N/N=C/c1ccc([N+](=O)[O-])cc1)Nc1ccccc1
# valid 1411 =  0.79
# Cc1cccc(O)c1CO
# valid 1412 =  0.85
# COc1ccc(OC)c(C(=O)NO)c1
# valid 1413 =  0.81
# COc1ccc(Br)cc1S(=O)(=O)Nc1ccccc1
# valid 1414 =  0.71
# CCCCCC[C@@H](O)c1ccc(SSc2ccc(Br)cc2)cc1
# valid 1415 =  0.79
# COc1ccc(/C=C/c2ccc(O)c(O)c2)cc1
# valid 1416 =  0.88
# O=C(Nc1ccc(Cl)cc1)c1ccc(O)c(O)c1
# valid 1417 =  0.86
# Cn1cnc(/C=C/C#Cc2ccc(Cl)cc2Cl)n1
# valid 1418 =  0.82
# CCn1c(N)nc(N)n1
# valid 1419 =  0.73
# Cc1ccc(NC(=O)C(C)NC(=O)c2c[nH]c3nc(-c3ccccc3)nc2N)cc1
# valid 1420 =  0.88
# CCS(=O)(=O)c1ccc(Cl)cc1Cn1ccnc1
# valid 1421 =  0.73
# O=C(/C=C\c1ccc([N+](=O)[O-])cc1)Nc1ccccc1C(=O)O
# valid 1422 =  0.84
# Cn1cc(/C=N/Nc2cccc(I)c2)c(C)c1
# valid 1423 =  0.87
CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC#CCCCCCCCCCCCCCCCCCCC[C@@H](C)O
# valid 2177 =  0.88
# Cc1ccc(CSc2nc(-c3cccnc3)cs2)cc1
# valid 2178 =  0.90
# COc1ccc(CCc2ccccc2)cc1CNCCO
# valid 2179 =  0.81
# CCOC(=O)c1cn(Cc2ccc(Cl)cc2)c(Cl)c1Cl
# valid 2180 =  0.83
# O=C(Nc1ccccc1)NCCCNc1ccnc2c1ccccc12
# valid 2181 =  0.87
# Cc1ccc(Cl)cc1NCCSc1cccnc1
# valid 2182 =  0.90
# O=C(O)c1cc2ccccc2o1
# valid 2183 =  0.90
# O=C(O)CCCc1ccc(O)cc1
# valid 2184 =  0.96
# COc1ccc(OCCC(=O)Nc2nc3ccccc3o2)cc1
# valid 2185 =  0.92
# CCN(CC)CCNc1ccnc2cc(Cl)ccc12
# valid 2186 =  0.96
# COC(=O)CCC(=O)Nc1ccc(-c2ccc([N+](=O)[O-])o2)cc1
# valid 2187 =  0.89
# C=Cc1ccc(OP(=O)(O)O)cc1
# valid 2188 =  0.87
# CCCc1ccc(Oc2ccc(-c3cccnc3)cc2)cc1
# valid 2189 =  0.80
# CCN(CC)CCCCCNc1ccnc2cc(Cl)ccc12
# valid 2190 =  0.82
# O=C(Nc1ccccc1)c1ccc(-n2cnc(-c3ccccc3)n2)cc1
# valid 2191 =  0.78
# COc1ccc(-c2nonc2-c2ccccc2)cc1O
# valid 2192 =  0.83
# Brc1ccc(-c2ccc([N+](=O)[O-])o2)cc1
# valid 2193 =  0.86
# CCCCCCCCCCC/C=C/C(=O)Nc1ccccc1
# valid 2194 =  0.81
# O=C(/C=C/c1cccc2ccccc2c1)c1ccccc1O
# valid 2195 =  0.86
# O=[N+]([O-])c1ccc(NC(=S)N/N=C/c2ccc3ccccc3n2)cc1
# valid 2196 =  0.82
# CCCCC/C=C(\C)c1ccc(O)cc1
# valid 2197 =  0.92
# CCCOc1ccc(/C=N/NC(=N)N)cc1
# valid 2198 =  0.82
# COc1ccc(-c2csc(-n3ccnc3)c2-c2ccccc2F)cc1
# valid 2199 =  0.72
# CCCCCCOC(=O)C1=C(Cl)C(=O)N(Cc2ccccc2)CC1
# valid 2200 =  0.85
# CN(CC)CCCNC(=O)O
# valid 2201 =  0.87
# Model saved at step 220000 in models(test)/checkpoint_step_220000.
# 0.87

# %%
gan_model_loaded.eval()
# Out:
# TrainGAN(
#   (generator): Generator(
#     (embedding_layer): Embedding(56, 256)
#     (project): FeedForward(
#       (_activations): ModuleList(
#         (0): LeakyReLU(negative_slope=0.01)
#         (1): ELU(alpha=0.1)
#       )
#       (_linear_layers): ModuleList(
#         (0): Linear(in_features=256, out_features=512, bias=True)
#         (1): Linear(in_features=512, out_features=512, bias=True)
#       )
#       (_dropout): ModuleList(
#         (0-1): 2 x Dropout(p=0.3, inplace=False)
#       )
#     )
#     (rnn): LSTMCell(256, 256)
#     (output_layer): Sequential(
#       (0): LeakyReLU(negative_slope=0.01)
#       (1): Dropout(p=0.3, inplace=False)
#       (2): Linear(in_features=256, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Dropout(p=0.3, inplace=False)
#       (5): Linear(in_features=512, out_features=55, bias=True)
#     )
#   )
#   (discriminator): Discriminator(
#     (embedding): Embedding(57, 256, padding_idx=0)
#     (rnn): LstmSeq2SeqEncoder(
#       (_module): LSTM(256, 256, batch_first=True, bidirectional=True)
#     )
#     (fc): Sequential(
#       (0): LeakyReLU(negative_slope=0.01)
#       (1): Dropout(p=0.3, inplace=False)
#       (2): Linear(in_features=512, out_features=1024, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Dropout(p=0.3, inplace=False)
#       (5): Linear(in_features=1024, out_features=1, bias=True)
#       (6): Sigmoid()
#     )
#   )
# )

# %%
smiles_list = gan_model_loaded.generate_n(50000)

# %%
smiles_list
# Out:
# ['O=C(Nc1ccccc1)c1cn(Cc2ccc(Br)cc2)[nH]1',
#  'COc1ccc(C(=O)/C=C/c2ccc(OC)cc2)cc1O',
#  'COc1ccc(-c2csc(NCc3ccc(Cl)cc3)nc2O)cc1',
#  'C[S+]([O-])c1ccc(NC(=N)N)cc1',
#  'COc1ccc(-c2nc(-c3ccc(Cl)cc3)nnc2N1',
#  'COc1ccc(-c2nc(-c3ccc(Cl)cc3)no2)cc1',
#  'COc1ccc(/C=N/NC(N)=S)cc1',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)cc2)cc1O',
#  'COc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'COc1ccc(-c2csc(-c3cccc(C#N)c3)nc2)cc1',
#  'COc1ccc(-c2nc(-c3ccc(Cl)cc3)nc2N)cc1',
#  'CCOC(=O)c1cc(Cl)cc(Br)c1',
#  'CCCCC[S+]([O-])CN(CC)C',
#  'O=C(Nc1ccccc1)c1cn(Cc2ccc(Br)cc2)nn1',
#  'Cn1cc(S(=O)(=O)Nc2ccc(Cl)cc2)n1',
#  'N#Cc1ccc(-c2cnc(-c3ccccc3)nc2)cc1',
#  'CCCCOc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'COC(=O)c1ccc(CSc2ccc(-n3ccnc3)nc2)cc1',
#  'Cc1ccsc1-c1ccncc1',
#  'O=C(Nc1ccc(Cl)cc1)N1CCN(Cc2ccc(Cl)cc2)C(N)=NN1',
#  'COc1ccc(CCn2ccnc2)cc1',
#  'O=C(CNc1ccc(Cl)cc1)c1ccc(N)cc1',
#  'COc1ccc(CSc2nc(-c3ccccc3)n[nH]2)cc1',
#  'COc1ccc(Br)cc1SSc1ccc(S(=O)(=O)NCc2ccccc2)c2ccccc12',
#  'O=c1c(-c2ccc(F)cc2)oc2ccccc12',
#  'COc1ccc(C(=O)N[C@@H](Cc2ccc(F)c(Cl)c2)c2ccccc2F)cc1',
#  'COc1ccc(-c2csc(NC(=N)N)c3)cc12',
#  'CCCCC/C(=N\\NC(N)=S)c1ccccc1',
#  'CCc1ccc(SCc2cnc(-c3ccc(Cl)cc3)nc2O)cc1',
#  'O=C(N/N=C/c1ccc(Br)cc1)N1CCN(Cc2ccccc2)CC1',
#  'COc1ccc(-c2cnc(-c3cccs3)nc2-c2ccccc2)cc1',
#  'CCCOc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'COc1ccc(-c2cc(C)nc(N)c2[N+](=O)[O-])cc1',
#  'O=P(O)(O)C(O)P(=O)(O)O',
#  'O=C(Nc1ccccc1)c1cn(Cc2ccc(Cl)cc2)nn1',
#  'COc1ccc(-c2ccc(-c3ccncc3)cc2)cc1',
#  'COc1ccc(/C=C/C(=O)c2cc(OC)c(OC)c(OC)c2)cc1OC',
#  'COc1ccc(-c2ccc(OC)c(OC)c2)cc1',
#  'Cl.NCC[C@H]1C[C@@H]2C[C@@]2C[C@H]12',
#  'O=C(Nc1ccccc1)c1nc(O)c([N+](=O)[O-])s1',
#  'CCCCOc1ccc(NC(=O)/C=C/c2ccc(OC)cc2)c(OC)c1',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)cc2)cc1O',
#  'O=C(Nc1ccccc1)c1nc(-c2ccc(F)cc2)nn1',
#  'COC1=CC(=O)N(Cc2ccc(F)cc2)C[C@@](c2ccc(Cl)cc2)C1',
#  'O=C(N/N=C/c1ccc(Cl)cc1)c1cccc(O)c1',
#  'COc1ccc(NC(=S)N/N=C/c2ccc(OC)cc2)cc1O',
#  'CCc1ccccc1-c1nc(N)nc(N)n1',
#  'COc1ccc(OC)c(C(=O)NCC2CC[C@@H]3C2=O)cc1',
#  'O=C(O)c1ccc(O)c(O)c1',
#  'Cn1c(=O)nc([N+](=O)[O-])c(Cl)c1Cl',
#  'CCCCCOc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'Cc1ccc(CNC(=S)N/N=C/c2ccco2)cc1',
#  'CCN(CC)CCNc1ccnc2cc(Cl)ccc12',
#  'C[C@]1(CCO)COc1ccc(/C=C/C(=O)c2ccc(OC)cc2)cc1OC',
#  'Cc1ccc(CCNCCCNC(=O)C2CCCCC2)cc1',
#  'COc1ccc(CSc2ccc(C(C)(C)C)cc2)cc1OC',
#  'Cc1ccc(-c2ccnc(NCCNC(=N)N)c2)cc1',
#  'CCCCCOc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'Cn1c(C#N)cc(C(=O)O)c2ccccc2c1=O',
#  'COc1ccc(-c2ccnc(NCCNC(=N)N)c2)cc1',
#  'COC(=O)CCC(=O)Nc1ccc(SCc2ccc(C)nc2)cc1',
#  'CCOC(CO)COc1ccc(Oc2ccc(C(C)(C)C)cc2)cc1',
#  'CCN(CC)CCNS(=O)(=O)O',
#  'CCCCC[S+]([O-])CCOc1ccc(Cl)cc1',
#  'COc1ccc(CCNC(=O)N/N=C/c2ccc(OC)cc2)cc1O',
#  'CCOC(=O)Nc1ccc(S(=O)(=O)Nc2ccc(Cl)cc2)cc1O',
#  'COc1ccc(/C=C/C(=N)N)cc1',
#  'C=CCOC(=O)OCC(Cc1ccccc1)P(=O)(O)O',
#  'CCCCCCCOc1ccc(/C=N/NC(N)=S)cc1',
#  'CCOCOC(=O)c1ccc(NC(=O)CSCC(=O)NCCNC(=O)Nc2ccc(C(F)(F)F)cc2)c2ccccc2n1',
#  'COC(=O)CCCCCCOc1ccc(C(=O)O)cc1',
#  'CCN(CC)CCNc1ccnc2cc(Cl)ccc12',
#  'CCc1cc(OC)ccc1NC(=O)CSc1nc2ccccc2nc1N',
#  'COc1ccc(/C=N/NC(N)=S)cc1',
#  'CCOc1ccc(/C=C/C(=O)c2cc(O)c3ccccc3nc2N)cc1',
#  'Cc1cc(-c2ccc(C#N)cc2)nc2[nH]ccc12',
#  'COc1ccc(CSc2nc(-c3ccc(Cl)cc3)nc2O)cc1',
#  'O=C(CNc1cccnc1)c1ccc(O)cc1',
#  'COc1ccc(NC(=O)CSc2ncc(Cl)nc2O)cc1',
#  'O=P(O)(O)C(Cc1ccccc1)N/N=C/c1ccc([N+](=O)[O-])o1',
#  'COc1ccc(/C=C/C(=N)N)cc1',
#  'COc1ccc(-c2cnc(-c3ccc(Cl)cc3)nc2N)cc1',
#  'O=C(Nc1ccc(Br)cc1)N1CCN(Cc2ccc(Cl)cc2)CCN1',
#  'CN(C)CC/C=C/C1=C(C)C(C)CCO1',
#  'CCOC(=O)c1cn(C(C)C)c2ccccc2c1=O',
#  'COc1ccc(-n2cnc(N)c2)cc1',
#  'COC(=O)CCCCOc1ccc(-c2ccc(-n3ccnc3)cs2)cc1',
#  'COc1ccc(SCc2ccc(NC(=N)N)cc2)cc1',
#  'CCC/C(=N\\NC(N)=S)c1ccccc1',
#  'O=C(Nc1ccccc1)c1ccc([N+](=O)[O-])cc1',
#  'O=C(Nc1ccccc1)c1ccc(-c2ccc([N+](=O)[O-])o2)cc1',
#  'COc1ccc(OCCNCC(=O)N/N=C/c2cccc(I)c2)cc1O',
#  'CCOC(=O)c1ccc(C(=O)OCCc2ccc(OC)c(OC)c2)cc1',
#  'COc1ccc(-c2ccc(-c3cccnc3)cc2)cc1',
#  'COc1ccc(-c2nc(-c3ccc(Cl)cc3)[nH]nc2N1',
#  'COc1ccc(/C=C/C(=O)c2c(O)c(O)c(O)c(O)c2[N+](=O)[O-])cc(C)c1',
#  'COc1ccc(-c2nc3[nH]cnc3nc2-c2ccccc2Br)s1',
#  'CCOC(=O)/C=C/C(=O)c1ccc(-c2cccc(Cl)c2)o1',
#  'Cn1cc(-c2cccc(C#N)c2)nc1C',
#  'COc1ccc(CSc2nnc(-c3ccc(Cl)cc3)nn2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(SCn2ccnc2)cc1',
#  'O=C(Nc1ccccc1)N1CCSCC1',
#  'O=C(Nc1ccccc1)c1ccc(Cl)cc1Cl',
#  'Cn1ccc(CCCc2ccc(-c3cccnc3)n2)cc1',
#  'CCCCCCCCOCCSCCCCCNC(=O)/C=C/c1ccc([N+](=O)[O-])o1',
#  'Cc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'COc1ccc(-c2csc(-c3cccnc3)n2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(Br)cc1',
#  'O=C(Nc1ccc(Cl)cc1)S(=O)(=O)c1cccc([N+](=O)[O-])c1',
#  'O=P(O)(O)C(CO)O',
#  'COc1ccc(-c2ccc(OC)c(OC)c2)cc1',
#  'COc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'COc1ccc(CSc2ncc(C#N)nc2N)cc1',
#  'CCCCCCCCOc1ccc(-c2ccnc(C(=O)N/N=C/c3ccc(OC)cc3)cc2OC)c1',
#  'COc1ccc(CSc2ncc(-c3ccc(Cl)cc3)nc2[N+](=O)[O-])cc1',
#  'CCCOC(=O)/C=C/C(=O)OCC(C)=O',
#  'COc1ccc(-c2ncc(-c3ccc(Cl)cc3)nc2N)cc1',
#  'CCN(CC)CCCCCNC(=O)O',
#  'O=C(CSc1nnc(-c2ccccc2)n1)c1ccccc1',
#  'CCOC(=O)c1cccc(NC(=O)CSc2ccc(-n3ccnc3)nc2)c1',
#  'COc1ccc(-c2cn(Cc3ccc(Cl)cc3)nn2)cc1',
#  'O=C(Cc1ccccc1)N1CCN(c2ccc(F)cc2)CC1',
#  'O=C(O)c1ccc(-c2ccc(-n3ccnc3)o2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)N1CCN(Cc2ccccc2)CC[C@@]1',
#  'N#C/C(=N\\NC(N)=S)c1ccccc1',
#  'O=C(Nc1ccc(Cl)cc1)N1CCC[C@@](O)(Cc2ccccc2)C1',
#  'C[C@@H](O)CC(Cc1ccccc1)P(=O)(O)O',
#  'C[S+]([O-])c1ccc(SCc2ccc(C(=O)O)cc2)cc1O',
#  'CCCCCCOc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'COC(=O)c1ccc(S(=O)(=O)Nc2ccc(-c3ccc(C#N)cc3)nn2)cc1',
#  'CN(CC)Sc1nnc(N)n1',
#  'O=C(Nc1ccccc1)C1=C(c2cccs2)CC=C1',
#  'O=C(Nc1ccccn1)N1CCN(Cc2ccc(Cl)cc2)CC1',
#  'CCN(CC)CCNC(=O)Nc1ccc(S(=O)(=O)Nc2ccc(Cl)cc2)cc1Cl',
#  'Clc1ccc(-c2nc(-c3ccccc3)o2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)Nc1ncc[nH]1',
#  'COc1ccc(-c2ccn(Cc3ccc(Cl)cc3)nc2N)cc1',
#  'COc1ccc(-c2csc(-c3cccnc3)c2)cc1',
#  'COc1ccc(C(=O)NCCCNC(=O)NCc2ccccn2)cc1',
#  'CCN(CC)CCNC(=O)c1ccc(OC)cc1',
#  'COc1ccc(CNC(=O)/C=C/c2ccc(OC)cc2)cc1O',
#  'Cl.O=C(O)CSc1nc2ccccc2nc1-c1ccccc1',
#  'CCC/C(=N\\NC(N)=S)c1ccccc1',
#  'COc1ccc(OCCOCCn2ccnc2)cc1',
#  'Cc1ccc(NC(=S)NCCc2c[nH]c3ccccc3c2)cc1',
#  'CCCOc1ccc(-c2ccc(-c3ccc(C)[nH]c23)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(Cl)cc1Cl',
#  'O=C(CNc1nc2ccc(Cl)cc2s1)c1ccccc1',
#  'CCCCCCOC(=O)CSCC(=O)N[C@H](Cc1ccc(Cl)cc1)n1ccnc1',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)c(OC)c2)cc1OC',
#  'COc1ccc(-c2cnc(-n3ccnc3)no2)cc1',
#  'COc1ccc(CSc2nnc(C(=O)NC(C)C)s2)cc1',
#  'O=C(NCCc1ccc(O)cc1)OCCO',
#  'COc1ccc(-c2cn(Cc3cccc(Cl)c3)[nH]c2=O)cc1',
#  'CCCCCCCCCOCOC1=C(F)C(F)F',
#  'COc1ccc(-c2ccc(-n3ccnc3)nc2O)cc1',
#  'CCN(CC)CCSc1nc2ccccc2[nH]1',
#  'C[C@@H]1O[C@@H](O)[C@H](O)O[C@H]1C[C@@H](O)OO',
#  'COc1ccc(-c2csc(-c3cccnc3)c2)cc1',
#  'O=C(Nc1ccccc1)c1ccc(-c2ccc(O)cc2)o1',
#  'Cl.N[C@H](Cc1ccc(O)c(O)c1)N1CCN(Cc2ccc(F)cc2)CC1',
#  'O=C(O)c1ccc(O)c(O)c1',
#  'CCCCC/C(=N\\NC(N)=S)c1ccc(F)cc1',
#  'COc1ccc(-c2ccc(-c3cccnc3)cc2)cc1',
#  'O=C(N/N=C/c1ccc(F)cc1)N1CCCC[C@@]1',
#  'O=C(Nc1cccc(Cl)c1)c1ccc(-c2ccc(Cl)cc2)o1',
#  'Cn1c(O)nc(-c2ccc(Cl)cc2)s1',
#  'N#Cc1ccc(-c2ccc(-n3ccnc3)nn2)cc1',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)c(OC)c2)cc1O',
#  'COc1ccc(-c2ccc(-n3ccnc3)nn2)cc1',
#  'CCN(CC)CCNc1ccnc2cc(Cl)ccc12',
#  'COc1ccc(/C=C/C(=O)c2ccc(C)cc2)cc1OC',
#  'Cc1ccc(-c2cn(CCNCCCCN3CC3)nc2N)cc(C)c1',
#  'Nc1nc2ccccc2nc1-c1ccccc1',
#  'COc1ccc(C(=O)N/N=C/c2ccc(-c3cccc(O)c3)cc2)cc1',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)c(OC)c2)cc1O',
#  'CCc1ccc(C(=O)O)cc1',
#  'O=C(O)/C=C/c1ccc([N+](=O)[O-])o1',
#  'Cl.O=C(O)CCCCCB=S',
#  'S=C(N/N=C/c1ccc([N+](=O)[O-])o1)c1ccccc1',
#  'CCN(CC)CCNC(=O)OCCCCO',
#  'O=C(Nc1ccccc1)c1cn(Cc2ccc(Cl)cc2)c2ccccc2c1Cl',
#  'COc1ccc(NC(=S)N/N=C/c2ccc(-n3ccnc3)cc2)cc1',
#  'COc1ccc(/C=N/NC(N)=S)cc1',
#  'CCOC(=O)OCc1ccc(CNC(=O)/C=C/c2ccc(OC)cc2)cc1O',
#  'O=C(Nc1ccccc1)Nc1ccc(Cl)cc1',
#  'COc1ccc(CNCCCNC(=O)CSCc2ccc(-n3ccnc3)cc2)cc1',
#  'O=C(NCCCNc1cnc(-c2ccccc2)c2ccccc12)N1CCCCCC1',
#  'COc1ccc(Sc2nc(-c3cccs3)onc2N)cc1',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccc(Cl)cc2)CC1',
#  'COC(=O)CCCc1cc(O)c(O)c(O)c1',
#  'CCCCCCCCCCCCCCCC/C=C/C(=O)O',
#  'CCCOc1ccc(-c2ccnc(-c3ccccc3)n2)cc1',
#  'O=C(c1ccc(Cl)cc1)N1CCN(c2ccc(Cl)cc2)CC1',
#  'Cn1cc(-c2ccc(C#N)cc2)nc1N',
#  'Cc1ccc(CNCCc2ccc(OC)cc2)cc1',
#  'O=C(Nc1ccccc1)c1cn(Cc2ccc(F)cc2)c2ccccc2c1=O',
#  'CCOC(=O)CCCc1ccc(O)cc1',
#  'CN(CC)CCCNC(=O)NCCCC[C@H](Cc1ccccc1)C(Cl)=O',
#  'O=C(Nc1ccc(Cl)cc1)N1CCN(c2ccc(F)cc2)C[C@H]1Cc1ccccc2c1',
#  'COc1ccc(C(=O)OCCCNC(=O)NCCCCSP(=O)(O)O)c1',
#  'O=C(O)c1ccc(Br)cc1',
#  'COc1ccc(/C=C/C(=O)c2cc(OC)c(OC)c(OC)c2)cc1OC',
#  'CCCCCCC/C=C/C(=O)O',
#  'COc1ccc(CNCCCCNC(=O)c2cc(O)c3ccccc3nc2[N+](=O)[O-])cc1',
#  'CCCC[C@@H]1O[C@@H](O)[C@@H](O)O[C@H](CO)OCO',
#  'Clc1ccc(-c2csc(Nc3cccnc3)c2)cc1',
#  'O=C(Nc1ccccc1)c1nc(-c2ccccc2)nn1',
#  'COc1ccc(-c2cnc(-c3ccncc3)nc2-c2ccccc2)cc1',
#  'Cc1ccc(CSc2cc(C)nc(N)c2-c2ccc(Cl)cc2)cc1',
#  'CCC1=CC[C@@](C#N)C(C)C1',
#  'COc1ccc(CCNCCc2cnc(-c3ccc(F)cc3)nc2)cc1',
#  'N#Cc1ccc(Oc2ccc(C(F)(F)F)cc2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(-c2ccc(Cl)cc2)o1',
#  'N#Cc1ccc(NC(=S)N/N=C/c2cccnc2)c2ccccc12',
#  'COc1ccc(SCc2cn(Cc3ccc(Cl)cc3)nc2N)cc1',
#  'O=P(O)(O)C(Cc1ccc(Br)cc1)N1CCN(Cc2ccc(Br)cc2)CC1',
#  'O=C(CNc1ccc(Cl)cc1)c1ccc(Cl)cc1Cl',
#  'Clc1ccc(-c2cnc(NCCNC(Cc3ccccc3)n3)cc2s1',
#  'COc1ccccc1CNc1ccnc2cc(Cl)ccc12',
#  'COc1ccc(-c2csc(NCCNC(=N)N)c2)cc1',
#  'CCN(CC)CCCNc1ccnc2cc(Cl)ccc12',
#  'Cn1cc(C(=O)O)nc1N',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(Br)cc1',
#  'COc1ccc(SCc2ccc(C(=O)OC)c(C)c2)cc1',
#  'COC(=O)CSc1nnc(C(=O)Nc2ccc(C#N)cc2)n1',
#  'COc1ccc(-c2csc(-c3ccc(C#N)cc3)n2)cc1',
#  'O=C(Nc1ccccc1)N1CCN(c2ccc(Cl)cc2)CCO1',
#  'O=C(Nc1cccc(Cl)c1)Nc1ccnc2ccccc12',
#  'COc1ccc(-c2csc(-c3ccc(Cl)cc3)n2)cc1',
#  'COc1ccc(-c2cn(CCNCCN3CCC3)nn2)ccc1',
#  'O=C(Nc1ccccc1)N1CCN(c2ccc(Cl)cc2)CC=C1',
#  'Fc1ccc(-c2cn[nH]n2)cc1',
#  'CCCCCCCCCCCCCCCC[C@]1(C)[C@@H](C)[C@@H](C)[C@H](C)C[C@@H]1O[C@@H](CO)O',
#  'CCCCOC(=O)N1SC(C(=O)O)C(C)CN(CC)CCCCC1',
#  'CCCCOC(=O)N1SC(=S)N/N=C/c2ccc(F)cc2)CC1',
#  'O=C(N/N=C/c1ccc([N+](=O)[O-])o1)c1ccccc1',
#  'COc1ccc(-c2ccc(C(=O)O)o2)cc1',
#  'COc1ccc(CNCc2ccc(-n3ccnc3)cc2)cc1',
#  'CCOC(=O)OCCOc1ccc(-c2ccc(-c3ccc(Cl)cc3)nc2)cc1',
#  'O=C(COc1ccccc1)Nc1ccc(Br)cc1',
#  'O=C(O)c1ccc([C@@H](CO)O)cc1',
#  'COc1ccc(NC(=O)c2ccc(OC)c(OC)c2)cc1O',
#  'COc1ccc(CSc2ccc(NC(=O)/C=C/c3ccc(OC)c(OC)c3)nc2N)cc1',
#  'Cc1ccc(CCC(=O)O)cc1',
#  'COc1ccc([C@@H](CO)/C=C/c2ccc(OC)c(OC)c2)cc1',
#  'CCOC(=O)c1ccc(N)cc1',
#  'Cl.O=[N+]([O-])c1ccc(NCCc2ccc(-c3cccnc3)cc2)o1',
#  'CCOC(=O)c1cn(Cc2ccc(Cl)c(Cl)c2)nn1',
#  'COc1ccc(SCc2ccc(-c3cccnc3)cc2)cc1',
#  'O=C(O)c1ccc(SCc2ccc(-c3cccnc3)o2)cc1',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)cc2)cc1O',
#  'COC(=O)CCC(=O)Nc1ccc(NC(=S)N/N=C/c2ccc(OC)cc2)cs1',
#  'CCCCCCCCCCc1cc(O)c(O)c(/C=N/NC(N)=S)c1',
#  'O=C(Nc1cccc(Cl)c1)c1ccc(N)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1cccc(Cl)c1',
#  'COc1ccc(/C=C/C(=N)N)cc1',
#  'COc1ccc(-c2cnc(-c3ccc(Cl)cc3)nc2O)cc1',
#  'Clc1ccc(-c2csc(-c3cccnc3)c2)cc1',
#  'O=P(O)(O)C(CCc1ccccc1)N1CCN(Cc2ccc(F)cc2)CCO1',
#  'O=P(O)(O)C(CO)O',
#  'O=C(Nc1ccc(-c2ccc(O)cc2)n1)N1CCN(Cc2ccccc2)CC1',
#  'CCCCCCCC/C=C/C(=O)O',
#  'O=C(Nc1ccccc1)c1ccc([N+](=O)[O-])cc1',
#  'COc1ccc(-c2nnc(-c3ccccn3)nc2)cc1',
#  'CCCCCCCCCOc1ccc(-c2ccc(-c3cccnc3)cc2)cc1',
#  'O=C(O)c1cccc(OCCNCCc2ccc([N+](=O)[O-])o2)c1',
#  'Cc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'Clc1ccc(-c2ccnc(Nc3ccccc3)n2)cc1',
#  'Clc1ccc(-c2csc(-c3cccnc3)c2)cc1',
#  'O=P(O)(Nc1ccccc1)N1CCN(Cc2ccc([N+](=O)[O-])cc2)CC1',
#  'CCCCCCCOC(=O)/C=C/C(=O)c1ccc(Cl)cc1',
#  'COc1ccc(/C=C/C(=N)N)cc1',
#  'O=C(Nc1cccnc1)c1ccc(-c2cccs2)cc1',
#  'Cc1ccc(Oc2ccc(-c3ccncn3)cc2)cc1',
#  'COc1ccc(/C=N/NC(N)=S)cc1',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccccc2)C(=O)N1',
#  'COc1ccc(C(=O)/C=C/c2ccc(OC)cc2)cc1O',
#  'O=C(Nc1ccccc1)c1ccc(Cl)cc1Cl',
#  'O=C(Nc1ccc(Br)cc1)c1ccc(N)cc1',
#  'O=C(Nc1ccccc1)c1ccc(Cl)cc1Cl',
#  'CCCCCOC(=O)CC(=O)Nc1ccc(NC(=S)N/N=C/c2ccc(Cl)cc2)c(O)c1',
#  'COc1ccc(SCc2ccc(C(=O)OC)cc2)cc1OC',
#  'CCN(CC)CCCNc1ccnc2cc(Cl)ccc12',
#  'CCOC(=O)/C=C/c1ccc([N+](=O)[O-])o1',
#  'O=C(Nc1cccc(Cl)c1)c1ccc([N+](=O)[O-])o1',
#  'N#Cc1ccc(Oc2ccc(-c3cccnc3)nc2)cc1',
#  'COc1ccc(CCCCNCCCNCCNCCNCCCNCCCNCCCNCCNCCNCCCN)c2ccc(Cl)cc2n1',
#  'CCCCCCCCCOc1ccc(C(=O)/C=C/c2ccc([N+](=O)[O-])cc2)o1',
#  'O=C(Nc1ccc(Cl)cc1)N1CCCCC1',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)c(OC)c2)cc1O',
#  'COC(=O)c1ccc(Nc2ccc(C(F)(F)F)cc2F)cc1',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccccc2)C(=O)N1',
#  'COc1ccc(CNCCCCNCCNCCCNC(=O)c2ccc(OC)c(OC)c2)cc1',
#  'O=P(O)(O)C(N)C(Cc1ccccc1)c1ccccc1',
#  'COc1ccc(NC(=O)CNC(=O)CSCc2ccc(Br)cc2)cs1',
#  'CCCCCCCCCOc1ccc(C(=O)O)cc1SSCCn1ccnc1',
#  'CC(C)n1cnc(N)c1C(C)=O',
#  'COc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'COc1ccc(NC(=S)N/N=C/c2ccc(OC)cc2)cc1O',
#  'COc1ccc(C(=O)NCCCNC(=S)N/N=C/c2ccc(OC)cc2)cc1O',
#  'COc1ccc(-c2csc(-c3ccncc3)n2)cc1',
#  'COC(=O)/C=C/C(=O)c1ccc(-c2ccccc2)o1',
#  'CCCCCCCOCCOc1ccc(C(=O)N/N=C/c2ccc(C#N)cc2)cc1',
#  'O=C(Nc1cccc(Cl)c1)c1ccc(O)cc1',
#  'O=C(/C=C/c1ccc([N+](=O)[O-])o1)c1ccc(O)cc1',
#  'COc1ccc(-c2csc(-c3cccnc3)c2)cc1',
#  'COc1ccc(SCc2ccc(C(=O)OC)c(OC)c2)cc1',
#  'COc1ccc(CCc2ccc(-c3ccc(OC)cc3)nc2O)cc1',
#  'O=C(Nc1ccnc2cc(Cl)ccc12)c1ccc(F)cc1',
#  'CSc1nnc(N)c(N)c1',
#  'O=P(O)(O)OCC(CCO)O',
#  'ClCOC1=CCc2ccc(F)cc2F)c2ccccc12',
#  'O=C(Nc1ccc([N+](=O)[O-])cc1)N1CCN(Cc2ccc(Cl)cc2)CC1',
#  'O=P(O)(O)C(Cc1ccccc1)N1CCN(Cc2ccc(F)cc2)CCC1',
#  'COc1ccc(SCc2ccc(C)nc2)cc1',
#  'CC1=CCCN1C(=O)C(CC)NC(=O)O',
#  'CCCCCOc1ccc(-c2ccc(-n3ccnc3)nc2-c2ccccc2)cc1',
#  'CCCCNC(=O)Nc1ccc(-c2ccc(-c3cccnc3)cc2)cc1',
#  'CCCOC(=O)CC(=O)N[C@H](Cc1ccc(Cl)cc1)N1CCN(Cc2ccccc2)CC1',
#  'O=C(Nc1ccccc1)N1CCN(c2ccc(F)cc2)CCO1',
#  'COc1ccc(CNCCc2ccc(OC)c(OC)c2)cc1',
#  'COc1ccc(NC(=S)N/N=C/c2ccc([N+](=O)[O-])o2)cc1',
#  'COC(=O)CCC(=O)Nc1ccc(CSc2ccc(C#N)cc2)cc1',
#  'COc1ccc(/C=C/C(=N)N)cc1',
#  'COc1ccc(SCC(=O)Nc2ccc(C(=O)O)cc2)cc1OC',
#  'CCCCCCCOc1ccc(C(=O)O)cc1',
#  'CN(CC)n1ccnc1',
#  'COc1ccc(-c2csc(-c3ccc(C#N)cc3)nc2)cc1',
#  'COC(=O)Cc1c[nH]c2ccccc12',
#  'O=C(Nc1ccccc1)c1nc(-c2ccccc2)oc1=O',
#  'COc1ccc([C@@H](CO)COCCCNCCCNCCCNC(=O)CSCc2ccc(Cl)cc2)cc1',
#  'COc1ccc(-c2cnc(-c3cccnc3)nc2O)cc1',
#  'O=C(Nc1ccccc1)N1CCOC[C@H]1CC(Cc1ccccc1)OCCc1ccccc1',
#  'COC(CO)OC(Cc1ccccc1)P(=O)(O)O',
#  'COc1ccc(/C=N/NC(N)=S)cc1',
#  'COc1ccc(-c2nsc(-c3cccc(Cl)c3)nc2)cc1',
#  'CCc1ccc(Oc2ccc(C)cc2)cc1',
#  'Clc1ccc(CSc2ccc(Cn3ccnc3)cc2)cc1',
#  'COc1ccc(C(=O)/C=C/C(=O)/C=C/c2ccc3ccccc3c2[N+](=O)[O-])ccc1',
#  'COc1ccc(/C=C/C(=N)N)cc1',
#  'O=C(Nc1ccccc1)N1CCOC[C@H]1Cc1ccccc1',
#  'O=[N+]([O-])c1ccc(SCCNc2nccc(-c3ccccc3)c2)cc1',
#  'CCCCCCCOCc1ccc(OC)cc1',
#  'CCCCCCCNC(=O)Nc1ccnc2cc(F)ccc12',
#  'CCCCCn1ccnc1',
#  'CCc1ccc(Oc2ccc(C)cc2)cc1',
#  'O=[N+]([O-])c1ccc(-c2cn[nH]nc2)c1',
#  'C[C@@H](O)Oc1ccc(-c2csc(Nc3ccncc3)n2)cc1',
#  'COc1ccc(/C=N/NC(=O)c2ccc(OC)c(OC)c2)cc1OC',
#  'COc1ccc(C(=O)OCC(C)=O)cc1OC',
#  'O=C(Nc1cccnc1)N1CCN(Cc2ccc(Cl)cc2)CC1',
#  'COc1ccc(-c2csc(-c3ccc(Cl)cc3)n2)cc1',
#  'O=C(Nc1cccc([N+](=O)[O-])c1)N1CCC[C@@](Cc2ccccc2)C1',
#  'O=C(O)c1ccc(-c2ccc(-n3ccnc3)o2)cc1',
#  'CN(C)c1ccc(S(=O)(=O)Nc2ccc(C#N)cc2)cc1',
#  'N#CC(=O)c1ccc(-c2ccc(Cl)cc2)o1',
#  'CCCCCOc1ccc([C@H](CO)P(=O)(O)O)cc1',
#  'Cl.NCCOc1ccc(-c2ccc(-c3ccccc3)nc2)cc1',
#  'O=C(Nc1ccccc1)N1CCCN1',
#  'COc1ccc(/C=C/C(=O)/C=C/c2ccc(OC)cc2)cc1O',
#  'O=C(N/N=C/c1ccc([N+](=O)[O-])o1)c1ccc(-c2ccccc2)o1',
#  'COc1ccc(Br)cc1S(=O)(=O)Nc1ncc(Br)c2c(-c3ccccc3)oc2c1',
#  'COc1ccc(NC(=O)CSCCc2ccc(-c3ccc(C)nc3)cc2)cc1',
#  'COc1ccc(CSc2nc(-c3ccc(Cl)cc3)nnc2N)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1cn(CC(CCCN)Cc2ccc(Br)cc2)CCO1',
#  'COc1ccc(-c2csc(NC(=N)N)c2)cc1',
#  'CCN(CC)CCNC(=O)N1CCC[C@@]1',
#  'COc1ccc(-c2nc(-c3ccc(Cl)cc3)nc2OC)cc1',
#  'COc1ccc(-c2ccnc(/C=C/NC(=O)/C=C/c3ccccc3)cc(C)c2OC)cc1',
#  'COc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'O=C(Nc1ccccn1)N1CCC[C@H]1O',
#  'O=C(NCCc1cscc1)C1CCCCC1',
#  'CCCOC(CO)(Cc1ccccc1)C(=O)Nc1ccc(Cl)cc1Cl',
#  'CCOC(=O)CCc1ccc(-c2ccc(-n3ccnc3)nc2)cc1',
#  'CCCCCCCCCCSc1nc2ccccc2[nH]1',
#  'CCCCC[C@H]1C[C@@H](O)[C@H](Cc2ccc(Cl)cc2)C[C@H]1O',
#  'COC(=O)c1c[nH]c2ccccc12',
#  'CCCCCCCCCC=CCCCCCCCCCc1ccc(O)c(O)c1',
#  'COc1ccc(/C=C/C(=O)NCCNC(=O)/C=C/c2ccccc2)cc1O',
#  'O=C(Nc1ccc(Br)cc1)c1ccc(Cl)cc1Cl',
#  'Cl.NC[C@@H]1COC1',
#  'COc1ccc(-c2nc(-c3cccs3)nc(N)nc23)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(Cl)cc1Cl',
#  'CCCOC(=O)c1ccc(SCc2ccc(-c3ccc(O)c(O)c3)cc2)cc1',
#  'COc1ccc(-c2nc(-c3ccc(Cl)cc3)no2)cc1',
#  'S=C(N/N=C/c1ccc([N+](=O)[O-])o1)c1ccccc1',
#  'COc1ccc(-c2nc(-c3ccc(Cl)cc3)n[nH]2)cc1',
#  'O=C(NCc1ccc(Cl)cc1)c1ccc(Br)cc1',
#  'CCCCCCC/C=C/C(=O)OCc1ccccc1',
#  'COc1ccc(OC)c(C(=O)/C=C/c2ccc(OC)cc2)c1O',
#  'Cc1ccc(-c2nc(-c3ccccc3)s2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1nc2ccccc2[nH]1',
#  'CSc1nnc(C(=O)Nc2ccc(Cl)cc2)n1',
#  'CCCCCC[S+]([O-])c1ccc(NC(=N)N)cc1',
#  'CCCOc1ccc(-c2ccc(C(=O)O)cc2)o1',
#  'COc1ccc(-c2ccc(-n3ccnn3)nc2)cc1',
#  'S=C(N/N=C/c1ccc([N+](=O)[O-])o1)c1cccc(O)c1',
#  'COc1ccc(SCc2ccc(CCNC(=O)NCc3ccc(Cl)cc3)nc2)cc1',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccc(F)cc2)CC1',
#  'C[C@]1(CCNC(=O)O)[C@H](Cc2ccc(Cl)cc2)C(=O)N1',
#  'CCCCOc1ccc(-c2cnc(-c3ccc(Cl)cc3)c(=O)[nH]2)cc1',
#  'COc1ccc(-c2nnc(-c3cccc(Cl)c3)nc2O)cc1',
#  'O=C(Nc1ccc2ccccc2c1)N/N=C/c1ccc(Cl)cc1',
#  'CCOC(=O)CCCSCCCOCc1ccc(O)c(O)c1',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)c(OC)c2)cc1O',
#  'O=C(N/N=C/c1ccc([N+](=O)[O-])o1)c1ccccc1',
#  'CCCCCOc1ccc(Cn2ccnc2)cc1',
#  'CCCCOC(=O)/C(=C\\c1ccc(F)cc1)C(=O)O',
#  'CCOC(=O)c1ccc(SCc2ccc(C)cc2)cc1',
#  'Cc1ccc(NC(=S)N/N=C/c2ccc([N+](=O)[O-])o2)cc1',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccc(Cl)cc2)CC1',
#  'Cl.Nc1ccc(Cl)cc1C(Cl)(Cl)Cl',
#  'COc1ccc(-c2ccc(-n3ccnc3)nc2[N+](=O)[O-])cc1',
#  'CCC1=CC[C@H](CSc2ccc(-c3ccc(C#N)cc3)C2)CC1',
#  'Clc1ccccc1CNc1ccnc2cc(O)ccc12',
#  'O=[C@@H]1O[C@@H](O)[C@@H](O)OC[C@H]1O',
#  'COc1ccc(NC(=S)N/N=C/c2ccc(C#N)cc2)cc1',
#  'CCN1CC[C@H](O)[C@@H]1O',
#  'O=C(Nc1ccccc1)c1ccc(-c2ccc3ccccc3nc2)cc1',
#  'CC(C)OC(=O)OCc1ccc(-c2ccc([N+](=O)[O-])o2)cc1',
#  'COc1ccc(S(=O)(=O)Nc2ccc(C(=O)O)cc2)cc1O',
#  'COc1ccc(-c2ccnc(NS(=O)(=O)NCc3ccc(Cl)cc3)nc2N)c1',
#  'COc1ccc(CNC(=S)N/N=C/c2ccc(OC)cc2)cc1O',
#  'CN(CC)CCCNc1ccnc2cc(Cl)ccc12',
#  'O=P(O)(O)CCCCSc1nc2ccccc2[nH]1',
#  'CCCCCCCCCCCCOC(CNC(=O)O)CSSc1nc2ccccc2nc1N',
#  'COc1ccccc1CNCCO',
#  'COc1ccc(-c2ccc(-c3cccnc3)cc2)cc1',
#  'CCn1c(=O)n(Cc2ccc(Cl)c(Cl)c2)nn1',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccc(F)cc2)C(=O)N1',
#  'CCCCC/C=C/C(=O)O',
#  'O=C(CNc1ccc(Cl)cc1)N1CCC(O)C1',
#  'O=C(Nc1ccncc1)c1ccc(-c2ccccc2)cc1',
#  'CCCCCCCCOc1ccc(CNC(=O)/C=C/c2ccc(OC)cc2)cc1O',
#  'COc1ccc(NC(=O)CSc2ccc(-n3ccnc3)nc2)cc1',
#  'CCCCCC[C@H]1CC[C@H](Cc2ccc(-c3ccccc3)C2)C1',
#  'Cc1ccc(S(=O)(=O)Nc2ccc(-c3cccnc3)cc2)cc1',
#  'COc1ccc(C(=O)/C=C/c2ccc(N)c(C(=O)O)c2)cc1',
#  'CCCCOC(=O)/C=C/c1ccc(Cl)cc1Cl',
#  'O=C(O)c1ccc(-c2ccc(-n3ccnc3)o2)cc1',
#  'O=C(NCCc1csc(-c2ccccc2)n1)c1ccccc1',
#  'COc1ccc(-c2ccc(OC)c(OC)c2)cc1',
#  'O=C(Nc1ccccc1)c1ncc(-c2ccccc2)o1',
#  'COc1ccc(C(=O)N[C@@H](COCCNC(=O)NO)cc2nnc(-c3ccccc3)nc2)c1',
#  'COc1ccc(-c2ccc(-n3ccnc3)nc2)cc1',
#  'COC(=O)/C(=C\\c1ccc(Cl)cc1Cl)N1CCCCC1',
#  'CC(C)OC(=O)c1ccc2ccccc2c1O',
#  'Cn1ccc(CSCCNC(=O)CSCc2ccc(Cl)cc2)n1',
#  'COc1ccc(-c2nc(-c3ccccc3)n[nH]2)cc1',
#  'Clc1ccc(-c2csc(-c3cccnc3)c2)cc1',
#  'COc1ccc(CSc2nc(-c3cccs3)oc2-c2ccccc2)cc1',
#  'COCc1cc(C)ccc1NC(=O)CSc1ncc[nH]1',
#  'Clc1cccc(-c2csc(-c3cccnc3)c2)c1',
#  'O=C(Nc1ccccc1)c1ccc([N+](=O)[O-])cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1ncc(Cl)s1',
#  'O=C(Nc1ccc(Cl)cc1)N1CCN(c2ccc(F)cc2)CCN1',
#  'COCOC(=O)CSc1nc(N)nc(N)c1N',
#  'O=C(/C=C/c1ccc(-c2ccccc2)s1)c1cccc(Cl)c1',
#  'COc1ccc(-c2csc(-c3ccc(Cl)cc3)n2)cc1',
#  'COc1ccc(-c2ccc(-c3ccncn3)nc2)cc1',
#  'O=C(Nc1cccnc1)c1ccc(Cl)cc1',
#  'COC(=O)/C=C/c1ccc2ccccc2c(=O)n1',
#  'C[C@@H]1O[C@@H](O)[C@H](O)[C@@H]1O',
#  'Cl.N[C@@H]1CCOC1',
#  'O=C(Nc1ccc(Br)cc1)N1CCN(c2ccc(F)cc2)CC1',
#  'O=C(Nc1nc2ccccc2s1)c1ccccc1',
#  'COc1ccc(C(=O)/C=C/c2ccc([N+](=O)[O-])cc2)cc1OC',
#  'O=C(Nc1ccc(Br)cc1)N1CCC[C@@](O)=O1',
#  'COc1ccc(-c2csc(-c3cccnc3)c2)cc1',
#  'COc1ccc(CNCCn2ccnc2)cc1',
#  'C[C@@H]1[C@@H](O)[C@H](CO)[C@H](O)[C@H](O)[C@H](Cc2ccc(O)c(O)c2)C[C@H]1C(=O)O',
#  'COc1ccc(CNCCc2ccc(OC)c(OC)c2)cc1',
#  'Brc1ccc(CSc2ccc(-n3ccnc3)cc2)cc1',
#  'COc1ccc(CSc2nnc(-c3ccc(Cl)cc3)nn2)cc1',
#  'COc1ccc(CNCCc2ccc(OC)c(OC)c2)cc1',
#  'CN(CC)CCCNc1cnc2ccccc12',
#  'COc1ccc(-c2csc(-c3cccnc3)c2)cc1',
#  'COc1ccc(C(=O)/C=C/c2ccc(OC)cc2)cc1O',
#  'CCCOC(CO)(CO)C1=CC(=O)CSC[C@H]1C(=O)Nc1ccnc2cc(Cl)ccc12',
#  'COc1ccc(NC(=O)c2cc(OC)c(OC)c(OC)c2)cc(C)c1',
#  'Cc1ccc(CNCc2ccc(OC)c(OC)c2)cc1',
#  'O=C(O)c1cccc(SCc2ccc(Cl)cc2)c1',
#  'Clc1ccccc1-c1nc2ccccc2nc1-c1ccccc1',
#  'Clc1ccc(-c2ncc(-c3ccccc3)nc2)cc1',
#  'O=C(CNc1ccc(Cl)cc1)N1CCN(c2ccc(Cl)cc2)C(=O)N1',
#  'C#Cc1ccc(Oc2ccc(-c3ccc(O)c(O)c3)cc2)cc1',
#  'COC(=O)c1c[nH]c2ccc(Cl)cc12',
#  'COc1ccc(-c2nc3ccccc3[nH]2)cc1',
#  'CCCCCCNCCC[C@H](Cc1ccccc1)P(=O)(O)O',
#  'O=P(O)(O)C(O)O',
#  'O=C(O)c1cccc(/C=N/NC(N)=S)c1',
#  'COc1ccc(CSc2nc(-c3ccc(Cl)c(Cl)c3)cc2OCl)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1cn(Cc2ccc(Cl)cc2)c2ccccc2c1Br',
#  'O=C(Nc1ccc(Cl)cc1)N1CCN(Cc2ccc(F)cc2)CC1',
#  'Clc1ccc2ccccc2n1',
#  'O=P(O)(O)C(CO)O',
#  'COc1ccc(C(=O)/C=C/c2ccc(OC)cc2)cc1O',
#  'Cc1ccc(S(=O)(=O)Nc2ccc(-n3ccnc3)nc2-c2ccccc2)cc1',
#  'Clc1ccc(Cl)cc1C(CO)CO',
#  'O=P(O)(O)C(O)CO',
#  'O=P(O)(O)CCc1c[nH]c(-c2ccccc2)n1',
#  'CCCCCCCCCCCCCCCOCC[C@H]1CCC[C@H]1Cc1ccc(Oc2ccccc2)cc1',
#  'COC(=O)/C=C/c1ccc([N+](=O)[O-])o1',
#  'CCCCCCCCCOC(=O)/C=C/c1ccc(Cl)cc1',
#  'N#Cc1ccc(-c2ccc(-c3ccc(Cl)cc3)nc2O)cc1',
#  'COc1ccc([C@@H](CO)/C=C/c2ccc(OC)cc2)cc1O',
#  'COc1ccc(SCc2ccc(C(=O)OC)c(OC)c2)cc1',
#  'CSc1nc(N)sn1',
#  'COC(=O)c1ccc(-c2ccc(-n3cncn3)cc2)cc1',
#  'COc1ccc(-c2ccc(-n3ccnc3)nc2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(-c2ccc(Cl)cc2)o1',
#  'O=C(Nc1ccccc1)c1ccc(Cl)cc1Cl',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(-c2ccc(Cl)cc2)o1',
#  'NC(=O)/C=C/c1ccc(-c2ccccc2)cc1O',
#  'Cc1ccc(Oc2cc(OC)c(OC)c(CC)c2)cc1',
#  'COc1ccc(C(C)=O)cc1SC1CCC[C@H]1Cc1ccccc1',
#  'COc1ccc(OC)c(C(=O)Nc2ccc(-c3ccncc3)c2)c1',
#  'CCCCC/C(=N\\NC(N)=O)c1ccccc1',
#  'COc1ccc(CSc2ccc(-c3ccc(OC)cc3)nc2)cc1',
#  'COC(=O)CCC(=O)N1CCOC[C@H]1Cc1ccccc1',
#  'COc1ccc(/C=C/C(=O)/C=C/c2ccc(-n3ccnc3)cc2)cc1',
#  'O=C(O)c1ccc(-c2ccnc(-c3ccccc3)n2)cc1',
#  'COC(=O)/C(=N\\NC(N)=S)Nc1ccc(F)c(F)c1',
#  'Cc1ccc(Cn2ccnc2)cc1',
#  'O=C(O)/C=C/c1ccc(O)c(O)c1',
#  'CCCCCCOc1ccc(Br)cc1',
#  'COC(=O)c1ccccc1N/N=C/c1ccc([N+](=O)[O-])o1',
#  'O=C(Nc1ccc(Cl)cc1)N1CCN(Cc2ccccc2)CC1',
#  'O=C(Nc1cccc(Cl)c1)N1CCN(Cc2ccccc2)CC1',
#  'COc1ccc(OCCOc2ccc(-c3ccc(OC)cc3)c(OC)c2)cc1',
#  'O=C(Nc1ccc(F)cc1)N1CCc2ccccc2O1',
#  'CN1C(=O)C=C(Cc2ccc(Cl)c(Cl)c2)CC1',
#  'O=C(N/N=C/c1ccc(Cl)cc1)c1ccc(Cl)cc1',
#  'COc1ccc(C2CCNCC2)cc1',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccccc2)C(=O)N1',
#  'COc1ccccc1-c1nc2ccccc2s1',
#  'O=C(Nc1ccccn1)N1CCN(Cc2ccc(Cl)cc2)Cc2ccccc21',
#  'CC1=CCCCC[C@H]1C(=O)OCc1ccc(Cl)cc1',
#  'COc1ccc(CNCCCCNCc2cnc3ccccc3n2)cc1',
#  'COc1ccc(-c2csc(-c3ccncc3)nc2)cc1',
#  'COC(=O)CCC(=O)Nc1ccc(C(C)(C)C)cc1',
#  'COc1ccc(OCCOc2ccc(C(=O)OC)cc2)cc1O',
#  'CCn1cc(C)nc1-c1ccc(-c2ccc(Cl)cc2)n1',
#  'CCN(CC)CCCNc1ccnc2cc(Cl)ccc12',
#  'Clc1cccc(-c2csc(Nc3ccccc3)n2)c1',
#  'O=C(Nc1ccccc1)c1ccc(-c2ccc(F)c(F)c2)cc1',
#  'O=C(O)c1ccc(-c2ccc(-c3cccs3)o2)cc1',
#  'Cc1ccc([C@@H](C)NC(=S)N/N=C/c2ccc(Cl)cc2)cc1O',
#  'COc1ccc(NC(=S)N/N=C/c2ccc(OC)cc2)cc1O',
#  'CC(C)OC(=O)/C=C/C(=O)OCC(C)=O',
#  'CC(C)OC(Cc1ccccc1)C(=O)O',
#  'COc1ccc(CNC(=O)CSCCC(=O)Nc2ccc(-c3cccnc3)cc2)cc1',
#  'COc1ccc(-c2ccc(-c3cccnc3)cc2)cc1',
#  'Cc1ccc(-c2cnc(-c3cccnc3)cc(=O)[nH]2)c1',
#  'Clc1ccccc1-c1nc2ccccc2[nH]1',
#  'COc1ccc(-c2ncc(-n3ccnc3)nc2N)cc1',
#  'CCOC(=O)c1ccc(NC(=O)/C=C/c2ccc(OC)cc2)cc1O',
#  'Cn1cc(C)c2cc(C)ncc12',
#  'CCCCOC(=O)OCC(=O)NCCc1csc(-c2ccc(C(F)(F)F)cc2)n1',
#  'COc1ccc(C(=O)/C=C/C(=O)c2ccc([N+](=O)[O-])o2)cc1',
#  'COc1ccc(-c2nnc(-c3ccc(Cl)cc3)nc2O)cc1',
#  'Cc1ccc([C@@H](C)NC(=S)N/N=C/c2ccc(Br)cc2)cc1O',
#  'CN(CC(=O)O)CC(=O)Nc1ccc(Cl)cc1',
#  'Cc1ccc(CNC(=O)CSCc2ccc(-c3ccccc3)cc2)cc1',
#  'CCCCCCCCCCCCCCCCOC(CNC(=O)c1ccc(N)cc1)C(=O)O',
#  'COc1ccc([C@@H](CO)COCP(=O)(O)O)cc1',
#  'O=P(O)(O)OCCCC(CCn1ccnc1)c1ccccc1',
#  'COc1ccc(CSc2cn(C)c(N)nc2SC)cc1',
#  'O=[N+]([O-])c1ccc(Nc2ccc(SCc3ccc(F)cc3)cc2)cc1',
#  'CCOC(=O)/C=C/C1=C(\\C)N[C@H](Cc2ccccc2)C1',
#  'COC(=O)Cn1c(C(=O)O)nc(N)c2ccccc12',
#  'CCCCCCCCCCCCOC(C)=C(C)c1ccc(O)cc1',
#  'CCCCCCCCCCCCCCCCCCCC#CCCCCOc1ccc(-c2ccc(-c3cccnc3)cc2)cc1',
#  'S=C(N/N=C/c1ccc(Cl)cc1)c1ccccc1O',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccc(F)cc2)CC1',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(Cl)cc1Cl',
#  'COc1ccc(-c2csc(NC(=N)N)c2)cc1',
#  'COc1ccc(S(=O)(=O)N/N=C/c2ccc(OC)cc2)cc1OC',
#  'C=CCOc1ccc(NC(=S)N/N=C/c2ccc(OC)cc2)cc1O',
#  'CCCCCC/C=C/C(=O)O',
#  'COc1ccc(-c2csc(NC(=N)N)c2)cc1',
#  'CCn1cc(CC(=O)O)nc1-c1ccccc1',
#  'CCCCCCc1ccc(Oc2ccc(-c3cccnc3)cc2)cc1',
#  'COc1ccc(C(=O)NCCc2csc(-c3ccc(F)cc3)nc2)c1',
#  'COc1ccc(-c2csc(-c3ccccc3)n2)cc1',
#  'Clc1ccc(CSc2nc(-c3cccc(Cl)c3)[nH]n2)cc1',
#  'C[S+]([O-])Cc1ccc(-c2ccc(OC)c(OC)c2)cc1',
#  'COc1ccc(-c2ccc(CNC(=N)N)cc2)cc1',
#  'COc1ccc(CNCCc2ccc(OC)cc2)cc1',
#  'Cl.N[C@@H]1CCN(Cc2ccc(Br)cc2)CC1',
#  'O=C(Nc1ccc(Br)cc1)N1CCN(Cc2ccc(Br)cc2)CC1',
#  'O=C(N/N=C/c1ccc([N+](=O)[O-])o1)c1ccccc1',
#  'COc1ccc(/C=C/C(=O)c2cc(OC)c(OC)c(OC)c2)cc1OC',
#  'O=C(Nc1ccccc1)c1nccs1',
#  'CC(C)CCn1ccnc1',
#  'O=C(N/N=C/c1ccc([N+](=O)[O-])o1)c1ccccc1',
#  'COc1ccc(-c2nc(-c3ccc(Cl)cc3)nn2[N+](=O)[O-])cc1',
#  'COc1ccc(-c2ccc(-n3ccnc3)nc2)cc1',
#  'COc1ccc(-c2ccc(-c3ccc(C(C)(C)C)cc3)nc2N)cc1',
#  'CC(C)OC(=O)Cc1ccc(SCc2ccc(OC)c(OC)c2)cc1',
#  'C[C@]1(CO)COc2ccc(OC)c(OC)c2OC',
#  'CCc1ccc(NC(=S)NCc2ccc([N+](=O)[O-])cc2)cc1',
#  'O=C(Nc1ccc(Br)cc1)N1CCCCC1',
#  'CCOC(=O)N1CC[C@@](O)=O1',
#  'O=C(N[C@@H](Cc1ccccc1)P(=O)(O)O)O',
#  'COc1ccc(/C=C/C(=O)c2ccc(C)cc2)cc1O',
#  'COc1ccc(CNC(=O)Cc2ccc(-n3ccnc3)nc2)cc1',
#  'CCCCCCOC(=O)Nc1cccc(S(=O)(=O)Nc2ccc(C#N)cc2)c1',
#  'Cc1ccc(Oc2ccc(-c3cccnc3)cc2)cc1',
#  'COc1ccc(-c2csc(-c3cccc(Cl)c3)nc2[N+](=O)[O-])cc1',
#  'COc1ccc(-c2csc(-c3ccc(Cl)cc3)n2)cc1',
#  'COc1ccc(CSc2nccc(Cl)c2)nc1',
#  'Cc1ccc(SCC(=O)NCCNC(=O)/C=C/c2ccc(OC)cc2)cc1OC',
#  'O=P(O)(O)CCCC/C=C/c1ccc(O)c(O)c1',
#  'O=C(Nc1ccccc1)c1cn(C(CCNCCCn2ccnc2)c2ccccc2)c2ccccc12',
#  'O=C(Nc1ccccc1)c1nc(-c2ccccc2)[nH]1',
#  'O=C(Nc1ccccc1)N1CCN(c2ccc(F)cc2)CC1',
#  'COc1ccc(/C=C/C(=O)c2cc(OC)c(OC)c(OC)c2)cc(OC)c1',
#  'COc1ccc(CSc2nc(-c3cccs3)[nH]c(=O)n3)cc1',
#  'COC(=O)CCOc1cc(C(C)=O)cc(C)c1OC',
#  'N#Cc1ccc(-c2ccc(-c3cccnc3)cc2)o1',
#  'CCN(CC)CCSc1nc2ccccc2nc1N',
#  'Cc1ccc(Cn2ccnc2)cc1',
#  'COc1ccc(C(C)=O)cc1CC(=O)O',
#  'O=C(CNc1ccnc2ccccc12)c1ccc(O)cc1',
#  'CN1CC[C@@H](Cc2ccncc2)CCN1',
#  'Clc1ccccc1CNc1ccc(Cl)cc1Cl',
#  'O=P(O)(O)C(CO)O',
#  'COc1ccc(-c2ccn(Cc3ccc(Cl)cc3)nc2N)cc1',
#  'COC1=C(C)C(=O)N(Cc2ccc(Cl)c(Cl)c2)CC[C@H]1C',
#  'COc1ccc(/C=C/C(=O)c2cc(OC)c(OC)c(OC)c2)cc1O',
#  'COc1ccc(-c2nc(-c3ccc(Cl)cc3)o2)cc1',
#  'COc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'COC(=O)CCC(=O)Nc1ccc(-c2ccc(-c3ccc(Cl)cc3)nc2)cc1',
#  'COc1ccc(-c2nc(-c3ccc(Cl)cc3)s2)cc1',
#  'COc1ccc(/C=C/C(=O)c2cc(OC)c(OC)c(OC)c2)cc1O',
#  'COc1ccc(SCC(=O)NCc2ccc(-c3ccc(OC)cc3)nc2)cc1',
#  'COc1ccc(CSc2nc(-c3ccc(Cl)cc3)n[nH]2)cc1',
#  'COC(=O)/C=C/c1ccc(-c2ccc(Cl)cc2)cc(Cl)c1',
#  'COc1ccc(/C=C/C(=S)NCCCNC(=O)/C=C/c2ccccc2O)cc1O',
#  'COc1ccc(-c2nc(-c3ccc(Cl)cc3)n[nH]2)cc1',
#  'O=C(Nc1ccncc1)c1ccc(-c2ccccn2)cc1',
#  'Nc1ccc(S(=O)(=O)Nc2ccc(-c3ccc(Cl)cc3)nc2O)cc1',
#  'Cn1cc(C#N)cc1C(C)=O',
#  'CN1CC[C@@H](O)[C@H]1O',
#  'COc1ccc(/C=C/C(=O)c2cc(OC)c(OC)c(OC)c2)cc1OC',
#  'O=C(Nc1ccc(Cl)cc1)N1CCN(Cc2cccc(Br)c2)CC1',
#  'COc1ccc(CSc2nc(-c3cccnc3)c[nH]c2O)cc1',
#  'COc1ccc(/C=C/C(=O)/C=C/c2cccc(OC)c2)cc1O',
#  'COc1ccc(-c2ccc(-n3ccnc3)nc2)cc1',
#  'COc1ccc(-c2ccnc(-c3cccnc3)c2)cc1',
#  'O=C(Nc1ccccc1)c1nccs1',
#  'COc1ccc(NC(=S)NNC(=S)N/N=C/c2ccc(OC)cc2)cc1O',
#  'O=C(NCCCNc1ccnc2cccc12)N1CCCCC[C@H]1C',
#  'Clc1ccc(-c2csc(-c3cccnc3)c2)cc1',
#  'CN(C)CCCCNC(=O)c1cccc(OC)c1',
#  'COc1ccc(CNC(=O)CSc2ncc(-c3ccc(Cl)cc3)nc2O)cc1',
#  'O=C(CN1CCCC1)N1CCN(Cc2ccc(F)cc2)=CC1',
#  'Cn1c(=O)n(CC(C)C)c2ccc(C#N)cc21',
#  'COc1ccc(-c2ccc(-n3ccnc3)cn2)cc1',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccc(Cl)cc2)CC1',
#  'O=C(Nc1ccc(Cl)cc1)S(=O)(=O)c1ccc(Cl)cc1',
#  'CCCCCCCCc1ccc(O)c(O)c1',
#  'COc1ccc(-c2cc(C)n(-c3ccccc3)nc2[N+](=O)[O-])cc1',
#  'CCCCCCCC[C@@H]1O[C@@H](O)[C@@H]1O[C@H](CO)[C@@H](O)O',
#  'COc1ccc(-c2ncc(-n3ccnc3)cc(C)n2)cc1',
#  'COc1ccc(/C=N/NC(N)=S)cc1',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccccc2)CC1',
#  'COc1ccc(CNC(=O)CSCCc2ccc(-n3ccnc3)cc2)cc1',
#  'O=C(Cc1ccccc1)N1CCC(O)C1',
#  'Cn1ccc(CSc2nc(-c3ccc(Cl)cc3)nn2)cc1',
#  'COc1ccc(/C=N/NC(=O)C(C)C)cc1',
#  'O=[N+]([O-])c1ccc(-c2ccc(-c3cccnc3)cc2)o1',
#  'COC(=O)/C=C/C(=O)N1CC[C@@](Cc2ccc(Cl)cc2)C1',
#  'O=C(N/N=C/c1cccc([N+](=O)[O-])c1)N1CCN(Cc2ccc(Cl)cc2)CC1',
#  'COc1ccc(C(=O)/C=C/c2ccc(OC)cc2)cc1O',
#  'Clc1ccc(CNCc2ccc(-c3cccs3)o2)cc1',
#  'CCOC(=O)Nc1ccc(S(=O)(=O)Nc2ccc(C(F)(F)F)cc2)cn1',
#  'O=C(Nc1ccc(Cl)cc1)c1nccs1',
#  'CCCCCCCCCCCC[S+]([O-])C[C@H]1CCN(Cc2ccc(F)cc2)CC1',
#  'COc1ccc(CNC(=O)CSCC(=O)NCCCNCCCNC(=O)CCSCCCCCCCCc2ccc([N+](=O)[O-])cc2)cc1',
#  'CCn1cc(C#N)cc1C(=O)O',
#  'COC(=O)C(CSc1ccccc1)N1CCN(CC(C)C)C1',
#  'O=P(O)(O)CCCc1ccc(O)cc1',
#  'CCCCCCCOC(=O)Nc1ccc(OCc2ccc(Cl)cc2)cc1',
#  'CC(C)(C)Nc1ccnc2cc(C#N)ccc12',
#  'O=C(Nc1cccc(Br)c1)N1CCOC1',
#  'CCOC(=O)c1ccc(NC(=O)CSc2ncc(-c3ccc(Cl)cc3)nc2O)cc1',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)c(OC)c2)cc1O',
#  'CCN(CC)CCc1ccc(Oc2ccc(-c3ccccc3)cc2)cc1',
#  'COc1ccc(CCNCCc2ccc(OC)cc2)cc1',
#  'COc1ccc(-c2ccc(-c3ccc(OC)cc3)nc2N)cc1',
#  'CCc1ccc(Oc2ccc(C(=O)O)cc2)cc1',
#  'COc1ccc(C(=O)/C=C/c2ccc([N+](=O)[O-])o2)cc1',
#  'CCOC(=O)Nc1ccc(Oc2ccc(C(F)(F)F)cc2)cc1',
#  'O=[N+]([O-])c1ccc(NC(=N)N)cc1',
#  'Cc1ccc(SCc2cc(C)nc(N)c2)cc1',
#  'O=C(O)c1cccc(OCCn2ccnc2)c1',
#  'CCCCCCCC/C=C/C(=O)Nc1ccc(-c2cccnc2)cc1',
#  'O=C(Nc1ccccc1)N1CCN(c2ccc(F)cc2)C(=O)N1',
#  'Clc1ccc(Cn2ccnc2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)N1CCN(Cc2ccc(F)cc2)CCO1',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)c(OC)c2)cc1O',
#  'COc1ccc(SCc2ccc(NC(=N)N)cc2)cc1',
#  'O=C(Nc1ccc(Br)cc1)N1CCN(Cc2ccc(F)cc2)CC1',
#  'O=P(O)(O)CCCCP(=O)(O)O',
#  'O=C(NO)c1ccc([N+](=O)[O-])cc1',
#  'Cn1c(=O)[nH]c(=O)n(Cc2ccc(Cl)cc2)n1',
#  'O=C(O)c1ccc(-c2ccc(O)c(O)c2)o1',
#  'CN(CC)CCCCNC(=O)O',
#  'COc1ccc(-n2ccnc2)cc1',
#  'COc1ccc(-c2csc(NC(=N)N)c2)cc1',
#  'O=C(Nc1ccc(Br)cc1)N1CCN(Cc2ccccc2)CC1',
#  'COc1ccc(SSc2nc(N)nc(N)nc2)cc1',
#  'CCCCCCCCNC(=O)Nc1ccc(-c2ccc(-c3cccs3)o2)cc1',
#  'Cl.O=C(Cl)N/N=C/c1ccc([N+](=O)[O-])o1',
#  'COc1ccc(-c2cnc(-c3ccc(Cl)cc3)nc2O)cc1',
#  'O=C(Nc1ccccc1)N1CCOCC1',
#  'O=C(Nc1ccccc1)N1CCN(c2ccccc2)CCN1',
#  'COc1ccc(-c2csc(N)c2-c2ccccc2)n1',
#  'COc1ccc(/C=C/C(=N)NC(C)C)cc1',
#  'S=C(N/N=C/c1ccc([N+](=O)[O-])o1)C1CCCCC1',
#  'COc1ccc(C(=O)N[C@@H](CC(=O)O)Nc2ccc(C(F)(F)F)cc2F)cc1',
#  'CSc1nc2ccccc2nc1SC',
#  'COc1ccc(/C=C/C(=O)c2cc(O)c(O)c(O)c2)cc1O',
#  'COC(=O)c1ccc(OC)c(C(=O)Nc2ccc(-c3cccnc3)c2)c1',
#  'CCOc1ccc(CSc2ncc(Cl)c(Cl)c2Cl)c(Cl)c1',
#  'COc1ccc(CNC(=O)c2ccc(OC)c(OC)c2)cc1',
#  'O=C(NCCc1csc(-c2cccs2)n1)c1ccccc1',
#  'O=C(Nc1ccc(Cl)cc1)N1CCC[C@@](=O)O1',
#  'O=C(Nc1ccc(Cl)cc1)c1cc(F)cc(F)c1Br',
#  'O=C(Nc1ccccn1)c1ccc(-c2ccc3ccccc3nc2)cc1',
#  'COc1ccc(-c2csc(NC(=O)N/N=C/c3ccccc3OC)o2)cc1',
#  'COc1cccc(-c2csc(-c3ccc(Cl)cc3)n2)c1',
#  'O=C(/C=C/c1ccc(Cl)cc1)c1ccc(O)c(O)c1',
#  'Cc1ccc(S(=O)(=O)Nc2ccc(-c3ccc(C#N)cc3)cc2[N+](=O)[O-])cc1',
#  'Cl.N[C@H](Cc1ccccc1)N1CCN(c2ccc(F)cc2)CC1',
#  'COc1ccc(/C=C/C(=N)N)cc1',
#  'Clc1ccc(CSc2ccc(Br)cc2)o1',
#  'CN(C)CCCOc1ccc(-c2ccc(-c3ccc(N)cc3)cc2)cc1',
#  'CCCC[C@@H]1O[C@@H](O)[C@@H]1OC[C@H]1CCOC[C@H]1CCO',
#  'COc1ccc(-n2nc(-c3ccc(Cl)cc3)nn2)cc1',
#  'COc1ccc(-c2nc(-c3cccc(Cl)c3)n[nH]2)cc1',
#  'O=C(N/N=C/c1ccc([N+](=O)[O-])o1)OCc1ccccc1',
#  'COC(=O)/C=C/c1ccc(Br)cc1O',
#  'O=C(Nc1ccc(Cl)cc1)c1cn(Cc2ccc(Cl)cc2)c2ccccc2c1=O',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(-c2ccc(F)cc2)cc1',
#  'COc1ccc(-c2csc(-c3cccnc3)c2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)N1CCN(c2ccc(Cl)cc2)CC1',
#  'COC(=O)CCCCCSCCCc1csc(-c2ccc(C#N)cc2)n1',
#  'CCCc1cc(O)c(O)c(/C=C/c2ccc(OC)cc2)c1',
#  'COc1ccc(-c2ccc(-n3ccnc3)nc2)cc1',
#  'COc1ccc(C(=O)/C=C/c2ccc(OC)cc2)cc1O',
#  'COc1ccc(C(=O)/C=C/c2ccc(Cl)cc2)cc1O',
#  'O=C(Nc1ccc(Cl)cc1)Nc1cccc2ccccc12',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)c(OC)c2)cc1O',
#  'COc1ccc(-c2nnc(-c3cccc(Cl)c3)nc2O)cc1',
#  'Fc1ccc(-c2ccc(-c3cccnc3)cc2)o1',
#  'COc1ccc(-c2csc(-c3cccnc3)c2)cc1',
#  'COc1ccc(-c2ccc(-c3ccc(N)cc3)nc2)cc1',
#  'COc1ccc(CSc2nc(-c3cccs3)nc(N)c2N)cc1',
#  'O=C(Nc1ccccc1)c1nc(-c2ccc(F)cc2)[nH]c1=O',
#  'CCCCCCOc1ccc(-c2cnc(-c3ccc(C#N)cc3)nc2N)cc1',
#  'CC(C)=C[C@H](Cc1ccc(-c2ccc(CNC(=N)N)cc2)n1)C1CCCC[C@H]1',
#  'COc1ccc(/C=C/C(=O)/C=C/c2ccc([N+](=O)[O-])o2)cc1',
#  'COc1ccc(C(=O)N[C@@H](CCNC(=O)/C=C/c2ccc([N+](=O)[O-])o2)cc1OC)c1ccccc1',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccc(F)cc2)C(Cl)=CCC1',
#  'COc1ccc(CSc2ncc(-c3ccc(Cl)cc3)nc2O)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1ncc[nH]1',
#  'CCOC(=O)c1ccc(-c2ccc(-n3ccnc3)nn2)cc1',
#  'COc1ccc(-c2cnc(-c3ccc(Cl)cc3)nc2-c2ccccc2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)N1CCN(Cc2ccccc2)C(=O)N1',
#  'COC(=O)CCCc1ccc(O)c(O)c1',
#  'COc1ccc(NC(=S)N/N=C/c2ccc(OC)cc2)cc1O',
#  'COC(=O)OCCc1[nH]c(=O)n(CCNC(=O)CCCNCCCn2ccnc2)c1O',
#  'O=C(/C=C/c1ccc(Br)cc1)c1cccc(O)c1',
#  'CC(C)OC(Cc1ccccc1)C(=O)O',
#  'COc1ccc(OCCCCCCNC(=O)CSCCC(=O)Nc2ccc(C(F)(F)F)cc2)cc1',
#  'O=C(N/N=C/c1ccc([N+](=O)[O-])o1)N1',
#  'C[C@H](Cc1ccc(O)c(O)c1)C(CN)C(C)C',
#  'Cl.N/N=C/c1ccc(-c2ccccc2)o1',
#  'CCOC(CO)Cc1ccc(OP(=O)(O)O)cc1',
#  'Cn1cc(-c2ccc(-c3ccc(C(C)(C)C)n3)nc2)cc1',
#  'CCCCCCOC(=O)/C=C/c1ccc(Cl)cc1',
#  'COc1ccc(-c2csc(NCc3cccc(Cl)c3)nc2O)c1',
#  'CC1(C)C[C@H](Cc2ccc(C#N)cc2)CCO1',
#  'COc1ccc(-c2csc(-c3cccnc3)c2)cc1',
#  'CCCCCCCCCCCCCCCOc1ccc(C(=O)Nc2ccc(SC)cc2)cc1',
#  'CCCOc1ccc(/C=C/C(=O)NCP(=O)(O)O)cc1',
#  'N#Cc1ccc(-c2csc(-c3cccnc3)n2)cc1',
#  'COc1ccc(C(=O)/C=C/c2ccc([N+](=O)[O-])cc2)cc1OC',
#  'CCCSCC(=O)Nc1ccnc(N)c1',
#  'O=C(O)c1cccc(/C=N/NC(=O)c2ccc([N+](=O)[O-])cc2)c1',
#  'Cc1ccc(NC(=S)N/C(=N)N)cc1',
#  'COc1ccc(CSc2ncc(C(C)(C)C)c(C)n2)cc1',
#  'O=C(N[C@@H]1C[C@@H](O)[C@@H]1O)C1CCOC1',
#  'O=C(Nc1ccccc1)N1CCC[C@@]1',
#  'COc1ccc(-c2csc(-c3ccc(Cl)cc3)n2)cc1',
#  'O=C(Nc1cccnc1)c1ccc(Cl)cc1',
#  'O=[N+]([O-])c1ccc(NC(=N)N)cc1',
#  'COc1ccc(-c2cnc(-c3ccc(Cl)cc3)cc2O)cc1',
#  'COC(=O)COC(=O)/C=C/c1ccc(Cl)cc1Cl',
#  'O=C(Nc1ccccc1)N1CCN(c2ccc(Cl)cc2)CC1',
#  'COc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'O=C(Nc1nc2ccccc2s1)c1ccccc1',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(Cl)cc1Cl',
#  'CN(CC)CCCNc1ccnc2cc(Cl)ccc12',
#  'O=C(NCCc1csc(-c2ccc(F)cc2)n1)c1ccccc1',
#  'O=C(NCc1ccc(Br)cc1)N1CCN(Cc2ccc(Br)cc2)C(=O)N1',
#  'O=C(O)c1ccc(-c2ccc(-c3cccnc3)o2)cc1',
#  'O=P(O)(O)CCCCSc1ccc(-c2ccccc2)n1',
#  'O=C(NCCc1csc(-c2ccccc2)n1)c1ccccc1',
#  'Cc1ccc(SCc2ccc(C(=O)NCc3ccccc3)nc2)cc1',
#  'Cl.N[C@@H](Cc1ccccc1)N1CCN(c2ccc(F)cc2)CC1',
#  'CCOC(CO)OC(Cc1ccc(Cl)cc1)C(=O)Nc1ccc(Br)cc1',
#  'CCc1ccc(Oc2ccc(C)cc2)cc1',
#  'CC/C(=N\\NC(=S)NCc1ccc(Cl)cc1)c1cccc(Cl)c1',
#  'COc1ccc(Cn2ccnc2)cc1',
#  'COc1ccc(C(=O)/C=C/c2ccc(OC)cc2)cc1O',
#  'CCCCOc1ccc(-c2ccnnc2)cc1',
#  'CCN(CC)CCCNC(=O)O',
#  'CCc1ccc(NC(=S)N/N=C/c2ccc(OC)cc2)cc1O',
#  'O=C(Nc1ccccc1)c1nc2ccccc2[nH]1',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccc(Cl)cc2)CC1',
#  'O=P(O)(O)CCCCCNS(=O)(=O)c1ccccc1Br',
#  'O=C(Nc1ccc(-c2ccc(F)cc2)cc1)N/N=C/c1ccc([N+](=O)[O-])o1',
#  'Cn1cc(COC(C)C)cc1OC',
#  'COc1ccc(Cc2ccc(-c3ccncc3)c(N)nc2)cc1',
#  'COc1ccc(CNCCCNC(=O)Nc2ccc(C(F)(F)F)cc2)cc1',
#  'COc1ccc(OC)c(/C=C/c2ccc(-n3ccnc3)c2)cc1',
#  'O=C(Nc1nc2ccccc2s1)c1ccccc1',
#  'O=C(N[C@@H](Cc1csc(-c2ccccc2)c1)c1cccnc1)c1ccccc1',
#  'O=C(NO)c1ccc(-c2ccc(Cl)cc2)o1',
#  'COc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'O=C(N/N=C/c1cccc([N+](=O)[O-])c1)N1CCN(Cc2ccc(F)cc2)CC1',
#  'Clc1ccc(Cn2ccnc2)cc1',
#  'CCCCOc1ccc(NC(=O)CCNC(=O)/C=C/c2ccc(OC)cc2)cc1OC',
#  'CCc1ccc(NC(=S)N/N=C/c2ccc(OC)cc2)cc1[N+](=O)[O-]',
#  'COc1ccc(-c2csc(-c3cccnc3)c2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1ncc[nH]1',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(O)c(O)c1',
#  'Cl.NCc1ccc(-c2ccc(F)cc2)c(Cl)c1',
#  'COc1ccc(CNC(=O)c2cc(OC)c(OC)c(OC)c2)cc1OC',
#  'COc1ccc(CNCCCNC(=S)N/N=C/c2ccc([N+](=O)[O-])o2)cc1',
#  'CCCCCCCCCCOc1ccc(-c2ccc(OC)c(OC)c2)cc1',
#  'O=C(/C=C/c1ccc([N+](=O)[O-])o1)c1ccc([N+](=O)[O-])o1',
#  'CCN(CC)CCCOc1ccc(Oc2ccc([N+](=O)[O-])cc2)cc1',
#  'CCCCn1ccnc1',
#  'Clc1ccc(Sc2nccs2)cc1',
#  'CCCCCCCCCCCCOC(=O)/C=C/C(=O)OCCO',
#  'COc1ccc(SCC(=O)NC(C)C)cc1OC',
#  'CCCOc1ccc(-c2cn(Cc3ccc(Cl)cc3)nn2)cc1',
#  'Cc1ccc(S(=O)(=O)Nc2ccc(C(F)(F)F)cc2F)cn1',
#  'C/C(=N\\NC(N)=S)c1ccc(Cl)cc1',
#  'CCCCCc1ccc(O)c(CNC(=O)c2ccc(-c3ccccc3)n2)c1',
#  'COc1ccc(-c2nc(-c3cccc(Cl)c3)nn2-c2ccccc2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1cn(Cc2ccc(Cl)cc2)nn1',
#  'CCC(CCCc1ccccc1)NC(=O)Nc1ccnc2cc(Cl)ccc12',
#  'CCc1ccc(NC(=S)N/N=C/c2ccc(OC)cc2)cc1O',
#  'CN(C)CC[C@H](Cc1ccc(O)cc1)C(=O)O',
#  'CCC[C@@H]1/C(=N\\O)O[C@H]1[C@@H](CO)O',
#  'COc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'O=C(Nc1nc2ccccc2s1)c1ccccc1',
#  'CCCCC/C(=N\\NC(N)=O)c1ccccc1',
#  'O=C(NNC(=O)c1ccccc1)N1CCN(Cc2ccccc2)C(=O)N1',
#  'Cc1ccc(CNC(=O)c2ccc(-c3ccc(O)c(O)c3)c(O)c2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1nc(-c2ccc(F)cc2)nn1',
#  'O=C(NCCc1csc(-c2ccccc2)n1)c1ccccc1',
#  'O=C(Nc1cccc(Cl)c1)c1cn(CC(CC(CCN)CCO)O)O[C@H]1C',
#  'O=C(Nc1ccccc1)N1CCN(O)CCO1',
#  'Cl.NCCOCc1ccccc1',
#  'Cc1ccc(S(=O)(=O)OCC(C)C)cc1',
#  'Cl.NCCNc1ccnc2cc(Cl)ccc12',
#  'Cc1ccc(-c2cn(CC(=O)NO)n(C)nc2O)n1',
#  'O=P(O)(O)C(O)O',
#  'CCCCCCCOc1ccc([C@@H](C)P(=O)(O)O)cc1',
#  'COc1ccc(OCC(C)C)cc1',
#  'Cl.NC[C@@H]1OC[C@H]1Cc1ccccc1',
#  'CCCCc1ccc(Oc2ccc(OC)cc2)cc1',
#  'O=C(Nc1ccccc1)N1CCN(c2ccc(F)cc2)C(Cl)=N/N1c1ccccc2c1O',
#  'O=C(Nc1ccncc1)c1ccc(-c2cccnc2)cc1',
#  'O=[N+]([O-])c1ccc(-c2ccc(-c3cccnc3)cc2)o1',
#  'COc1ccc(-c2cnc(-c3ccc(Cl)cc3)nc2O)cc1',
#  'O=C(Nc1ccc(Cn2ccnc2)cc1)N1CCN(Cc2ccc(Cl)cc2)CC1',
#  'COc1ccc(-c2nnc(-c3cccnc3)cs2)cc1',
#  'COC(=O)c1ccc(C(=O)NCc2ccc(-c3cccs3)o2)cc1',
#  'O=C(Nc1ccc(Br)cc1)N1CCN(Cc2ccc(F)cc2)CC1',
#  'CCCCOC(=O)N1CCN(Cc2ccc(C#N)cc2)C[C@@H]1O',
#  'CCCCCOc1ccc(-c2csc(-c3ccc(Cl)cc3)n2)cc1',
#  'Clc1ccc(-c2ccc(-c3ccncc3)cc2)o1',
#  'COC(=O)Nc1ccc(C(=O)Nc2ccc(-n3ccnc3)cc2)cc1',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)c(OC)c2)cc1O',
#  'COc1ccc(OCC2CCOCC2)cc1',
#  'CCCOC(=O)Cc1ccc(N)c(N)c1',
#  'COC(=O)c1ccc(NC(=O)/C=C/c2ccc([N+](=O)[O-])o2)cc1',
#  'CCOC(=O)CCc1ccc(Oc2ccc(OC)c(OC)c2)cc1',
#  'CN(CC)CCC[C@@H]1O[C@@H](CO)[C@H](O)[C@H](O)O',
#  'CCOC(=O)/C=C/c1ccc(Cl)cc1Cl',
#  'O=C(Nc1cccc(Cl)c1)c1ccc(-n2ccnc2)cc1',
#  'COc1ccc(S(=O)(=O)Nc2ccc(-c3ccncn3)nc2)cc1',
#  'CCCOC(=O)/C=C/c1ccc([N+](=O)[O-])o1',
#  'CCCCCOC(=O)/C=C/c1ccc(-n2ccnc2)cc1',
#  'CCCOc1ccc(-c2ccc(-c3cccnc3)cc2)cc1',
#  'O=C(Nc1ccccc1)c1nc2ccc(Cl)cc2s1',
#  'COc1ccc(-c2csc(NC(=N)N)c2)cc1',
#  'O=C(O)Cc1cnc(-c2ccccc2)n1',
#  'COc1ccc(-c2csc(-c3ccc(Cl)cc3)nc2N)cc1',
#  'CCC/C(=C\\CNC(=O)O)c1ccc(Cl)cc1',
#  'Cc1ccc(NC(=S)N/N=C/c2ccc(OC)cc2)cc1O',
#  'O=C(O)/C=C/c1ccc(-c2ccccc2)o1',
#  'CCCOC(=O)c1ccc(NC(=O)CCNC(=O)Nc2ccc(-c3cccnc3)cc2)cc1',
#  'COc1cccc(-c2nnc(-c3cccnc3)nc2)cc1',
#  'COc1ccc(CSc2ncc(-c3ccc(Cl)cc3)nc2N)cc1',
#  'COc1ccc(C(=O)/C=C/c2ccc([N+](=O)[O-])cc2)cc1OC',
#  'CCCCCCOc1ccc(C(=O)/C=C/c2ccc(OC)cc2)cc1OC',
#  'C[S+]([O-])c1ccc(SSc2ccc(C(=O)NCc3ccc(Cl)cc3)o2)cc1',
#  'CN(C)CCCc1ccc(Oc2ccc(Cl)cc2)cc1',
#  'C/C(=N\\NC(N)=S)c1ccc(Cl)cc1Br',
#  'COc1ccc(CSc2ncc(-c3ccc(Cl)c(Cl)c3)c(Cl)c2F)cc1',
#  'Cl.O=[N+]([O-])c1ccc(-c2ccc(-c3cccnc3)cc2)o1',
#  'CCCCOCOCc1ccc(Oc2ccc(OC)cc2)cc1',
#  'O=C(Nc1ccc(Cl)cc1)c1ccc(Cl)cc1O',
#  'COc1ccc(CSc2nc(-c3ccc(Cl)cc3)s2)cc1',
#  'CCOC(=O)/C(=C\\c1ccc(O)c(O)c1)C(Cl)c1cccnc1',
#  'O=C(Nc1ccncc1)c1ccc(-c2cccs2)cc1',
#  'COc1ccc(-c2coc(-c3ccc(Cl)cc3)nc2N)cc1',
#  'COc1ccc(NC(=O)CSCCNC(=O)/C=C/c2ccc(OC)cc2)cc1OC',
#  'COc1ccc(C(=O)/C=C/c2ccc(C#N)cc2)cc1',
#  'O=C(Nc1cccc2ccccc12)N1CCN(c2ccc(Cl)cc2)CC1',
#  'CC1=CCCOC1=O',
#  'O=C(Nc1ccncc1)c1ccc(-c2ccccc2)cc1',
#  'CCOC(=O)c1ccc(/C=C/C(=O)c2cc(OC)c(OC)c(OC)c2)cc1O',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccc(F)cc2)CC1',
#  'CCSC(=O)N/N=C/c1ccc([N+](=O)[O-])o1',
#  'CCOC(=O)c1ccccc1Nc1ccc(S(=O)(=O)NCc2ccc(F)cc2)c2ccccc12',
#  'Cl.NCCOCCO',
#  'O=P(O)(O)OCC(CO)P(=O)(O)O',
#  'CCCc1ccc(-c2ccc(-n3ccnc3)cc2)cc1',
#  'CCOC(=O)Nc1nc2ccccc2[nH]1',
#  'O=C(Nc1ccccc1)c1nc(-c2ccc(Cl)cc2)n[nH]1',
#  'COc1ccc([C@@H](CO)OCCCCNC(=O)Nc2cccc(Cl)c2)cc1',
#  'O=C(N/N=C/c1ccc(Cl)cc1)c1ccc(Br)cc1',
#  'COc1ccc(CSc2nc(-c3ccc(Br)c(O)c3)s2)cc1',
#  'COc1ccc(/C=C/C(=O)/C=C/c2ccc(OC)cc2)cc1O',
#  'COc1ccc(/C=C/C(=N)N)cc1',
#  'COc1ccc(CCn2ccnc2)c(O)c1',
#  'COc1ccc(C(=O)/C=C/c2ccc(OC)cc2)c(OC)c1',
#  'O=C(NNC(=O)c1ccccc1)c1ccc(Cl)cc1',
#  'COc1ccc(-c2ccc(-c3ccncc3)nc2)cc1',
#  'CCC[C@@](C)(C)O',
#  'COc1cccc(-c2n[nH]c(-c3ccccc3)n2)c1',
#  'CCCCCCC[C@H]1CC[C@@H](O)C[C@@H]1',
#  'Cl.O=P(CSc1ccccc1)N1CCSC1',
#  'Cc1ccc(CNCCCNCCNCCNCCCNC(=N)N)cc1',
#  'Clc1ccc(CSc2ccc(-c3cccs3)cs2)cc1',
#  'COc1ccc(-c2nc(-c3cccc(Cl)c3)s2)cc1',
#  'COc1ccc(CNCCc2cnc3ccccc3n2)cc1',
#  'COc1ccc(SCC(=O)Nc2ccc(C(C)(C)C)cc2)cc1OC',
#  'CCCCCCCCC/C=C/C(=O)O',
#  'CCC[C@@H](O)O',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccc(Br)cc2)CC1',
#  'O=C(Nc1ccccc1)N1CCN(Cc2ccc(F)cc2)CC1',
#  'COc1ccc(/C=C/C(=N)NC(N)=O)cc1',
#  'O=C(Nc1ccccn1)N1CCCCC[C@@H]1',
#  'CCCCOC(=O)Nc1ccncc1',
#  'CCCCCCCCCCCC/C(=C\\C)NC(C)C',
#  'COC(=O)c1ccc(C(=O)OCc2ccc(Cl)cc2)cc1O',
#  'CCCCCCc1ccc(O)cc1',
#  'Cc1ccc(NC(=S)N/N=C/c2ccc([N+](=O)[O-])o2)cc1',
#  'COc1ccc(/C=C/C(=N)N)cc1',
#  'O=C(Nc1cccnc1)c1ccc([N+](=O)[O-])o1',
#  'COc1ccc(-c2nc(-c3ccc(Cl)cc3)n[nH]2)cc1',
#  'Cl.Cl.N[C@@H]1CC[C@H]1O',
#  'CSc1nc(N)nc(N)c1-c1ccccc1',
#  'COc1ccc(CNC(=O)CSc2nc(-c3ccc(F)cc3)n[nH]2)cc1',
#  'Nc1ccc(S(=O)(=O)Nc2ccc(Cl)cc2)c(=O)n1',
#  'O=C(O)c1ccc(-c2ccc(-n3ccnc3)o2)cc1',
#  'C[C@]1(Cc2ccc([N+](=O)[O-])cc2)CC[C@@H]1O',
#  'C/C(=N\\NC(N)=S)c1ccc(Cl)cc1',
#  'COCc1ccc(C#N)cc1',
#  'CSc1nnc(-c2ccc(C#N)cc2)n1',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)c(OC)c2)cc1O',
#  'O=P(O)(O)CCCCC[C@]1(C)COc2ccccc2O1',
#  'COc1ccc(/C=C/C(=O)c2ccc(OC)c(OC)c2)cc1O',
#  'O=C(N[C@H](Cc1ccc(O)c(O)c1)Nc1ccc(Cl)cc1)c1ccccc1Cl',
#  'COc1ccc(/C=C/C(=O)/C=C/c2ccc([N+](=O)[O-])o2)cc1',
#  'COC(=O)CCP(=O)(O)O',
#  'COc1ccc(-c2nc(-c3ccc(Cl)cc3)nc2O)cc1',
#  'CN(CC)CNc1ccnc2cc(Cl)ccc12',
#  'O=C(Nc1ccccc1)c1ccc(-c2ccc(F)cc2)o1',
#  'COc1ccc(OC)c(C(=O)/C=C/c2ccc(C)cc2)c1O',
#  'Cc1ccc(-c2ccnc(NC(=N)N)c2)cc1',
#  'O=C(O)/C=C/c1ccc([N+](=O)[O-])o1',
#  'COc1ccc(CNC(=O)CSc2nccs2)cc1',
#  'O=C(NCCc1csc(-c2ccccc2)n1)c1ccccc1',
#  'C=CCOc1ccc(-c2ccnc(N)c2)cc1',
#  'O=C(NCCc1csc(-c2ccccc2)n1)c1ccccc1',
#  'CCOC(=O)c1ccc(-c2ccnc(N)c2)cc1',
#  'CCCCCCC[S+]([O-])Oc1ccc(-c2ccc(OC)c(OC)c2)cc1',
#  ...]

# %%
# Specify the output file name
output_file = 'smiles_list.txt'

# Write the SMILES list to a .txt file
with open(output_file, 'w') as file:
    for smiles in smiles_list:
        file.write(smiles + '\n')

print(f"SMILES list saved to '{output_file}'.")
# Out:
# SMILES list saved to 'smiles_list.txt'.

# %%
from rdkit import Chem
import pandas as pd
import csv

data = []
valid = 0
invalid = 0

def check_validity(smile):
    try:
        mol = Chem.MolFromSmiles(smile)
        if mol is not None:
            return True
        else:
            return False
    except:
        return False

for smile in smiles_list:
    if check_validity(smile):
        validity = 'valid'
        valid += 1
    else:
        validity = 'invalid'
        invalid += 1
    data.append([smile, validity])

print("valid: ", valid)
print("invalid: ", invalid)
# Out:
# valid:  44964
# invalid:  5036

# %%
df = pd.DataFrame(data, columns=['smile', 'validity'])

# Drop duplicate SMILES strings
df = df.drop_duplicates(subset=['smile'])
# Filter to keep only valid SMILES strings
valid_smiles = df[df['validity'] == 'valid']['smile']

# Specify the output file name
output_file = 'smiles_list.txt'

# Write the valid SMILES list to a .txt file
with open(output_file, 'w') as file:
    for smiles in valid_smiles:
        file.write(smiles + '\n')

print(f"SMILES list saved to '{output_file}'.")
# Out:
# SMILES list saved to 'smiles_list.txt'.

# %%
import torch

# Save generator and discriminator models
torch.save(gan_model_loaded.generator.state_dict(), f"generator.pth")
torch.save(gan_model_loaded.discriminator.state_dict(), f"discriminator.pth")

# Save tokenizer state
tokenizer_state = {
    'mapping': gan_model_loaded.tokenizer.mapping,
    'inv_mapping': gan_model_loaded.tokenizer.inv_mapping,
    'start_token': gan_model_loaded.tokenizer.start_token,
    'end_token': gan_model_loaded.tokenizer.end_token,
    'vocab_size': gan_model_loaded.tokenizer.vocab_size
}
torch.save(tokenizer_state, f"tokenizer.pth")

# Save generator optimizer state
torch.save(gan_model_loaded.generator_optim.state_dict(), f"generator_optimizer.pth")

# Save discriminator optimizer state
torch.save(gan_model_loaded.discriminator_optim.state_dict(), f"discriminator_optimizer.pth")

print("Model saved successfully.")
# Out:
# Model saved successfully.
